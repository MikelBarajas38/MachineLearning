# %% [markdown]
# <a href="https://colab.research.google.com/github/MikelBarajas38/MachineLearning/blob/main/ClassCompFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Comparative Analysis of Classifier Models**
#
# ## Machine Learning
# ### Mikel Ignacio Barajas Martínez
#
# Ingeniería en Sistemas Inteligentes, 2021, 336483, 202102300012 \
# Machine Learning, 281601
#
# ### 03/31/24
#
# 𝝮

# %%
# base imports
# !pip install ucimlrepo
from ucimlrepo import fetch_ucirepo
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# data preparation and preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# metrics and evaluation
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# decision tree
from sklearn import tree

# naive bayes
from sklearn.naive_bayes import GaussianNB

# k-nearest neighbors
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.inspection import DecisionBoundaryDisplay # visualization

# SVMs
from sklearn import svm
from sklearn.model_selection import GridSearchCV, StratifiedShuffleSplit
from matplotlib.colors import Normalize

# DNNs
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# CNNs
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten
# Out:
# Requirement already satisfied: ucimlrepo in /usr/local/lib/python3.10/dist-packages (0.0.6)

# %% [markdown]
# ## **Abstract**
#
# This notebook presents a comparative analysis between three simple classifier models: decision trees, which generate “rules” based on the relationship between
# the input data (using metrics such as information entropy); Naïve-Bayes, which uses a
# joint probability model where all attributes are assumed to be mutually independent;
# a k-nearest neighbor method where a predefined number of training samples closest in distance to the testing point are chosen to predict its class; and support vector machines (SVM), which find the optimal separating hyperplane for classification. Two
# datasets are used for training and testing: the Iris dataset (1988) and the Wine dataset (1991),
# both taken from the UCI machine learning repository. Two training sessions per model were conducted for each dataset, one using a 50/50 training split and the other using an 80/20 training split.

# %% [markdown]
# ## **Introduction**
#
# Classifier algorithms are, as the name suggests, ones that categorize inputs into one of a defined set of discrete classes (Cuevas, 2020). Such a broad definition encompasses a high number of processes, from simple heuristic-based classifiers to more advanced machine learning
# techniques.
#
# A decision tree represents a function that takes as input a vector of attribute values and
# returns a “decision”: a single output value, which is reached through a series of tests (Russell
# & Norvig, 2015). These tests, or rules, are automatically generated, “learning” the relationship between attributes and outcomes. By definition, this means that a decision tree is a classifier.
#
# Naïve-Bayes is another comparably simple classifier, where all of the attributes are assumed to be mutually independent, which simplifies the application of Bayes’ theorem by expressing a joint probability model as a product of probabilities (Cuevas, 2020).
#
# Nearest neighbors methods use known observations in the training set closest in input space to a sample $x$ to classify said sample by "closeness". Specifically, the k-nearest teighbor for for a given class $Y$ is defined as follows:
#
# \begin{align}
#         Y &= \frac{1}{k} \sum_{x_i \in N_k(x)}yi
# \end{align}
#
# where $N_k(x)$ is the neighborhood of x defined by the k-closest points $x_i$ in the training set. Closeness implies a metric, e.g., euclidean distance. Basically, the $k$ observations with $x_i$ closest to $x$ in the input space are chosen, and the final classification is based on the average of their responses (Hastie et al., 2008).
#
# Support vector machines (SVMs) perform classification using a hyperplane that separates the points based on class. Given how there could be multiple such hyperplanes. SVMs find the optimal hyperplane by maximizing the margin (which maximizes the distance between it and the nearest data point of each class, which are then called support vectors). SVMs can be generalized to work with non-linear problems using the kernel trick (Gunn, 1998).
#
# Deep Neural Networks (DNN) are used as an umbrella term, but a general definition is that of a feed-forward, artificial neural network that has more than one layer of hidden units between its inputs and its outputs. Each hidden unit, $j$, typically uses the logistic function to map its total input from the layer below, $x_j$, to the scalar state, $y_j$ that it sends to the layer above (Hinton et al., 2012).
#
# In this course, the term mainly refers to Deep Belief Networks (DBN) and their building blocks, Restricted Boltzmann Machines (RBM) (Cuevas et al., 2016). RBMs are undirected probabilistic graphical models containing a layer of observable variables and a single layer of latent (hidden) variables. A RBM is a bipartite graph itself, with no connections between units in the same layer allowed (Goodfellow et al., 2016). RBMs can be trained with a lot of techniques, such as Gibbs sampling, but the most common method by far is Hinton’s Contrastive Divergence (CD) algorithm.
#
# RBMs may be stacked (with the outputs of the current model being used as the inputs for the next) to form deeper models. Deep Belief Networks were one of the first models to do so. DBN are generative models with several layers of hidden units, where each of the RBMs that compose the model receives features from and generates features for their adjacent units. In this basic form, DBN may perform unsupervised learning, but one could perform classification (supervised learning) tasks using a hybrid model that adds a labeled output layer, taking the weights from the DBN and defining a multi-layered perceptron (MLP), performing fine-tuning. DBN sparked the deep learning revolution after being reintroduced by Hinton et al. (2006).
#
# DBNs could be described as DNNs with unsupervised pretraining (stacked restricted Boltzmann machines trained with contrastive divergence), whose weights are then fine-tuned with a regular backpropagation supervised learning approach (classification). For purposes of this notebook, a regular feed-forward architecture will be used.
#
# Convolutional networks (LeCun, 1989), also known as
# convolutional neural networks (CNNs) are a specialized kind of neural network for processing data that has a known grid-like topology. The name “convolutional neural network” indicates that the network employs a linear operation called
# convolution. (Goodfellow et al., 2016)
#
# Convolutional networks are simply neural networks that use convolution in place of general matrix multiplication in at least one of their layers. For this notebook, which uses two tabular datasets, a simple network with a 1-dimensional convolutional layer and a 1-dimensional pooling layer is used.

# %% [markdown]
# ## **Methodology**
#
# In order to evaluate and compare the performance of said classifiers, two datasets will be employed: the Iris dataset and the Wine dataset from the UC Irvine Machine Learning
# Repository.
#
# Each of the algorithms will be tested twice for each of the datasets, with the first training
# session being done using a 50/50 testing split and the second session with an 80/20 training split. The performance will be measured through the confusion matrix and the accuracy of each run. To ensure reproducible outputs, a seed is defined for the splitting process.

# %%
seed = 8

class Classifier:

    def __init__(self, name, accuracy, confusion_matrix, report):

        self.name = name
        self.accuracy = accuracy
        self.confusion_matrix = confusion_matrix
        self.report = report


# for SVMs

class MidpointNormalize(Normalize):
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        x, y = [self.vmin, self.midpoint, self.vmax], [0, 0.5, 1]
        return np.ma.masked_array(np.interp(value, x, y))

# %% [markdown]
# ## **Iris Dataset**
#
# The Iris dataset (1988) refers to different features of iris plants. The data set contains 3 classes of 50 instances each (150 instances total), where each class refers to a type of iris plant.

# %%
iris = fetch_ucirepo(id=53)

# data (as pandas dataframes)
X = iris.data.features
y = iris.data.targets

# %%
# metadata
iris.metadata
# Out:
# {'uci_id': 53,
#  'name': 'Iris',
#  'repository_url': 'https://archive.ics.uci.edu/dataset/53/iris',
#  'data_url': 'https://archive.ics.uci.edu/static/public/53/data.csv',
#  'abstract': 'A small classic dataset from Fisher, 1936. One of the earliest known datasets used for evaluating classification methods.\n',
#  'area': 'Biology',
#  'tasks': ['Classification'],
#  'characteristics': ['Tabular'],
#  'num_instances': 150,
#  'num_features': 4,
#  'feature_types': ['Real'],
#  'demographics': [],
#  'target_col': ['class'],
#  'index_col': None,
#  'has_missing_values': 'no',
#  'missing_values_symbol': None,
#  'year_of_dataset_creation': 1936,
#  'last_updated': 'Tue Sep 12 2023',
#  'dataset_doi': '10.24432/C56C76',
#  'creators': ['R. A. Fisher'],
#  'intro_paper': {'title': 'The Iris data set: In search of the source of virginica',
#   'authors': 'A. Unwin, K. Kleinman',
#   'published_in': 'Significance, 2021',
#   'year': 2021,
#   'url': 'https://www.semanticscholar.org/paper/4599862ea877863669a6a8e63a3c707a787d5d7e',
#   'doi': '1740-9713.01589'},
#  'additional_info': {'summary': 'This is one of the earliest datasets used in the literature on classification methods and widely used in statistics and machine learning.  The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are not linearly separable from each other.\n\nPredicted attribute: class of iris plant.\n\nThis is an exceedingly simple domain.\n\nThis data differs from the data presented in Fishers article (identified by Steve Chadwick,  spchadwick@espeedaz.net ).  The 35th sample should be: 4.9,3.1,1.5,0.2,"Iris-setosa" where the error is in the fourth feature. The 38th sample: 4.9,3.6,1.4,0.1,"Iris-setosa" where the errors are in the second and third features.  ',
#   'purpose': 'N/A',
#   'funded_by': None,
#   'instances_represent': 'Each instance is a plant',
#   'recommended_data_splits': None,
#   'sensitive_data': None,
#   'preprocessing_description': None,
#   'variable_info': None,
#   'citation': None}}

# %%
# variable information
iris.variables
# Out:
#            name     role         type demographic  \
# 0  sepal length  Feature   Continuous        None
# 1   sepal width  Feature   Continuous        None
# 2  petal length  Feature   Continuous        None
# 3   petal width  Feature   Continuous        None
# 4         class   Target  Categorical        None
#
#                                          description units missing_values
# 0                                               None    cm             no
# 1                                               None    cm             no
# 2                                               None    cm             no
# 3                                               None    cm             no
# 4  class of iris plant: Iris Setosa, Iris Versico...  None             no

# %%
X
# Out:
#      sepal length  sepal width  petal length  petal width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 1 columns]

# %%
x_train50, x_test50, y_train50, y_test50 = train_test_split(X, y, test_size = 0.5, random_state = seed)
x_train80, x_test20, y_train80, y_test20 = train_test_split(X, y, test_size = 0.2, random_state = seed)

# %% [markdown]
# ### Decision Tree

# %% [markdown]
# **50 / 50 split**

# %%
model = tree.DecisionTreeClassifier()

model.fit(x_train50, y_train50.to_numpy().ravel())

model_pred = model.predict(x_test50)

print(confusion_matrix(y_test50, model_pred))
print(classification_report(y_test50, model_pred))

tree.plot_tree(model, feature_names = iris.data.headers, class_names = np.unique(y))

iris_tree_5050 = Classifier('Decision Tree 50/50', accuracy_score(y_test50, model_pred), confusion_matrix(y_test50, model_pred), classification_report(y_test50, model_pred))
# Out:
# [[26  0  0]
#  [ 0 23  2]
#  [ 0  2 22]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        26
# Iris-versicolor       0.92      0.92      0.92        25
#  Iris-virginica       0.92      0.92      0.92        24
#
#        accuracy                           0.95        75
#       macro avg       0.95      0.95      0.95        75
#    weighted avg       0.95      0.95      0.95        75

# %% [markdown]
# **80 / 20 split**

# %%
model = tree.DecisionTreeClassifier()

model.fit(x_train80, y_train80.to_numpy().ravel())

model_pred = model.predict(x_test20)

print(confusion_matrix(y_test20, model_pred))
print(classification_report(y_test20, model_pred))

tree.plot_tree(model, feature_names = iris.data.headers, class_names = np.unique(y))

iris_tree_8020 = Classifier('Decision Tree 80/20', accuracy_score(y_test20, model_pred), confusion_matrix(y_test20, model_pred), classification_report(y_test20, model_pred))
# Out:
# [[10  0  0]
#  [ 0  8  1]
#  [ 0  3  8]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       0.73      0.89      0.80         9
#  Iris-virginica       0.89      0.73      0.80        11
#
#        accuracy                           0.87        30
#       macro avg       0.87      0.87      0.87        30
#    weighted avg       0.88      0.87      0.87        30

# %% [markdown]
# ### Naive Bayes

# %% [markdown]
# **50 / 50 split**

# %%
model = GaussianNB()

model.fit(x_train50, y_train50.to_numpy().ravel())

model_pred = model.predict(x_test50)

print(confusion_matrix(y_test50, model_pred))
print(classification_report(y_test50, model_pred))

iris_bayes_5050 = Classifier('Naïve-Bayes 50/50', accuracy_score(y_test50, model_pred), confusion_matrix(y_test50, model_pred), classification_report(y_test50, model_pred))
# Out:
# [[26  0  0]
#  [ 0 22  3]
#  [ 0  3 21]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        26
# Iris-versicolor       0.88      0.88      0.88        25
#  Iris-virginica       0.88      0.88      0.88        24
#
#        accuracy                           0.92        75
#       macro avg       0.92      0.92      0.92        75
#    weighted avg       0.92      0.92      0.92        75

# %% [markdown]
# **80 / 20 split**

# %%
model = GaussianNB()

model.fit(x_train80, y_train80.to_numpy().ravel())

model_pred = model.predict(x_test20)

print(confusion_matrix(y_test20, model_pred))
print(classification_report(y_test20, model_pred))

iris_bayes_8020 = Classifier('Naïve-Bayes 80/20', accuracy_score(y_test20, model_pred), confusion_matrix(y_test20, model_pred), classification_report(y_test20, model_pred))
# Out:
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  2  9]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       0.78      0.78      0.78         9
#  Iris-virginica       0.82      0.82      0.82        11
#
#        accuracy                           0.87        30
#       macro avg       0.87      0.87      0.87        30
#    weighted avg       0.87      0.87      0.87        30

# %% [markdown]
# ### K-nearest neighbors

# %% [markdown]
# **Visualization**

# %%
# taken from https://scikit-learn.org/stable/auto_examples/neighbors/plot_classification.html#sphx-glr-auto-examples-neighbors-plot-classification-py

x_trainvis = x_train50[['sepal length', 'sepal width']]
y_trainvis = y_train50

x_testvis = x_test50[['sepal length', 'sepal width']]
y_testvis = y_test50

label_encoder = LabelEncoder()
colors = label_encoder.fit_transform(y)

iris_knearest_vis = Pipeline(
    steps=[("scaler", StandardScaler()), ("knn", KNeighborsClassifier(n_neighbors=11))]
)

_, axs = plt.subplots(ncols=2, figsize=(12, 5))

for ax, weights in zip(axs, ("uniform", "distance")):
    iris_knearest_vis.set_params(knn__weights=weights).fit(x_trainvis, y_trainvis.to_numpy().ravel())
    disp = DecisionBoundaryDisplay.from_estimator(
        iris_knearest_vis,
        x_testvis,
        response_method="predict",
        plot_method="pcolormesh",
        xlabel="sepal length (cm)",
        ylabel="sepal width (cm)",
        shading="auto",
        alpha=0.5,
        ax=ax,
    )
    scatter = disp.ax_.scatter(X.iloc[:, 0], X.iloc[:, 1], c=colors, edgecolors="k")
    disp.ax_.legend(
        scatter.legend_elements()[0],
        np.unique(y),
        loc="lower left",
        title="Classes",
    )
    _ = disp.ax_.set_title(
        f"3-Class classification\n(k={iris_knearest_vis[-1].n_neighbors}, weights={weights!r})"
    )

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# **50/50 Split**

# %%
model_pred = None
best_accuracy = -1
best_k = 0

for k in range(1, len(x_test50)):

    k_model = Pipeline(
        steps=[("scaler", StandardScaler()), ('knn', KNeighborsClassifier(k, weights = 'distance'))]
        # steps=[('knn', KNeighborsClassifier(k, weights = 'distance'))]
    )

    k_model.fit(x_train50, y_train50.to_numpy().ravel())

    k_model_pred = k_model.predict(x_test50)

    k_accuracy = accuracy_score(y_test50, k_model_pred)

    # print(f'> k({k}) accuracy: {k_accuracy}')

    if best_accuracy < k_accuracy:
        best_accuracy = k_accuracy
        model_pred = k_model_pred
        best_k = k

print()
print(f'> best k: {best_k}')
print(confusion_matrix(y_test50, model_pred))
print(classification_report(y_test50, model_pred))

iris_k_neighbors_5050 = Classifier(f'k({best_k})-neighbors 50/50', accuracy_score(y_test50, model_pred), confusion_matrix(y_test50, model_pred), classification_report(y_test50, model_pred))
# Out:
# > best k: 1
# [[25  1  0]
#  [ 0 25  0]
#  [ 0  3 21]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      0.96      0.98        26
# Iris-versicolor       0.86      1.00      0.93        25
#  Iris-virginica       1.00      0.88      0.93        24
#
#        accuracy                           0.95        75
#       macro avg       0.95      0.95      0.95        75
#    weighted avg       0.95      0.95      0.95        75

# %% [markdown]
# **80/20 Split**

# %%
model_pred = None
best_accuracy = -1
best_k = 0

for k in range(1, len(x_test20)):

    k_model = Pipeline(
        steps=[("scaler", StandardScaler()), ('knn', KNeighborsClassifier(k, weights = 'distance'))]
        # steps=[('knn', KNeighborsClassifier(k, weights = 'distance'))]
    )

    k_model.fit(x_train80, y_train80.to_numpy().ravel())

    k_model_pred = k_model.predict(x_test20)

    k_accuracy = accuracy_score(y_test20, k_model_pred)

    # print(f'> k({k}) accuracy: {k_accuracy}')

    if best_accuracy < k_accuracy:
        best_accuracy = k_accuracy
        model_pred = k_model_pred
        best_k = k

print()
print(f'> best k: {best_k}')
print(confusion_matrix(y_test20, model_pred))
print(classification_report(y_test20, model_pred))

iris_k_neighbors_8020 = Classifier(f'k({best_k})-neighbors 80/20', accuracy_score(y_test20, model_pred), confusion_matrix(y_test20, model_pred), classification_report(y_test20, model_pred))
# Out:
# > best k: 5
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  2  9]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       0.82      1.00      0.90         9
#  Iris-virginica       1.00      0.82      0.90        11
#
#        accuracy                           0.93        30
#       macro avg       0.94      0.94      0.93        30
#    weighted avg       0.95      0.93      0.93        30

# %% [markdown]
# ### SVM (Linear kernel)

# %% [markdown]
# **50/50 Split**

# %%
model = svm.SVC(kernel = 'linear', C = 1.0)

model.fit(x_train50, y_train50.to_numpy().ravel())

model_pred = model.predict(x_test50)

print(confusion_matrix(y_test50, model_pred))
print(classification_report(y_test50, model_pred))

iris_SVM_linear_5050 = Classifier('SVM (linear) 50/50', accuracy_score(y_test50, model_pred), confusion_matrix(y_test50, model_pred), classification_report(y_test50, model_pred))
# Out:
# [[26  0  0]
#  [ 0 24  1]
#  [ 0  3 21]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        26
# Iris-versicolor       0.89      0.96      0.92        25
#  Iris-virginica       0.95      0.88      0.91        24
#
#        accuracy                           0.95        75
#       macro avg       0.95      0.94      0.95        75
#    weighted avg       0.95      0.95      0.95        75

# %% [markdown]
# **80/20 Split**

# %%
model = svm.SVC(kernel = 'linear', C = 1.0)

model.fit(x_train80, y_train80.to_numpy().ravel())

model_pred = model.predict(x_test20)

print(confusion_matrix(y_test20, model_pred))
print(classification_report(y_test20, model_pred))

iris_SVM_linear_8020 = Classifier('SVM (linear) 80/20', accuracy_score(y_test20, model_pred), confusion_matrix(y_test20, model_pred), classification_report(y_test20, model_pred))
# Out:
# [[10  0  0]
#  [ 0  8  1]
#  [ 0  1 10]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       0.89      0.89      0.89         9
#  Iris-virginica       0.91      0.91      0.91        11
#
#        accuracy                           0.93        30
#       macro avg       0.93      0.93      0.93        30
#    weighted avg       0.93      0.93      0.93        30

# %% [markdown]
# ### SVM (rbf kernel)

# %% [markdown]
# **50/50 split**

# %%
C_range = np.logspace(-2, 10, 13)
gamma_range = np.logspace(-9, 3, 13)
param_grid = dict(gamma=gamma_range, C=C_range)
cv = StratifiedShuffleSplit(n_splits = 5, test_size = 0.5, random_state = seed)
grid = GridSearchCV(svm.SVC(), param_grid=param_grid, cv=cv)
grid.fit(X, y.to_numpy().ravel())

best_C = grid.best_params_['C']
best_gamma = grid.best_params_['gamma']

print(f'best params c:{best_C}, gamma: {best_gamma}')

model = svm.SVC(C = best_C, gamma = best_gamma)

model.fit(x_train50, y_train50.to_numpy().ravel())

model_pred = model.predict(x_test50)

print(confusion_matrix(y_test50, model_pred))
print(classification_report(y_test50, model_pred))

iris_SVM_rbf_5050 = Classifier('SVM (rbf) 50/50', accuracy_score(y_test50, model_pred), confusion_matrix(y_test50, model_pred), classification_report(y_test50, model_pred))
# Out:
# best params c:1.0, gamma: 1.0
# [[26  0  0]
#  [ 0 23  2]
#  [ 0  2 22]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        26
# Iris-versicolor       0.92      0.92      0.92        25
#  Iris-virginica       0.92      0.92      0.92        24
#
#        accuracy                           0.95        75
#       macro avg       0.95      0.95      0.95        75
#    weighted avg       0.95      0.95      0.95        75

# %%
scores = grid.cv_results_["mean_test_score"].reshape(len(C_range), len(gamma_range))

plt.figure(figsize=(8, 6))
plt.subplots_adjust(left=0.2, right=0.95, bottom=0.15, top=0.95)
plt.imshow(
    scores,
    interpolation="nearest",
    cmap=plt.cm.hot,
    norm=MidpointNormalize(vmin=0.2, midpoint=0.92),
)
plt.xlabel("gamma")
plt.ylabel("C")
plt.colorbar()
plt.xticks(np.arange(len(gamma_range)), gamma_range, rotation=45)
plt.yticks(np.arange(len(C_range)), C_range)
plt.title("Validation accuracy")
plt.show()

# %% [markdown]
# **80/20 Split**

# %%
C_range = np.logspace(-2, 10, 13)
gamma_range = np.logspace(-9, 3, 13)
param_grid = dict(gamma=gamma_range, C=C_range)
cv = StratifiedShuffleSplit(n_splits = 5, test_size = 0.2, random_state = seed)
grid = GridSearchCV(svm.SVC(), param_grid=param_grid, cv=cv)
grid.fit(X, y.to_numpy().ravel())

best_C = grid.best_params_['C']
best_gamma = grid.best_params_['gamma']

print(f'best params c:{best_C}, gamma: {best_gamma}')

model = svm.SVC(C = best_C, gamma = best_gamma)

model.fit(x_train50, y_train50.to_numpy().ravel())

model_pred = model.predict(x_test50)

print(confusion_matrix(y_test50, model_pred))
print(classification_report(y_test50, model_pred))

iris_SVM_rbf_8020 = Classifier('SVM (rbf) 80/20', accuracy_score(y_test50, model_pred), confusion_matrix(y_test50, model_pred), classification_report(y_test50, model_pred))
# Out:
# best params c:100.0, gamma: 0.01
# [[26  0  0]
#  [ 0 23  2]
#  [ 0  2 22]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        26
# Iris-versicolor       0.92      0.92      0.92        25
#  Iris-virginica       0.92      0.92      0.92        24
#
#        accuracy                           0.95        75
#       macro avg       0.95      0.95      0.95        75
#    weighted avg       0.95      0.95      0.95        75

# %%
scores = grid.cv_results_["mean_test_score"].reshape(len(C_range), len(gamma_range))

plt.figure(figsize=(8, 6))
plt.subplots_adjust(left=0.2, right=0.95, bottom=0.15, top=0.95)
plt.imshow(
    scores,
    interpolation="nearest",
    cmap=plt.cm.hot,
    norm=MidpointNormalize(vmin=0.2, midpoint=0.92),
)
plt.xlabel("gamma")
plt.ylabel("C")
plt.colorbar()
plt.xticks(np.arange(len(gamma_range)), gamma_range, rotation=45)
plt.yticks(np.arange(len(C_range)), C_range)
plt.title("Validation accuracy")
plt.show()

# %% [markdown]
# ### DNN

# %%
input_size = X.shape[1]
output_size = 3

#preprocessing
label_encoder = LabelEncoder()
scaler = StandardScaler()

# %% [markdown]
# **50/50 Split**

# %%
# preprocessing
y_train50_ord = label_encoder.fit_transform(y_train50) # can't use string as before -> assign unique integer to each class
y_test50_ord = label_encoder.fit_transform(y_test50)
x_train50_scaled = scaler.fit_transform(x_train50) # scale data to unit variance -> better results
x_test50_scaled = scaler.fit_transform(x_test50)

# define model

model = Sequential([
    Dense(64, activation='relu', input_shape=(input_size,)),
    Dense(64, activation='relu'),
    Dense(output_size, activation='softmax')
])

model.summary()

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# training and testing

model.fit(x_train50_scaled, y_train50_ord, epochs=200, batch_size=64, verbose=2)

print()
print('Classification results:')

loss, accuracy = model.evaluate(x_test50_scaled, y_test50_ord, verbose=2)

model_pred = model.predict(x_test50_scaled)

# print(model_pred)

model_pred_classes = np.argmax(model_pred, axis=1)

print(confusion_matrix(y_test50_ord, model_pred_classes))
print(classification_report(y_test50_ord, model_pred_classes))

iris_DNN_5050 = Classifier('DNN [in 64 64 out]', accuracy, confusion_matrix(y_test50_ord, model_pred_classes), classification_report(y_test50_ord, model_pred_classes))
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_16 (Dense)            (None, 64)                320
#
#  dense_17 (Dense)            (None, 64)                4160
#
#  dense_18 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 4675 (18.26 KB)
# Trainable params: 4675 (18.26 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Epoch 1/200
# 2/2 - 2s - loss: 1.1210 - accuracy: 0.2400 - 2s/epoch - 859ms/step
# Epoch 2/200
# 2/2 - 0s - loss: 1.0487 - accuracy: 0.4000 - 17ms/epoch - 8ms/step
# Epoch 3/200
# 2/2 - 0s - loss: 0.9818 - accuracy: 0.6400 - 35ms/epoch - 18ms/step
# Epoch 4/200
# 2/2 - 0s - loss: 0.9187 - accuracy: 0.7867 - 17ms/epoch - 8ms/step
# Epoch 5/200
# 2/2 - 0s - loss: 0.8616 - accuracy: 0.8133 - 20ms/epoch - 10ms/step
# Epoch 6/200
# 2/2 - 0s - loss: 0.8097 - accuracy: 0.8133 - 45ms/epoch - 23ms/step
# Epoch 7/200
# 2/2 - 0s - loss: 0.7598 - accuracy: 0.8267 - 29ms/epoch - 15ms/step
# Epoch 8/200
# 2/2 - 0s - loss: 0.7147 - accuracy: 0.8267 - 22ms/epoch - 11ms/step
# Epoch 9/200
# 2/2 - 0s - loss: 0.6741 - accuracy: 0.8267 - 30ms/epoch - 15ms/step
# Epoch 10/200
# 2/2 - 0s - loss: 0.6356 - accuracy: 0.8400 - 19ms/epoch - 9ms/step
# Epoch 11/200
# 2/2 - 0s - loss: 0.6016 - accuracy: 0.8400 - 20ms/epoch - 10ms/step
# Epoch 12/200
# 2/2 - 0s - loss: 0.5709 - accuracy: 0.8400 - 20ms/epoch - 10ms/step
# Epoch 13/200
# 2/2 - 0s - loss: 0.5420 - accuracy: 0.8400 - 27ms/epoch - 13ms/step
# Epoch 14/200
# 2/2 - 0s - loss: 0.5154 - accuracy: 0.8400 - 19ms/epoch - 9ms/step
# Epoch 15/200
# 2/2 - 0s - loss: 0.4918 - accuracy: 0.8400 - 26ms/epoch - 13ms/step
# Epoch 16/200
# 2/2 - 0s - loss: 0.4699 - accuracy: 0.8400 - 32ms/epoch - 16ms/step
# Epoch 17/200
# 2/2 - 0s - loss: 0.4496 - accuracy: 0.8400 - 21ms/epoch - 10ms/step
# Epoch 18/200
# 2/2 - 0s - loss: 0.4317 - accuracy: 0.8400 - 24ms/epoch - 12ms/step
# Epoch 19/200
# 2/2 - 0s - loss: 0.4145 - accuracy: 0.8400 - 23ms/epoch - 12ms/step
# Epoch 20/200
# 2/2 - 0s - loss: 0.3996 - accuracy: 0.8400 - 22ms/epoch - 11ms/step
# Epoch 21/200
# 2/2 - 0s - loss: 0.3847 - accuracy: 0.8400 - 33ms/epoch - 17ms/step
# Epoch 22/200
# 2/2 - 0s - loss: 0.3716 - accuracy: 0.8533 - 38ms/epoch - 19ms/step
# Epoch 23/200
# 2/2 - 0s - loss: 0.3591 - accuracy: 0.8667 - 30ms/epoch - 15ms/step
# Epoch 24/200
# 2/2 - 0s - loss: 0.3477 - accuracy: 0.8800 - 23ms/epoch - 11ms/step
# Epoch 25/200
# 2/2 - 0s - loss: 0.3366 - accuracy: 0.8800 - 23ms/epoch - 11ms/step
# Epoch 26/200
# 2/2 - 0s - loss: 0.3259 - accuracy: 0.8800 - 26ms/epoch - 13ms/step
# Epoch 27/200
# 2/2 - 0s - loss: 0.3167 - accuracy: 0.8800 - 26ms/epoch - 13ms/step
# Epoch 28/200
# 2/2 - 0s - loss: 0.3077 - accuracy: 0.8800 - 33ms/epoch - 17ms/step
# Epoch 29/200
# 2/2 - 0s - loss: 0.2996 - accuracy: 0.8933 - 65ms/epoch - 32ms/step
# Epoch 30/200
# 2/2 - 0s - loss: 0.2918 - accuracy: 0.8933 - 28ms/epoch - 14ms/step
# Epoch 31/200
# 2/2 - 0s - loss: 0.2843 - accuracy: 0.8933 - 27ms/epoch - 14ms/step
# Epoch 32/200
# 2/2 - 0s - loss: 0.2773 - accuracy: 0.8933 - 28ms/epoch - 14ms/step
# Epoch 33/200
# 2/2 - 0s - loss: 0.2708 - accuracy: 0.8933 - 23ms/epoch - 12ms/step
# Epoch 34/200
# 2/2 - 0s - loss: 0.2642 - accuracy: 0.8933 - 27ms/epoch - 14ms/step
# Epoch 35/200
# 2/2 - 0s - loss: 0.2586 - accuracy: 0.8933 - 31ms/epoch - 15ms/step
# Epoch 36/200
# 2/2 - 0s - loss: 0.2523 - accuracy: 0.8933 - 32ms/epoch - 16ms/step
# Epoch 37/200
# 2/2 - 0s - loss: 0.2470 - accuracy: 0.8933 - 31ms/epoch - 15ms/step
# Epoch 38/200
# 2/2 - 0s - loss: 0.2422 - accuracy: 0.8933 - 20ms/epoch - 10ms/step
# Epoch 39/200
# 2/2 - 0s - loss: 0.2372 - accuracy: 0.8933 - 22ms/epoch - 11ms/step
# Epoch 40/200
# 2/2 - 0s - loss: 0.2326 - accuracy: 0.8933 - 32ms/epoch - 16ms/step
# Epoch 41/200
# 2/2 - 0s - loss: 0.2276 - accuracy: 0.8933 - 28ms/epoch - 14ms/step
# Epoch 42/200
# 2/2 - 0s - loss: 0.2232 - accuracy: 0.9067 - 20ms/epoch - 10ms/step
# Epoch 43/200
# 2/2 - 0s - loss: 0.2183 - accuracy: 0.9067 - 23ms/epoch - 12ms/step
# Epoch 44/200
# 2/2 - 0s - loss: 0.2137 - accuracy: 0.9067 - 39ms/epoch - 20ms/step
# Epoch 45/200
# 2/2 - 0s - loss: 0.2092 - accuracy: 0.9200 - 33ms/epoch - 16ms/step
# Epoch 46/200
# 2/2 - 0s - loss: 0.2047 - accuracy: 0.9333 - 32ms/epoch - 16ms/step
# Epoch 47/200
# 2/2 - 0s - loss: 0.2002 - accuracy: 0.9333 - 21ms/epoch - 10ms/step
# Epoch 48/200
# 2/2 - 0s - loss: 0.1963 - accuracy: 0.9467 - 31ms/epoch - 15ms/step
# Epoch 49/200
# 2/2 - 0s - loss: 0.1937 - accuracy: 0.9600 - 26ms/epoch - 13ms/step
# Epoch 50/200
# 2/2 - 0s - loss: 0.1896 - accuracy: 0.9600 - 24ms/epoch - 12ms/step
# Epoch 51/200
# 2/2 - 0s - loss: 0.1852 - accuracy: 0.9600 - 30ms/epoch - 15ms/step
# Epoch 52/200
# 2/2 - 0s - loss: 0.1809 - accuracy: 0.9733 - 25ms/epoch - 13ms/step
# Epoch 53/200
# 2/2 - 0s - loss: 0.1777 - accuracy: 0.9733 - 28ms/epoch - 14ms/step
# Epoch 54/200
# 2/2 - 0s - loss: 0.1749 - accuracy: 0.9467 - 34ms/epoch - 17ms/step
# Epoch 55/200
# 2/2 - 0s - loss: 0.1720 - accuracy: 0.9333 - 30ms/epoch - 15ms/step
# Epoch 56/200
# 2/2 - 0s - loss: 0.1688 - accuracy: 0.9467 - 47ms/epoch - 24ms/step
# Epoch 57/200
# 2/2 - 0s - loss: 0.1649 - accuracy: 0.9467 - 41ms/epoch - 21ms/step
# Epoch 58/200
# 2/2 - 0s - loss: 0.1617 - accuracy: 0.9467 - 24ms/epoch - 12ms/step
# Epoch 59/200
# 2/2 - 0s - loss: 0.1586 - accuracy: 0.9467 - 24ms/epoch - 12ms/step
# Epoch 60/200
# 2/2 - 0s - loss: 0.1550 - accuracy: 0.9600 - 23ms/epoch - 12ms/step
# Epoch 61/200
# 2/2 - 0s - loss: 0.1510 - accuracy: 0.9733 - 22ms/epoch - 11ms/step
# Epoch 62/200
# 2/2 - 0s - loss: 0.1481 - accuracy: 0.9733 - 29ms/epoch - 15ms/step
# Epoch 63/200
# 2/2 - 0s - loss: 0.1452 - accuracy: 0.9733 - 20ms/epoch - 10ms/step
# Epoch 64/200
# 2/2 - 0s - loss: 0.1427 - accuracy: 0.9733 - 18ms/epoch - 9ms/step
# Epoch 65/200
# 2/2 - 0s - loss: 0.1402 - accuracy: 0.9733 - 29ms/epoch - 15ms/step
# Epoch 66/200
# 2/2 - 0s - loss: 0.1379 - accuracy: 0.9600 - 17ms/epoch - 9ms/step
# Epoch 67/200
# 2/2 - 0s - loss: 0.1358 - accuracy: 0.9600 - 18ms/epoch - 9ms/step
# Epoch 68/200
# 2/2 - 0s - loss: 0.1332 - accuracy: 0.9600 - 20ms/epoch - 10ms/step
# Epoch 69/200
# 2/2 - 0s - loss: 0.1301 - accuracy: 0.9600 - 19ms/epoch - 10ms/step
# Epoch 70/200
# 2/2 - 0s - loss: 0.1273 - accuracy: 0.9600 - 18ms/epoch - 9ms/step
# Epoch 71/200
# 2/2 - 0s - loss: 0.1247 - accuracy: 0.9733 - 19ms/epoch - 10ms/step
# Epoch 72/200
# 2/2 - 0s - loss: 0.1217 - accuracy: 0.9733 - 15ms/epoch - 8ms/step
# Epoch 73/200
# 2/2 - 0s - loss: 0.1191 - accuracy: 0.9733 - 15ms/epoch - 7ms/step
# Epoch 74/200
# 2/2 - 0s - loss: 0.1170 - accuracy: 0.9733 - 12ms/epoch - 6ms/step
# Epoch 75/200
# 2/2 - 0s - loss: 0.1151 - accuracy: 0.9600 - 20ms/epoch - 10ms/step
# Epoch 76/200
# 2/2 - 0s - loss: 0.1130 - accuracy: 0.9733 - 22ms/epoch - 11ms/step
# Epoch 77/200
# 2/2 - 0s - loss: 0.1102 - accuracy: 0.9733 - 39ms/epoch - 19ms/step
# Epoch 78/200
# 2/2 - 0s - loss: 0.1077 - accuracy: 0.9867 - 29ms/epoch - 15ms/step
# Epoch 79/200
# 2/2 - 0s - loss: 0.1050 - accuracy: 0.9867 - 25ms/epoch - 12ms/step
# Epoch 80/200
# 2/2 - 0s - loss: 0.1025 - accuracy: 0.9867 - 14ms/epoch - 7ms/step
# Epoch 81/200
# 2/2 - 0s - loss: 0.1003 - accuracy: 0.9867 - 13ms/epoch - 7ms/step
# Epoch 82/200
# 2/2 - 0s - loss: 0.0980 - accuracy: 0.9867 - 15ms/epoch - 7ms/step
# Epoch 83/200
# 2/2 - 0s - loss: 0.0959 - accuracy: 0.9867 - 25ms/epoch - 13ms/step
# Epoch 84/200
# 2/2 - 0s - loss: 0.0936 - accuracy: 0.9867 - 28ms/epoch - 14ms/step
# Epoch 85/200
# 2/2 - 0s - loss: 0.0914 - accuracy: 0.9867 - 13ms/epoch - 6ms/step
# Epoch 86/200
# 2/2 - 0s - loss: 0.0894 - accuracy: 0.9867 - 34ms/epoch - 17ms/step
# Epoch 87/200
# 2/2 - 0s - loss: 0.0874 - accuracy: 0.9867 - 29ms/epoch - 15ms/step
# Epoch 88/200
# 2/2 - 0s - loss: 0.0858 - accuracy: 0.9867 - 24ms/epoch - 12ms/step
# Epoch 89/200
# 2/2 - 0s - loss: 0.0846 - accuracy: 0.9733 - 26ms/epoch - 13ms/step
# Epoch 90/200
# 2/2 - 0s - loss: 0.0831 - accuracy: 0.9733 - 26ms/epoch - 13ms/step
# Epoch 91/200
# 2/2 - 0s - loss: 0.0810 - accuracy: 0.9867 - 34ms/epoch - 17ms/step
# Epoch 92/200
# 2/2 - 0s - loss: 0.0792 - accuracy: 1.0000 - 11ms/epoch - 5ms/step
# Epoch 93/200
# 2/2 - 0s - loss: 0.0770 - accuracy: 0.9867 - 10ms/epoch - 5ms/step
# Epoch 94/200
# 2/2 - 0s - loss: 0.0758 - accuracy: 0.9867 - 12ms/epoch - 6ms/step
# Epoch 95/200
# 2/2 - 0s - loss: 0.0740 - accuracy: 0.9867 - 33ms/epoch - 16ms/step
# Epoch 96/200
# 2/2 - 0s - loss: 0.0725 - accuracy: 0.9867 - 30ms/epoch - 15ms/step
# Epoch 97/200
# 2/2 - 0s - loss: 0.0712 - accuracy: 0.9867 - 21ms/epoch - 11ms/step
# Epoch 98/200
# 2/2 - 0s - loss: 0.0698 - accuracy: 0.9867 - 23ms/epoch - 12ms/step
# Epoch 99/200
# 2/2 - 0s - loss: 0.0687 - accuracy: 0.9867 - 20ms/epoch - 10ms/step
# Epoch 100/200
# 2/2 - 0s - loss: 0.0667 - accuracy: 0.9867 - 20ms/epoch - 10ms/step
# Epoch 101/200
# 2/2 - 0s - loss: 0.0652 - accuracy: 0.9867 - 22ms/epoch - 11ms/step
# Epoch 102/200
# 2/2 - 0s - loss: 0.0649 - accuracy: 0.9867 - 32ms/epoch - 16ms/step
# Epoch 103/200
# 2/2 - 0s - loss: 0.0651 - accuracy: 0.9867 - 27ms/epoch - 13ms/step
# Epoch 104/200
# 2/2 - 0s - loss: 0.0663 - accuracy: 0.9867 - 29ms/epoch - 15ms/step
# Epoch 105/200
# 2/2 - 0s - loss: 0.0664 - accuracy: 0.9867 - 30ms/epoch - 15ms/step
# Epoch 106/200
# 2/2 - 0s - loss: 0.0656 - accuracy: 0.9867 - 30ms/epoch - 15ms/step
# Epoch 107/200
# 2/2 - 0s - loss: 0.0639 - accuracy: 0.9867 - 29ms/epoch - 14ms/step
# Epoch 108/200
# 2/2 - 0s - loss: 0.0615 - accuracy: 0.9867 - 16ms/epoch - 8ms/step
# Epoch 109/200
# 2/2 - 0s - loss: 0.0585 - accuracy: 0.9867 - 35ms/epoch - 18ms/step
# Epoch 110/200
# 2/2 - 0s - loss: 0.0562 - accuracy: 1.0000 - 35ms/epoch - 18ms/step
# Epoch 111/200
# 2/2 - 0s - loss: 0.0559 - accuracy: 0.9867 - 26ms/epoch - 13ms/step
# Epoch 112/200
# 2/2 - 0s - loss: 0.0564 - accuracy: 0.9867 - 28ms/epoch - 14ms/step
# Epoch 113/200
# 2/2 - 0s - loss: 0.0567 - accuracy: 0.9867 - 34ms/epoch - 17ms/step
# Epoch 114/200
# 2/2 - 0s - loss: 0.0568 - accuracy: 0.9867 - 42ms/epoch - 21ms/step
# Epoch 115/200
# 2/2 - 0s - loss: 0.0566 - accuracy: 0.9867 - 41ms/epoch - 21ms/step
# Epoch 116/200
# 2/2 - 0s - loss: 0.0557 - accuracy: 0.9867 - 24ms/epoch - 12ms/step
# Epoch 117/200
# 2/2 - 0s - loss: 0.0545 - accuracy: 0.9867 - 32ms/epoch - 16ms/step
# Epoch 118/200
# 2/2 - 0s - loss: 0.0525 - accuracy: 0.9867 - 52ms/epoch - 26ms/step
# Epoch 119/200
# 2/2 - 0s - loss: 0.0505 - accuracy: 0.9867 - 21ms/epoch - 11ms/step
# Epoch 120/200
# 2/2 - 0s - loss: 0.0489 - accuracy: 0.9867 - 48ms/epoch - 24ms/step
# Epoch 121/200
# 2/2 - 0s - loss: 0.0480 - accuracy: 0.9867 - 58ms/epoch - 29ms/step
# Epoch 122/200
# 2/2 - 0s - loss: 0.0478 - accuracy: 0.9867 - 46ms/epoch - 23ms/step
# Epoch 123/200
# 2/2 - 0s - loss: 0.0477 - accuracy: 0.9867 - 30ms/epoch - 15ms/step
# Epoch 124/200
# 2/2 - 0s - loss: 0.0465 - accuracy: 0.9733 - 49ms/epoch - 24ms/step
# Epoch 125/200
# 2/2 - 0s - loss: 0.0462 - accuracy: 0.9867 - 19ms/epoch - 9ms/step
# Epoch 126/200
# 2/2 - 0s - loss: 0.0451 - accuracy: 0.9867 - 35ms/epoch - 18ms/step
# Epoch 127/200
# 2/2 - 0s - loss: 0.0445 - accuracy: 0.9867 - 27ms/epoch - 13ms/step
# Epoch 128/200
# 2/2 - 0s - loss: 0.0439 - accuracy: 0.9867 - 29ms/epoch - 15ms/step
# Epoch 129/200
# 2/2 - 0s - loss: 0.0434 - accuracy: 0.9867 - 43ms/epoch - 22ms/step
# Epoch 130/200
# 2/2 - 0s - loss: 0.0429 - accuracy: 0.9867 - 30ms/epoch - 15ms/step
# Epoch 131/200
# 2/2 - 0s - loss: 0.0424 - accuracy: 0.9867 - 22ms/epoch - 11ms/step
# Epoch 132/200
# 2/2 - 0s - loss: 0.0418 - accuracy: 0.9867 - 29ms/epoch - 14ms/step
# Epoch 133/200
# 2/2 - 0s - loss: 0.0415 - accuracy: 0.9867 - 44ms/epoch - 22ms/step
# Epoch 134/200
# 2/2 - 0s - loss: 0.0409 - accuracy: 0.9867 - 13ms/epoch - 7ms/step
# Epoch 135/200
# 2/2 - 0s - loss: 0.0408 - accuracy: 0.9867 - 42ms/epoch - 21ms/step
# Epoch 136/200
# 2/2 - 0s - loss: 0.0401 - accuracy: 0.9867 - 24ms/epoch - 12ms/step
# Epoch 137/200
# 2/2 - 0s - loss: 0.0395 - accuracy: 0.9867 - 26ms/epoch - 13ms/step
# Epoch 138/200
# 2/2 - 0s - loss: 0.0394 - accuracy: 0.9867 - 16ms/epoch - 8ms/step
# Epoch 139/200
# 2/2 - 0s - loss: 0.0386 - accuracy: 0.9867 - 16ms/epoch - 8ms/step
# Epoch 140/200
# 2/2 - 0s - loss: 0.0383 - accuracy: 0.9867 - 15ms/epoch - 8ms/step
# Epoch 141/200
# 2/2 - 0s - loss: 0.0380 - accuracy: 0.9867 - 18ms/epoch - 9ms/step
# Epoch 142/200
# 2/2 - 0s - loss: 0.0378 - accuracy: 0.9867 - 16ms/epoch - 8ms/step
# Epoch 143/200
# 2/2 - 0s - loss: 0.0374 - accuracy: 0.9867 - 15ms/epoch - 7ms/step
# Epoch 144/200
# 2/2 - 0s - loss: 0.0369 - accuracy: 0.9867 - 14ms/epoch - 7ms/step
# Epoch 145/200
# 2/2 - 0s - loss: 0.0366 - accuracy: 0.9867 - 14ms/epoch - 7ms/step
# Epoch 146/200
# 2/2 - 0s - loss: 0.0350 - accuracy: 0.9867 - 15ms/epoch - 7ms/step
# Epoch 147/200
# 2/2 - 0s - loss: 0.0355 - accuracy: 1.0000 - 26ms/epoch - 13ms/step
# Epoch 148/200
# 2/2 - 0s - loss: 0.0363 - accuracy: 0.9867 - 16ms/epoch - 8ms/step
# Epoch 149/200
# 2/2 - 0s - loss: 0.0380 - accuracy: 0.9867 - 15ms/epoch - 7ms/step
# Epoch 150/200
# 2/2 - 0s - loss: 0.0394 - accuracy: 0.9867 - 13ms/epoch - 7ms/step
# Epoch 151/200
# 2/2 - 0s - loss: 0.0387 - accuracy: 0.9867 - 29ms/epoch - 14ms/step
# Epoch 152/200
# 2/2 - 0s - loss: 0.0364 - accuracy: 0.9867 - 31ms/epoch - 15ms/step
# Epoch 153/200
# 2/2 - 0s - loss: 0.0358 - accuracy: 0.9867 - 24ms/epoch - 12ms/step
# Epoch 154/200
# 2/2 - 0s - loss: 0.0331 - accuracy: 1.0000 - 24ms/epoch - 12ms/step
# Epoch 155/200
# 2/2 - 0s - loss: 0.0326 - accuracy: 1.0000 - 24ms/epoch - 12ms/step
# Epoch 156/200
# 2/2 - 0s - loss: 0.0323 - accuracy: 0.9867 - 14ms/epoch - 7ms/step
# Epoch 157/200
# 2/2 - 0s - loss: 0.0323 - accuracy: 0.9867 - 15ms/epoch - 7ms/step
# Epoch 158/200
# 2/2 - 0s - loss: 0.0324 - accuracy: 0.9867 - 18ms/epoch - 9ms/step
# Epoch 159/200
# 2/2 - 0s - loss: 0.0323 - accuracy: 0.9867 - 13ms/epoch - 7ms/step
# Epoch 160/200
# 2/2 - 0s - loss: 0.0319 - accuracy: 0.9867 - 21ms/epoch - 10ms/step
# Epoch 161/200
# 2/2 - 0s - loss: 0.0320 - accuracy: 0.9867 - 14ms/epoch - 7ms/step
# Epoch 162/200
# 2/2 - 0s - loss: 0.0312 - accuracy: 0.9867 - 29ms/epoch - 15ms/step
# Epoch 163/200
# 2/2 - 0s - loss: 0.0303 - accuracy: 1.0000 - 21ms/epoch - 10ms/step
# Epoch 164/200
# 2/2 - 0s - loss: 0.0308 - accuracy: 1.0000 - 29ms/epoch - 14ms/step
# Epoch 165/200
# 2/2 - 0s - loss: 0.0313 - accuracy: 0.9867 - 14ms/epoch - 7ms/step
# Epoch 166/200
# 2/2 - 0s - loss: 0.0306 - accuracy: 1.0000 - 14ms/epoch - 7ms/step
# Epoch 167/200
# 2/2 - 0s - loss: 0.0298 - accuracy: 1.0000 - 21ms/epoch - 10ms/step
# Epoch 168/200
# 2/2 - 0s - loss: 0.0291 - accuracy: 1.0000 - 12ms/epoch - 6ms/step
# Epoch 169/200
# 2/2 - 0s - loss: 0.0290 - accuracy: 1.0000 - 39ms/epoch - 19ms/step
# Epoch 170/200
# 2/2 - 0s - loss: 0.0289 - accuracy: 0.9867 - 25ms/epoch - 13ms/step
# Epoch 171/200
# 2/2 - 0s - loss: 0.0291 - accuracy: 0.9867 - 43ms/epoch - 22ms/step
# Epoch 172/200
# 2/2 - 0s - loss: 0.0293 - accuracy: 0.9867 - 26ms/epoch - 13ms/step
# Epoch 173/200
# 2/2 - 0s - loss: 0.0291 - accuracy: 0.9867 - 19ms/epoch - 10ms/step
# Epoch 174/200
# 2/2 - 0s - loss: 0.0288 - accuracy: 0.9867 - 26ms/epoch - 13ms/step
# Epoch 175/200
# 2/2 - 0s - loss: 0.0285 - accuracy: 0.9867 - 44ms/epoch - 22ms/step
# Epoch 176/200
# 2/2 - 0s - loss: 0.0280 - accuracy: 0.9867 - 39ms/epoch - 20ms/step
# Epoch 177/200
# 2/2 - 0s - loss: 0.0278 - accuracy: 0.9867 - 27ms/epoch - 14ms/step
# Epoch 178/200
# 2/2 - 0s - loss: 0.0276 - accuracy: 0.9867 - 36ms/epoch - 18ms/step
# Epoch 179/200
# 2/2 - 0s - loss: 0.0272 - accuracy: 1.0000 - 22ms/epoch - 11ms/step
# Epoch 180/200
# 2/2 - 0s - loss: 0.0270 - accuracy: 1.0000 - 20ms/epoch - 10ms/step
# Epoch 181/200
# 2/2 - 0s - loss: 0.0264 - accuracy: 1.0000 - 11ms/epoch - 6ms/step
# Epoch 182/200
# 2/2 - 0s - loss: 0.0263 - accuracy: 1.0000 - 12ms/epoch - 6ms/step
# Epoch 183/200
# 2/2 - 0s - loss: 0.0262 - accuracy: 1.0000 - 11ms/epoch - 6ms/step
# Epoch 184/200
# 2/2 - 0s - loss: 0.0261 - accuracy: 1.0000 - 19ms/epoch - 10ms/step
# Epoch 185/200
# 2/2 - 0s - loss: 0.0260 - accuracy: 1.0000 - 24ms/epoch - 12ms/step
# Epoch 186/200
# 2/2 - 0s - loss: 0.0258 - accuracy: 1.0000 - 25ms/epoch - 13ms/step
# Epoch 187/200
# 2/2 - 0s - loss: 0.0257 - accuracy: 1.0000 - 23ms/epoch - 11ms/step
# Epoch 188/200
# 2/2 - 0s - loss: 0.0255 - accuracy: 1.0000 - 16ms/epoch - 8ms/step
# Epoch 189/200
# 2/2 - 0s - loss: 0.0254 - accuracy: 1.0000 - 15ms/epoch - 8ms/step
# Epoch 190/200
# 2/2 - 0s - loss: 0.0256 - accuracy: 0.9867 - 23ms/epoch - 12ms/step
# Epoch 191/200
# 2/2 - 0s - loss: 0.0258 - accuracy: 0.9867 - 15ms/epoch - 7ms/step
# Epoch 192/200
# 2/2 - 0s - loss: 0.0244 - accuracy: 1.0000 - 21ms/epoch - 10ms/step
# Epoch 193/200
# 2/2 - 0s - loss: 0.0242 - accuracy: 1.0000 - 14ms/epoch - 7ms/step
# Epoch 194/200
# 2/2 - 0s - loss: 0.0257 - accuracy: 1.0000 - 15ms/epoch - 8ms/step
# Epoch 195/200
# 2/2 - 0s - loss: 0.0261 - accuracy: 0.9867 - 16ms/epoch - 8ms/step
# Epoch 196/200
# 2/2 - 0s - loss: 0.0269 - accuracy: 0.9867 - 19ms/epoch - 10ms/step
# Epoch 197/200
# 2/2 - 0s - loss: 0.0275 - accuracy: 0.9867 - 29ms/epoch - 15ms/step
# Epoch 198/200
# 2/2 - 0s - loss: 0.0276 - accuracy: 0.9867 - 16ms/epoch - 8ms/step
# Epoch 199/200
# 2/2 - 0s - loss: 0.0272 - accuracy: 0.9867 - 18ms/epoch - 9ms/step
# Epoch 200/200
# 2/2 - 0s - loss: 0.0263 - accuracy: 0.9867 - 16ms/epoch - 8ms/step
#
# Classification results:
# 3/3 - 0s - loss: 0.3106 - accuracy: 0.9333 - 268ms/epoch - 89ms/step
# 3/3 [==============================] - 0s 7ms/step
# [[25  1  0]
#  [ 0 23  2]
#  [ 0  2 22]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        26
#            1       0.88      0.92      0.90        25
#            2       0.92      0.92      0.92        24
#
#     accuracy                           0.93        75
#    macro avg       0.93      0.93      0.93        75
# weighted avg       0.93      0.93      0.93        75

# %%
# preprocessing
y_train80_ord = label_encoder.fit_transform(y_train80) # can't use string as before -> assign unique integer to each class
y_test20_ord = label_encoder.fit_transform(y_test20)
x_train80_scaled = scaler.fit_transform(x_train80) # scale data to unit variance -> better results
x_test20_scaled = scaler.fit_transform(x_test20)

# define model

model = Sequential([
    Dense(64, activation='relu', input_shape=(input_size,)),
    Dense(64, activation='relu'),
    Dense(output_size, activation='softmax')
])

model.summary()

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# training and testing

model.fit(x_train80_scaled, y_train80_ord, epochs=200, batch_size=64, verbose=2)

print()
print('Classification results:')

loss, accuracy = model.evaluate(x_test20_scaled, y_test20_ord, verbose=2)

model_pred = model.predict(x_test20_scaled)

# print(model_pred)

model_pred_classes = np.argmax(model_pred, axis=1)

print(confusion_matrix(y_test20_ord, model_pred_classes))
print(classification_report(y_test20_ord, model_pred_classes))

iris_DNN_8020 = Classifier('DNN [in 64 64 out]', accuracy, confusion_matrix(y_test20_ord, model_pred_classes), classification_report(y_test20_ord, model_pred_classes))
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_19 (Dense)            (None, 64)                320
#
#  dense_20 (Dense)            (None, 64)                4160
#
#  dense_21 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 4675 (18.26 KB)
# Trainable params: 4675 (18.26 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Epoch 1/200
# 2/2 - 2s - loss: 1.0856 - accuracy: 0.3667 - 2s/epoch - 810ms/step
# Epoch 2/200
# 2/2 - 0s - loss: 1.0240 - accuracy: 0.5417 - 9ms/epoch - 5ms/step
# Epoch 3/200
# 2/2 - 0s - loss: 0.9676 - accuracy: 0.7000 - 9ms/epoch - 4ms/step
# Epoch 4/200
# 2/2 - 0s - loss: 0.9166 - accuracy: 0.7750 - 15ms/epoch - 7ms/step
# Epoch 5/200
# 2/2 - 0s - loss: 0.8697 - accuracy: 0.8000 - 12ms/epoch - 6ms/step
# Epoch 6/200
# 2/2 - 0s - loss: 0.8251 - accuracy: 0.8500 - 11ms/epoch - 5ms/step
# Epoch 7/200
# 2/2 - 0s - loss: 0.7829 - accuracy: 0.8417 - 10ms/epoch - 5ms/step
# Epoch 8/200
# 2/2 - 0s - loss: 0.7435 - accuracy: 0.8417 - 10ms/epoch - 5ms/step
# Epoch 9/200
# 2/2 - 0s - loss: 0.7055 - accuracy: 0.8417 - 10ms/epoch - 5ms/step
# Epoch 10/200
# 2/2 - 0s - loss: 0.6698 - accuracy: 0.8417 - 10ms/epoch - 5ms/step
# Epoch 11/200
# 2/2 - 0s - loss: 0.6355 - accuracy: 0.8500 - 10ms/epoch - 5ms/step
# Epoch 12/200
# 2/2 - 0s - loss: 0.6038 - accuracy: 0.8500 - 9ms/epoch - 5ms/step
# Epoch 13/200
# 2/2 - 0s - loss: 0.5744 - accuracy: 0.8500 - 9ms/epoch - 5ms/step
# Epoch 14/200
# 2/2 - 0s - loss: 0.5472 - accuracy: 0.8500 - 9ms/epoch - 4ms/step
# Epoch 15/200
# 2/2 - 0s - loss: 0.5219 - accuracy: 0.8583 - 9ms/epoch - 4ms/step
# Epoch 16/200
# 2/2 - 0s - loss: 0.4978 - accuracy: 0.8583 - 9ms/epoch - 5ms/step
# Epoch 17/200
# 2/2 - 0s - loss: 0.4756 - accuracy: 0.8583 - 9ms/epoch - 5ms/step
# Epoch 18/200
# 2/2 - 0s - loss: 0.4556 - accuracy: 0.8583 - 10ms/epoch - 5ms/step
# Epoch 19/200
# 2/2 - 0s - loss: 0.4367 - accuracy: 0.8583 - 11ms/epoch - 5ms/step
# Epoch 20/200
# 2/2 - 0s - loss: 0.4184 - accuracy: 0.8667 - 12ms/epoch - 6ms/step
# Epoch 21/200
# 2/2 - 0s - loss: 0.4024 - accuracy: 0.8667 - 10ms/epoch - 5ms/step
# Epoch 22/200
# 2/2 - 0s - loss: 0.3863 - accuracy: 0.8667 - 10ms/epoch - 5ms/step
# Epoch 23/200
# 2/2 - 0s - loss: 0.3712 - accuracy: 0.8667 - 9ms/epoch - 5ms/step
# Epoch 24/200
# 2/2 - 0s - loss: 0.3591 - accuracy: 0.8667 - 9ms/epoch - 5ms/step
# Epoch 25/200
# 2/2 - 0s - loss: 0.3465 - accuracy: 0.8750 - 10ms/epoch - 5ms/step
# Epoch 26/200
# 2/2 - 0s - loss: 0.3350 - accuracy: 0.8750 - 9ms/epoch - 4ms/step
# Epoch 27/200
# 2/2 - 0s - loss: 0.3242 - accuracy: 0.8833 - 9ms/epoch - 4ms/step
# Epoch 28/200
# 2/2 - 0s - loss: 0.3137 - accuracy: 0.8833 - 9ms/epoch - 5ms/step
# Epoch 29/200
# 2/2 - 0s - loss: 0.3041 - accuracy: 0.8833 - 9ms/epoch - 5ms/step
# Epoch 30/200
# 2/2 - 0s - loss: 0.2948 - accuracy: 0.8833 - 9ms/epoch - 4ms/step
# Epoch 31/200
# 2/2 - 0s - loss: 0.2857 - accuracy: 0.8750 - 8ms/epoch - 4ms/step
# Epoch 32/200
# 2/2 - 0s - loss: 0.2778 - accuracy: 0.8833 - 9ms/epoch - 4ms/step
# Epoch 33/200
# 2/2 - 0s - loss: 0.2702 - accuracy: 0.8833 - 9ms/epoch - 4ms/step
# Epoch 34/200
# 2/2 - 0s - loss: 0.2639 - accuracy: 0.8917 - 10ms/epoch - 5ms/step
# Epoch 35/200
# 2/2 - 0s - loss: 0.2571 - accuracy: 0.8917 - 11ms/epoch - 5ms/step
# Epoch 36/200
# 2/2 - 0s - loss: 0.2506 - accuracy: 0.8917 - 10ms/epoch - 5ms/step
# Epoch 37/200
# 2/2 - 0s - loss: 0.2450 - accuracy: 0.8917 - 10ms/epoch - 5ms/step
# Epoch 38/200
# 2/2 - 0s - loss: 0.2391 - accuracy: 0.8917 - 9ms/epoch - 5ms/step
# Epoch 39/200
# 2/2 - 0s - loss: 0.2337 - accuracy: 0.9000 - 11ms/epoch - 5ms/step
# Epoch 40/200
# 2/2 - 0s - loss: 0.2284 - accuracy: 0.9000 - 10ms/epoch - 5ms/step
# Epoch 41/200
# 2/2 - 0s - loss: 0.2235 - accuracy: 0.9083 - 9ms/epoch - 5ms/step
# Epoch 42/200
# 2/2 - 0s - loss: 0.2183 - accuracy: 0.9083 - 9ms/epoch - 4ms/step
# Epoch 43/200
# 2/2 - 0s - loss: 0.2134 - accuracy: 0.9250 - 11ms/epoch - 5ms/step
# Epoch 44/200
# 2/2 - 0s - loss: 0.2085 - accuracy: 0.9333 - 9ms/epoch - 4ms/step
# Epoch 45/200
# 2/2 - 0s - loss: 0.2038 - accuracy: 0.9333 - 9ms/epoch - 5ms/step
# Epoch 46/200
# 2/2 - 0s - loss: 0.1993 - accuracy: 0.9500 - 10ms/epoch - 5ms/step
# Epoch 47/200
# 2/2 - 0s - loss: 0.1949 - accuracy: 0.9500 - 11ms/epoch - 6ms/step
# Epoch 48/200
# 2/2 - 0s - loss: 0.1905 - accuracy: 0.9500 - 10ms/epoch - 5ms/step
# Epoch 49/200
# 2/2 - 0s - loss: 0.1864 - accuracy: 0.9500 - 9ms/epoch - 5ms/step
# Epoch 50/200
# 2/2 - 0s - loss: 0.1823 - accuracy: 0.9500 - 12ms/epoch - 6ms/step
# Epoch 51/200
# 2/2 - 0s - loss: 0.1779 - accuracy: 0.9500 - 10ms/epoch - 5ms/step
# Epoch 52/200
# 2/2 - 0s - loss: 0.1738 - accuracy: 0.9500 - 19ms/epoch - 9ms/step
# Epoch 53/200
# 2/2 - 0s - loss: 0.1699 - accuracy: 0.9500 - 10ms/epoch - 5ms/step
# Epoch 54/200
# 2/2 - 0s - loss: 0.1662 - accuracy: 0.9500 - 10ms/epoch - 5ms/step
# Epoch 55/200
# 2/2 - 0s - loss: 0.1625 - accuracy: 0.9500 - 9ms/epoch - 5ms/step
# Epoch 56/200
# 2/2 - 0s - loss: 0.1587 - accuracy: 0.9500 - 10ms/epoch - 5ms/step
# Epoch 57/200
# 2/2 - 0s - loss: 0.1549 - accuracy: 0.9500 - 10ms/epoch - 5ms/step
# Epoch 58/200
# 2/2 - 0s - loss: 0.1515 - accuracy: 0.9500 - 9ms/epoch - 5ms/step
# Epoch 59/200
# 2/2 - 0s - loss: 0.1478 - accuracy: 0.9500 - 9ms/epoch - 5ms/step
# Epoch 60/200
# 2/2 - 0s - loss: 0.1444 - accuracy: 0.9500 - 10ms/epoch - 5ms/step
# Epoch 61/200
# 2/2 - 0s - loss: 0.1411 - accuracy: 0.9500 - 9ms/epoch - 4ms/step
# Epoch 62/200
# 2/2 - 0s - loss: 0.1380 - accuracy: 0.9667 - 10ms/epoch - 5ms/step
# Epoch 63/200
# 2/2 - 0s - loss: 0.1349 - accuracy: 0.9667 - 10ms/epoch - 5ms/step
# Epoch 64/200
# 2/2 - 0s - loss: 0.1314 - accuracy: 0.9750 - 9ms/epoch - 4ms/step
# Epoch 65/200
# 2/2 - 0s - loss: 0.1286 - accuracy: 0.9750 - 13ms/epoch - 6ms/step
# Epoch 66/200
# 2/2 - 0s - loss: 0.1256 - accuracy: 0.9750 - 10ms/epoch - 5ms/step
# Epoch 67/200
# 2/2 - 0s - loss: 0.1227 - accuracy: 0.9750 - 9ms/epoch - 5ms/step
# Epoch 68/200
# 2/2 - 0s - loss: 0.1197 - accuracy: 0.9750 - 10ms/epoch - 5ms/step
# Epoch 69/200
# 2/2 - 0s - loss: 0.1173 - accuracy: 0.9667 - 10ms/epoch - 5ms/step
# Epoch 70/200
# 2/2 - 0s - loss: 0.1143 - accuracy: 0.9667 - 10ms/epoch - 5ms/step
# Epoch 71/200
# 2/2 - 0s - loss: 0.1118 - accuracy: 0.9667 - 11ms/epoch - 5ms/step
# Epoch 72/200
# 2/2 - 0s - loss: 0.1095 - accuracy: 0.9667 - 10ms/epoch - 5ms/step
# Epoch 73/200
# 2/2 - 0s - loss: 0.1068 - accuracy: 0.9667 - 11ms/epoch - 6ms/step
# Epoch 74/200
# 2/2 - 0s - loss: 0.1045 - accuracy: 0.9667 - 12ms/epoch - 6ms/step
# Epoch 75/200
# 2/2 - 0s - loss: 0.1023 - accuracy: 0.9667 - 9ms/epoch - 5ms/step
# Epoch 76/200
# 2/2 - 0s - loss: 0.1004 - accuracy: 0.9667 - 9ms/epoch - 5ms/step
# Epoch 77/200
# 2/2 - 0s - loss: 0.0978 - accuracy: 0.9667 - 10ms/epoch - 5ms/step
# Epoch 78/200
# 2/2 - 0s - loss: 0.0959 - accuracy: 0.9667 - 14ms/epoch - 7ms/step
# Epoch 79/200
# 2/2 - 0s - loss: 0.0939 - accuracy: 0.9667 - 17ms/epoch - 9ms/step
# Epoch 80/200
# 2/2 - 0s - loss: 0.0919 - accuracy: 0.9667 - 13ms/epoch - 6ms/step
# Epoch 81/200
# 2/2 - 0s - loss: 0.0898 - accuracy: 0.9667 - 10ms/epoch - 5ms/step
# Epoch 82/200
# 2/2 - 0s - loss: 0.0882 - accuracy: 0.9667 - 11ms/epoch - 5ms/step
# Epoch 83/200
# 2/2 - 0s - loss: 0.0864 - accuracy: 0.9667 - 9ms/epoch - 5ms/step
# Epoch 84/200
# 2/2 - 0s - loss: 0.0846 - accuracy: 0.9667 - 10ms/epoch - 5ms/step
# Epoch 85/200
# 2/2 - 0s - loss: 0.0835 - accuracy: 0.9667 - 14ms/epoch - 7ms/step
# Epoch 86/200
# 2/2 - 0s - loss: 0.0814 - accuracy: 0.9667 - 10ms/epoch - 5ms/step
# Epoch 87/200
# 2/2 - 0s - loss: 0.0803 - accuracy: 0.9667 - 10ms/epoch - 5ms/step
# Epoch 88/200
# 2/2 - 0s - loss: 0.0784 - accuracy: 0.9667 - 11ms/epoch - 6ms/step
# Epoch 89/200
# 2/2 - 0s - loss: 0.0772 - accuracy: 0.9667 - 12ms/epoch - 6ms/step
# Epoch 90/200
# 2/2 - 0s - loss: 0.0751 - accuracy: 0.9667 - 9ms/epoch - 5ms/step
# Epoch 91/200
# 2/2 - 0s - loss: 0.0738 - accuracy: 0.9667 - 10ms/epoch - 5ms/step
# Epoch 92/200
# 2/2 - 0s - loss: 0.0725 - accuracy: 0.9667 - 9ms/epoch - 5ms/step
# Epoch 93/200
# 2/2 - 0s - loss: 0.0715 - accuracy: 0.9667 - 10ms/epoch - 5ms/step
# Epoch 94/200
# 2/2 - 0s - loss: 0.0700 - accuracy: 0.9667 - 10ms/epoch - 5ms/step
# Epoch 95/200
# 2/2 - 0s - loss: 0.0688 - accuracy: 0.9667 - 9ms/epoch - 5ms/step
# Epoch 96/200
# 2/2 - 0s - loss: 0.0675 - accuracy: 0.9667 - 9ms/epoch - 5ms/step
# Epoch 97/200
# 2/2 - 0s - loss: 0.0663 - accuracy: 0.9667 - 11ms/epoch - 5ms/step
# Epoch 98/200
# 2/2 - 0s - loss: 0.0653 - accuracy: 0.9667 - 10ms/epoch - 5ms/step
# Epoch 99/200
# 2/2 - 0s - loss: 0.0642 - accuracy: 0.9667 - 10ms/epoch - 5ms/step
# Epoch 100/200
# 2/2 - 0s - loss: 0.0632 - accuracy: 0.9667 - 10ms/epoch - 5ms/step
# Epoch 101/200
# 2/2 - 0s - loss: 0.0621 - accuracy: 0.9667 - 10ms/epoch - 5ms/step
# Epoch 102/200
# 2/2 - 0s - loss: 0.0611 - accuracy: 0.9667 - 11ms/epoch - 6ms/step
# Epoch 103/200
# 2/2 - 0s - loss: 0.0602 - accuracy: 0.9667 - 10ms/epoch - 5ms/step
# Epoch 104/200
# 2/2 - 0s - loss: 0.0599 - accuracy: 0.9667 - 9ms/epoch - 5ms/step
# Epoch 105/200
# 2/2 - 0s - loss: 0.0589 - accuracy: 0.9667 - 10ms/epoch - 5ms/step
# Epoch 106/200
# 2/2 - 0s - loss: 0.0578 - accuracy: 0.9667 - 10ms/epoch - 5ms/step
# Epoch 107/200
# 2/2 - 0s - loss: 0.0567 - accuracy: 0.9667 - 9ms/epoch - 5ms/step
# Epoch 108/200
# 2/2 - 0s - loss: 0.0561 - accuracy: 0.9667 - 9ms/epoch - 5ms/step
# Epoch 109/200
# 2/2 - 0s - loss: 0.0553 - accuracy: 0.9667 - 9ms/epoch - 4ms/step
# Epoch 110/200
# 2/2 - 0s - loss: 0.0554 - accuracy: 0.9667 - 8ms/epoch - 4ms/step
# Epoch 111/200
# 2/2 - 0s - loss: 0.0538 - accuracy: 0.9667 - 11ms/epoch - 6ms/step
# Epoch 112/200
# 2/2 - 0s - loss: 0.0531 - accuracy: 0.9667 - 10ms/epoch - 5ms/step
# Epoch 113/200
# 2/2 - 0s - loss: 0.0525 - accuracy: 0.9667 - 11ms/epoch - 6ms/step
# Epoch 114/200
# 2/2 - 0s - loss: 0.0517 - accuracy: 0.9667 - 11ms/epoch - 5ms/step
# Epoch 115/200
# 2/2 - 0s - loss: 0.0511 - accuracy: 0.9667 - 12ms/epoch - 6ms/step
# Epoch 116/200
# 2/2 - 0s - loss: 0.0504 - accuracy: 0.9667 - 15ms/epoch - 8ms/step
# Epoch 117/200
# 2/2 - 0s - loss: 0.0498 - accuracy: 0.9667 - 11ms/epoch - 5ms/step
# Epoch 118/200
# 2/2 - 0s - loss: 0.0492 - accuracy: 0.9667 - 9ms/epoch - 5ms/step
# Epoch 119/200
# 2/2 - 0s - loss: 0.0488 - accuracy: 0.9667 - 9ms/epoch - 5ms/step
# Epoch 120/200
# 2/2 - 0s - loss: 0.0482 - accuracy: 0.9667 - 10ms/epoch - 5ms/step
# Epoch 121/200
# 2/2 - 0s - loss: 0.0478 - accuracy: 0.9667 - 11ms/epoch - 6ms/step
# Epoch 122/200
# 2/2 - 0s - loss: 0.0473 - accuracy: 0.9750 - 10ms/epoch - 5ms/step
# Epoch 123/200
# 2/2 - 0s - loss: 0.0467 - accuracy: 0.9667 - 10ms/epoch - 5ms/step
# Epoch 124/200
# 2/2 - 0s - loss: 0.0462 - accuracy: 0.9667 - 9ms/epoch - 5ms/step
# Epoch 125/200
# 2/2 - 0s - loss: 0.0456 - accuracy: 0.9667 - 9ms/epoch - 5ms/step
# Epoch 126/200
# 2/2 - 0s - loss: 0.0457 - accuracy: 0.9667 - 10ms/epoch - 5ms/step
# Epoch 127/200
# 2/2 - 0s - loss: 0.0448 - accuracy: 0.9750 - 10ms/epoch - 5ms/step
# Epoch 128/200
# 2/2 - 0s - loss: 0.0445 - accuracy: 0.9667 - 9ms/epoch - 5ms/step
# Epoch 129/200
# 2/2 - 0s - loss: 0.0441 - accuracy: 0.9667 - 9ms/epoch - 4ms/step
# Epoch 130/200
# 2/2 - 0s - loss: 0.0438 - accuracy: 0.9667 - 12ms/epoch - 6ms/step
# Epoch 131/200
# 2/2 - 0s - loss: 0.0435 - accuracy: 0.9667 - 9ms/epoch - 5ms/step
# Epoch 132/200
# 2/2 - 0s - loss: 0.0430 - accuracy: 0.9750 - 10ms/epoch - 5ms/step
# Epoch 133/200
# 2/2 - 0s - loss: 0.0425 - accuracy: 0.9750 - 10ms/epoch - 5ms/step
# Epoch 134/200
# 2/2 - 0s - loss: 0.0422 - accuracy: 0.9750 - 11ms/epoch - 5ms/step
# Epoch 135/200
# 2/2 - 0s - loss: 0.0418 - accuracy: 0.9750 - 10ms/epoch - 5ms/step
# Epoch 136/200
# 2/2 - 0s - loss: 0.0414 - accuracy: 0.9750 - 10ms/epoch - 5ms/step
# Epoch 137/200
# 2/2 - 0s - loss: 0.0410 - accuracy: 0.9750 - 9ms/epoch - 5ms/step
# Epoch 138/200
# 2/2 - 0s - loss: 0.0407 - accuracy: 0.9750 - 11ms/epoch - 5ms/step
# Epoch 139/200
# 2/2 - 0s - loss: 0.0405 - accuracy: 0.9750 - 15ms/epoch - 8ms/step
# Epoch 140/200
# 2/2 - 0s - loss: 0.0401 - accuracy: 0.9750 - 11ms/epoch - 5ms/step
# Epoch 141/200
# 2/2 - 0s - loss: 0.0398 - accuracy: 0.9750 - 10ms/epoch - 5ms/step
# Epoch 142/200
# 2/2 - 0s - loss: 0.0402 - accuracy: 0.9750 - 14ms/epoch - 7ms/step
# Epoch 143/200
# 2/2 - 0s - loss: 0.0395 - accuracy: 0.9750 - 16ms/epoch - 8ms/step
# Epoch 144/200
# 2/2 - 0s - loss: 0.0390 - accuracy: 0.9750 - 12ms/epoch - 6ms/step
# Epoch 145/200
# 2/2 - 0s - loss: 0.0394 - accuracy: 0.9750 - 13ms/epoch - 6ms/step
# Epoch 146/200
# 2/2 - 0s - loss: 0.0384 - accuracy: 0.9750 - 15ms/epoch - 8ms/step
# Epoch 147/200
# 2/2 - 0s - loss: 0.0381 - accuracy: 0.9750 - 14ms/epoch - 7ms/step
# Epoch 148/200
# 2/2 - 0s - loss: 0.0381 - accuracy: 0.9833 - 21ms/epoch - 11ms/step
# Epoch 149/200
# 2/2 - 0s - loss: 0.0376 - accuracy: 0.9833 - 16ms/epoch - 8ms/step
# Epoch 150/200
# 2/2 - 0s - loss: 0.0378 - accuracy: 0.9750 - 16ms/epoch - 8ms/step
# Epoch 151/200
# 2/2 - 0s - loss: 0.0371 - accuracy: 0.9750 - 13ms/epoch - 7ms/step
# Epoch 152/200
# 2/2 - 0s - loss: 0.0374 - accuracy: 0.9750 - 13ms/epoch - 6ms/step
# Epoch 153/200
# 2/2 - 0s - loss: 0.0365 - accuracy: 0.9833 - 15ms/epoch - 7ms/step
# Epoch 154/200
# 2/2 - 0s - loss: 0.0366 - accuracy: 0.9750 - 13ms/epoch - 6ms/step
# Epoch 155/200
# 2/2 - 0s - loss: 0.0361 - accuracy: 0.9750 - 14ms/epoch - 7ms/step
# Epoch 156/200
# 2/2 - 0s - loss: 0.0357 - accuracy: 0.9833 - 13ms/epoch - 6ms/step
# Epoch 157/200
# 2/2 - 0s - loss: 0.0355 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
# Epoch 158/200
# 2/2 - 0s - loss: 0.0354 - accuracy: 0.9833 - 11ms/epoch - 6ms/step
# Epoch 159/200
# 2/2 - 0s - loss: 0.0356 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
# Epoch 160/200
# 2/2 - 0s - loss: 0.0359 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
# Epoch 161/200
# 2/2 - 0s - loss: 0.0350 - accuracy: 0.9833 - 16ms/epoch - 8ms/step
# Epoch 162/200
# 2/2 - 0s - loss: 0.0346 - accuracy: 0.9833 - 15ms/epoch - 8ms/step
# Epoch 163/200
# 2/2 - 0s - loss: 0.0346 - accuracy: 0.9833 - 13ms/epoch - 7ms/step
# Epoch 164/200
# 2/2 - 0s - loss: 0.0341 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 165/200
# 2/2 - 0s - loss: 0.0340 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 166/200
# 2/2 - 0s - loss: 0.0337 - accuracy: 0.9833 - 14ms/epoch - 7ms/step
# Epoch 167/200
# 2/2 - 0s - loss: 0.0334 - accuracy: 0.9917 - 11ms/epoch - 6ms/step
# Epoch 168/200
# 2/2 - 0s - loss: 0.0333 - accuracy: 0.9917 - 12ms/epoch - 6ms/step
# Epoch 169/200
# 2/2 - 0s - loss: 0.0330 - accuracy: 0.9917 - 11ms/epoch - 5ms/step
# Epoch 170/200
# 2/2 - 0s - loss: 0.0329 - accuracy: 0.9917 - 11ms/epoch - 5ms/step
# Epoch 171/200
# 2/2 - 0s - loss: 0.0326 - accuracy: 0.9917 - 16ms/epoch - 8ms/step
# Epoch 172/200
# 2/2 - 0s - loss: 0.0324 - accuracy: 0.9917 - 12ms/epoch - 6ms/step
# Epoch 173/200
# 2/2 - 0s - loss: 0.0322 - accuracy: 0.9917 - 13ms/epoch - 6ms/step
# Epoch 174/200
# 2/2 - 0s - loss: 0.0321 - accuracy: 0.9917 - 13ms/epoch - 6ms/step
# Epoch 175/200
# 2/2 - 0s - loss: 0.0324 - accuracy: 0.9917 - 13ms/epoch - 7ms/step
# Epoch 176/200
# 2/2 - 0s - loss: 0.0317 - accuracy: 0.9917 - 12ms/epoch - 6ms/step
# Epoch 177/200
# 2/2 - 0s - loss: 0.0315 - accuracy: 0.9917 - 13ms/epoch - 6ms/step
# Epoch 178/200
# 2/2 - 0s - loss: 0.0313 - accuracy: 0.9917 - 11ms/epoch - 6ms/step
# Epoch 179/200
# 2/2 - 0s - loss: 0.0312 - accuracy: 0.9917 - 15ms/epoch - 8ms/step
# Epoch 180/200
# 2/2 - 0s - loss: 0.0315 - accuracy: 0.9833 - 11ms/epoch - 6ms/step
# Epoch 181/200
# 2/2 - 0s - loss: 0.0310 - accuracy: 0.9833 - 15ms/epoch - 8ms/step
# Epoch 182/200
# 2/2 - 0s - loss: 0.0306 - accuracy: 0.9917 - 12ms/epoch - 6ms/step
# Epoch 183/200
# 2/2 - 0s - loss: 0.0305 - accuracy: 0.9917 - 12ms/epoch - 6ms/step
# Epoch 184/200
# 2/2 - 0s - loss: 0.0304 - accuracy: 0.9917 - 12ms/epoch - 6ms/step
# Epoch 185/200
# 2/2 - 0s - loss: 0.0302 - accuracy: 0.9917 - 10ms/epoch - 5ms/step
# Epoch 186/200
# 2/2 - 0s - loss: 0.0300 - accuracy: 0.9917 - 11ms/epoch - 6ms/step
# Epoch 187/200
# 2/2 - 0s - loss: 0.0298 - accuracy: 0.9917 - 12ms/epoch - 6ms/step
# Epoch 188/200
# 2/2 - 0s - loss: 0.0300 - accuracy: 0.9917 - 12ms/epoch - 6ms/step
# Epoch 189/200
# 2/2 - 0s - loss: 0.0294 - accuracy: 0.9917 - 13ms/epoch - 7ms/step
# Epoch 190/200
# 2/2 - 0s - loss: 0.0295 - accuracy: 0.9917 - 11ms/epoch - 6ms/step
# Epoch 191/200
# 2/2 - 0s - loss: 0.0295 - accuracy: 0.9917 - 12ms/epoch - 6ms/step
# Epoch 192/200
# 2/2 - 0s - loss: 0.0291 - accuracy: 0.9917 - 12ms/epoch - 6ms/step
# Epoch 193/200
# 2/2 - 0s - loss: 0.0289 - accuracy: 0.9917 - 11ms/epoch - 6ms/step
# Epoch 194/200
# 2/2 - 0s - loss: 0.0289 - accuracy: 0.9917 - 13ms/epoch - 7ms/step
# Epoch 195/200
# 2/2 - 0s - loss: 0.0291 - accuracy: 0.9917 - 12ms/epoch - 6ms/step
# Epoch 196/200
# 2/2 - 0s - loss: 0.0286 - accuracy: 0.9917 - 11ms/epoch - 6ms/step
# Epoch 197/200
# 2/2 - 0s - loss: 0.0289 - accuracy: 0.9917 - 15ms/epoch - 7ms/step
# Epoch 198/200
# 2/2 - 0s - loss: 0.0281 - accuracy: 0.9917 - 11ms/epoch - 6ms/step
# Epoch 199/200
# 2/2 - 0s - loss: 0.0279 - accuracy: 0.9917 - 11ms/epoch - 5ms/step
# Epoch 200/200
# 2/2 - 0s - loss: 0.0278 - accuracy: 0.9917 - 12ms/epoch - 6ms/step
#
# Classification results:
# 1/1 - 0s - loss: 0.4491 - accuracy: 0.9000 - 231ms/epoch - 231ms/step
# 1/1 [==============================] - 0s 85ms/step
# [[10  0  0]
#  [ 0  8  1]
#  [ 0  2  9]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.80      0.89      0.84         9
#            2       0.90      0.82      0.86        11
#
#     accuracy                           0.90        30
#    macro avg       0.90      0.90      0.90        30
# weighted avg       0.90      0.90      0.90        30

# %% [markdown]
# ### CNN

# %%
input_size = X.shape[1]
output_size = 3

#preprocessing
label_encoder = LabelEncoder()

# %% [markdown]
# **50/50 Split**

# %%
# preprocessing
y_train50_ord = label_encoder.fit_transform(y_train50) # can't use string as before -> assign unique integer to each class
y_test50_ord = label_encoder.fit_transform(y_test50)

x_train50_reshaped = x_train50.to_numpy().reshape(-1, input_size, 1)
x_test50_reshaped = x_test50.to_numpy().reshape(-1, input_size, 1)

# define model

model = Sequential([
    Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(input_size, 1)),
    MaxPooling1D(pool_size=2),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(output_size, activation='softmax')
])

model.summary()

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# training and testing

model.fit(x_train50_reshaped, y_train50_ord, epochs=200, batch_size=64, verbose=2)

print()
print('Classification results:')

loss, accuracy = model.evaluate(x_test50_reshaped, y_test50_ord, verbose=2)

model_pred = model.predict(x_test50_reshaped)

# print(model_pred)

model_pred_classes = np.argmax(model_pred, axis=1)

print(confusion_matrix(y_test50_ord, model_pred_classes))
print(classification_report(y_test50_ord, model_pred_classes))

iris_CNN_5050 = Classifier('CNN [in C1D P1D F 128 out]', accuracy, confusion_matrix(y_test50_ord, model_pred_classes), classification_report(y_test50_ord, model_pred_classes))
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 2, 64)             256
#
#  max_pooling1d_2 (MaxPoolin  (None, 1, 64)             0
#  g1D)
#
#  flatten_2 (Flatten)         (None, 64)                0
#
#  dense_22 (Dense)            (None, 128)               8320
#
#  dense_23 (Dense)            (None, 3)                 387
#
# =================================================================
# Total params: 8963 (35.01 KB)
# Trainable params: 8963 (35.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Epoch 1/200
# 2/2 - 1s - loss: 1.3031 - accuracy: 0.2000 - 1s/epoch - 561ms/step
# Epoch 2/200
# 2/2 - 0s - loss: 1.1402 - accuracy: 0.3333 - 14ms/epoch - 7ms/step
# Epoch 3/200
# 2/2 - 0s - loss: 1.0214 - accuracy: 0.3333 - 14ms/epoch - 7ms/step
# Epoch 4/200
# 2/2 - 0s - loss: 0.9513 - accuracy: 0.6000 - 16ms/epoch - 8ms/step
# Epoch 5/200
# 2/2 - 0s - loss: 0.9194 - accuracy: 0.5200 - 13ms/epoch - 7ms/step
# Epoch 6/200
# 2/2 - 0s - loss: 0.9027 - accuracy: 0.5867 - 15ms/epoch - 7ms/step
# Epoch 7/200
# 2/2 - 0s - loss: 0.8867 - accuracy: 0.5333 - 17ms/epoch - 8ms/step
# Epoch 8/200
# 2/2 - 0s - loss: 0.8642 - accuracy: 0.6667 - 17ms/epoch - 9ms/step
# Epoch 9/200
# 2/2 - 0s - loss: 0.8396 - accuracy: 0.6667 - 19ms/epoch - 10ms/step
# Epoch 10/200
# 2/2 - 0s - loss: 0.8075 - accuracy: 0.6667 - 17ms/epoch - 9ms/step
# Epoch 11/200
# 2/2 - 0s - loss: 0.7748 - accuracy: 0.6667 - 14ms/epoch - 7ms/step
# Epoch 12/200
# 2/2 - 0s - loss: 0.7449 - accuracy: 0.6667 - 14ms/epoch - 7ms/step
# Epoch 13/200
# 2/2 - 0s - loss: 0.7181 - accuracy: 0.6667 - 13ms/epoch - 6ms/step
# Epoch 14/200
# 2/2 - 0s - loss: 0.6964 - accuracy: 0.6667 - 15ms/epoch - 7ms/step
# Epoch 15/200
# 2/2 - 0s - loss: 0.6767 - accuracy: 0.6667 - 20ms/epoch - 10ms/step
# Epoch 16/200
# 2/2 - 0s - loss: 0.6562 - accuracy: 0.6667 - 18ms/epoch - 9ms/step
# Epoch 17/200
# 2/2 - 0s - loss: 0.6360 - accuracy: 0.6667 - 16ms/epoch - 8ms/step
# Epoch 18/200
# 2/2 - 0s - loss: 0.6135 - accuracy: 0.6800 - 16ms/epoch - 8ms/step
# Epoch 19/200
# 2/2 - 0s - loss: 0.5962 - accuracy: 0.7067 - 13ms/epoch - 7ms/step
# Epoch 20/200
# 2/2 - 0s - loss: 0.5810 - accuracy: 0.8267 - 19ms/epoch - 10ms/step
# Epoch 21/200
# 2/2 - 0s - loss: 0.5665 - accuracy: 0.8933 - 16ms/epoch - 8ms/step
# Epoch 22/200
# 2/2 - 0s - loss: 0.5523 - accuracy: 0.8933 - 16ms/epoch - 8ms/step
# Epoch 23/200
# 2/2 - 0s - loss: 0.5383 - accuracy: 0.8400 - 18ms/epoch - 9ms/step
# Epoch 24/200
# 2/2 - 0s - loss: 0.5253 - accuracy: 0.8267 - 16ms/epoch - 8ms/step
# Epoch 25/200
# 2/2 - 0s - loss: 0.5133 - accuracy: 0.7467 - 16ms/epoch - 8ms/step
# Epoch 26/200
# 2/2 - 0s - loss: 0.5064 - accuracy: 0.6933 - 17ms/epoch - 8ms/step
# Epoch 27/200
# 2/2 - 0s - loss: 0.4958 - accuracy: 0.6933 - 14ms/epoch - 7ms/step
# Epoch 28/200
# 2/2 - 0s - loss: 0.4849 - accuracy: 0.7200 - 18ms/epoch - 9ms/step
# Epoch 29/200
# 2/2 - 0s - loss: 0.4745 - accuracy: 0.8000 - 17ms/epoch - 9ms/step
# Epoch 30/200
# 2/2 - 0s - loss: 0.4664 - accuracy: 0.9067 - 20ms/epoch - 10ms/step
# Epoch 31/200
# 2/2 - 0s - loss: 0.4662 - accuracy: 0.9600 - 17ms/epoch - 9ms/step
# Epoch 32/200
# 2/2 - 0s - loss: 0.4705 - accuracy: 0.8400 - 18ms/epoch - 9ms/step
# Epoch 33/200
# 2/2 - 0s - loss: 0.4685 - accuracy: 0.8000 - 20ms/epoch - 10ms/step
# Epoch 34/200
# 2/2 - 0s - loss: 0.4587 - accuracy: 0.8133 - 13ms/epoch - 6ms/step
# Epoch 35/200
# 2/2 - 0s - loss: 0.4420 - accuracy: 0.9200 - 17ms/epoch - 9ms/step
# Epoch 36/200
# 2/2 - 0s - loss: 0.4302 - accuracy: 0.9467 - 14ms/epoch - 7ms/step
# Epoch 37/200
# 2/2 - 0s - loss: 0.4218 - accuracy: 0.8400 - 15ms/epoch - 8ms/step
# Epoch 38/200
# 2/2 - 0s - loss: 0.4182 - accuracy: 0.8000 - 13ms/epoch - 6ms/step
# Epoch 39/200
# 2/2 - 0s - loss: 0.4133 - accuracy: 0.7867 - 12ms/epoch - 6ms/step
# Epoch 40/200
# 2/2 - 0s - loss: 0.4075 - accuracy: 0.8000 - 12ms/epoch - 6ms/step
# Epoch 41/200
# 2/2 - 0s - loss: 0.4005 - accuracy: 0.8400 - 12ms/epoch - 6ms/step
# Epoch 42/200
# 2/2 - 0s - loss: 0.3916 - accuracy: 0.8933 - 14ms/epoch - 7ms/step
# Epoch 43/200
# 2/2 - 0s - loss: 0.3859 - accuracy: 0.9067 - 14ms/epoch - 7ms/step
# Epoch 44/200
# 2/2 - 0s - loss: 0.3806 - accuracy: 0.9067 - 13ms/epoch - 6ms/step
# Epoch 45/200
# 2/2 - 0s - loss: 0.3755 - accuracy: 0.9333 - 14ms/epoch - 7ms/step
# Epoch 46/200
# 2/2 - 0s - loss: 0.3693 - accuracy: 0.9333 - 16ms/epoch - 8ms/step
# Epoch 47/200
# 2/2 - 0s - loss: 0.3643 - accuracy: 0.9067 - 12ms/epoch - 6ms/step
# Epoch 48/200
# 2/2 - 0s - loss: 0.3598 - accuracy: 0.9067 - 18ms/epoch - 9ms/step
# Epoch 49/200
# 2/2 - 0s - loss: 0.3554 - accuracy: 0.8933 - 12ms/epoch - 6ms/step
# Epoch 50/200
# 2/2 - 0s - loss: 0.3513 - accuracy: 0.8933 - 16ms/epoch - 8ms/step
# Epoch 51/200
# 2/2 - 0s - loss: 0.3455 - accuracy: 0.9067 - 14ms/epoch - 7ms/step
# Epoch 52/200
# 2/2 - 0s - loss: 0.3387 - accuracy: 0.9067 - 13ms/epoch - 7ms/step
# Epoch 53/200
# 2/2 - 0s - loss: 0.3331 - accuracy: 0.9467 - 12ms/epoch - 6ms/step
# Epoch 54/200
# 2/2 - 0s - loss: 0.3287 - accuracy: 0.9600 - 12ms/epoch - 6ms/step
# Epoch 55/200
# 2/2 - 0s - loss: 0.3227 - accuracy: 0.9600 - 12ms/epoch - 6ms/step
# Epoch 56/200
# 2/2 - 0s - loss: 0.3194 - accuracy: 0.9333 - 15ms/epoch - 8ms/step
# Epoch 57/200
# 2/2 - 0s - loss: 0.3153 - accuracy: 0.9067 - 12ms/epoch - 6ms/step
# Epoch 58/200
# 2/2 - 0s - loss: 0.3094 - accuracy: 0.9467 - 12ms/epoch - 6ms/step
# Epoch 59/200
# 2/2 - 0s - loss: 0.3036 - accuracy: 0.9600 - 12ms/epoch - 6ms/step
# Epoch 60/200
# 2/2 - 0s - loss: 0.2998 - accuracy: 0.9733 - 12ms/epoch - 6ms/step
# Epoch 61/200
# 2/2 - 0s - loss: 0.2983 - accuracy: 0.9467 - 11ms/epoch - 6ms/step
# Epoch 62/200
# 2/2 - 0s - loss: 0.2911 - accuracy: 0.9467 - 12ms/epoch - 6ms/step
# Epoch 63/200
# 2/2 - 0s - loss: 0.2857 - accuracy: 0.9600 - 12ms/epoch - 6ms/step
# Epoch 64/200
# 2/2 - 0s - loss: 0.2873 - accuracy: 0.9067 - 11ms/epoch - 6ms/step
# Epoch 65/200
# 2/2 - 0s - loss: 0.2911 - accuracy: 0.9067 - 11ms/epoch - 6ms/step
# Epoch 66/200
# 2/2 - 0s - loss: 0.2935 - accuracy: 0.8933 - 13ms/epoch - 7ms/step
# Epoch 67/200
# 2/2 - 0s - loss: 0.2877 - accuracy: 0.8933 - 15ms/epoch - 8ms/step
# Epoch 68/200
# 2/2 - 0s - loss: 0.2737 - accuracy: 0.9067 - 16ms/epoch - 8ms/step
# Epoch 69/200
# 2/2 - 0s - loss: 0.2633 - accuracy: 0.9600 - 16ms/epoch - 8ms/step
# Epoch 70/200
# 2/2 - 0s - loss: 0.2558 - accuracy: 0.9733 - 13ms/epoch - 7ms/step
# Epoch 71/200
# 2/2 - 0s - loss: 0.2515 - accuracy: 0.9733 - 15ms/epoch - 7ms/step
# Epoch 72/200
# 2/2 - 0s - loss: 0.2474 - accuracy: 0.9733 - 15ms/epoch - 7ms/step
# Epoch 73/200
# 2/2 - 0s - loss: 0.2436 - accuracy: 0.9733 - 13ms/epoch - 7ms/step
# Epoch 74/200
# 2/2 - 0s - loss: 0.2396 - accuracy: 0.9733 - 13ms/epoch - 6ms/step
# Epoch 75/200
# 2/2 - 0s - loss: 0.2363 - accuracy: 0.9733 - 12ms/epoch - 6ms/step
# Epoch 76/200
# 2/2 - 0s - loss: 0.2366 - accuracy: 0.9467 - 10ms/epoch - 5ms/step
# Epoch 77/200
# 2/2 - 0s - loss: 0.2332 - accuracy: 0.9467 - 10ms/epoch - 5ms/step
# Epoch 78/200
# 2/2 - 0s - loss: 0.2267 - accuracy: 0.9467 - 11ms/epoch - 5ms/step
# Epoch 79/200
# 2/2 - 0s - loss: 0.2219 - accuracy: 0.9733 - 15ms/epoch - 7ms/step
# Epoch 80/200
# 2/2 - 0s - loss: 0.2238 - accuracy: 0.9600 - 12ms/epoch - 6ms/step
# Epoch 81/200
# 2/2 - 0s - loss: 0.2218 - accuracy: 0.9600 - 12ms/epoch - 6ms/step
# Epoch 82/200
# 2/2 - 0s - loss: 0.2135 - accuracy: 0.9733 - 12ms/epoch - 6ms/step
# Epoch 83/200
# 2/2 - 0s - loss: 0.2101 - accuracy: 0.9733 - 11ms/epoch - 5ms/step
# Epoch 84/200
# 2/2 - 0s - loss: 0.2067 - accuracy: 0.9733 - 10ms/epoch - 5ms/step
# Epoch 85/200
# 2/2 - 0s - loss: 0.2035 - accuracy: 0.9733 - 11ms/epoch - 5ms/step
# Epoch 86/200
# 2/2 - 0s - loss: 0.2011 - accuracy: 0.9600 - 11ms/epoch - 5ms/step
# Epoch 87/200
# 2/2 - 0s - loss: 0.1987 - accuracy: 0.9467 - 10ms/epoch - 5ms/step
# Epoch 88/200
# 2/2 - 0s - loss: 0.1955 - accuracy: 0.9467 - 13ms/epoch - 6ms/step
# Epoch 89/200
# 2/2 - 0s - loss: 0.1933 - accuracy: 0.9733 - 11ms/epoch - 6ms/step
# Epoch 90/200
# 2/2 - 0s - loss: 0.1904 - accuracy: 0.9600 - 11ms/epoch - 5ms/step
# Epoch 91/200
# 2/2 - 0s - loss: 0.1889 - accuracy: 0.9467 - 11ms/epoch - 5ms/step
# Epoch 92/200
# 2/2 - 0s - loss: 0.1869 - accuracy: 0.9467 - 11ms/epoch - 5ms/step
# Epoch 93/200
# 2/2 - 0s - loss: 0.1844 - accuracy: 0.9467 - 15ms/epoch - 8ms/step
# Epoch 94/200
# 2/2 - 0s - loss: 0.1805 - accuracy: 0.9733 - 13ms/epoch - 6ms/step
# Epoch 95/200
# 2/2 - 0s - loss: 0.1777 - accuracy: 0.9467 - 14ms/epoch - 7ms/step
# Epoch 96/200
# 2/2 - 0s - loss: 0.1791 - accuracy: 0.9467 - 11ms/epoch - 6ms/step
# Epoch 97/200
# 2/2 - 0s - loss: 0.1774 - accuracy: 0.9467 - 11ms/epoch - 6ms/step
# Epoch 98/200
# 2/2 - 0s - loss: 0.1723 - accuracy: 0.9467 - 11ms/epoch - 6ms/step
# Epoch 99/200
# 2/2 - 0s - loss: 0.1697 - accuracy: 0.9467 - 11ms/epoch - 6ms/step
# Epoch 100/200
# 2/2 - 0s - loss: 0.1677 - accuracy: 0.9467 - 12ms/epoch - 6ms/step
# Epoch 101/200
# 2/2 - 0s - loss: 0.1686 - accuracy: 0.9467 - 11ms/epoch - 6ms/step
# Epoch 102/200
# 2/2 - 0s - loss: 0.1640 - accuracy: 0.9600 - 12ms/epoch - 6ms/step
# Epoch 103/200
# 2/2 - 0s - loss: 0.1632 - accuracy: 0.9733 - 16ms/epoch - 8ms/step
# Epoch 104/200
# 2/2 - 0s - loss: 0.1652 - accuracy: 0.9733 - 12ms/epoch - 6ms/step
# Epoch 105/200
# 2/2 - 0s - loss: 0.1609 - accuracy: 0.9733 - 16ms/epoch - 8ms/step
# Epoch 106/200
# 2/2 - 0s - loss: 0.1681 - accuracy: 0.9333 - 17ms/epoch - 8ms/step
# Epoch 107/200
# 2/2 - 0s - loss: 0.1665 - accuracy: 0.9467 - 12ms/epoch - 6ms/step
# Epoch 108/200
# 2/2 - 0s - loss: 0.1547 - accuracy: 0.9600 - 13ms/epoch - 7ms/step
# Epoch 109/200
# 2/2 - 0s - loss: 0.1529 - accuracy: 0.9733 - 12ms/epoch - 6ms/step
# Epoch 110/200
# 2/2 - 0s - loss: 0.1602 - accuracy: 0.9600 - 11ms/epoch - 5ms/step
# Epoch 111/200
# 2/2 - 0s - loss: 0.1625 - accuracy: 0.9600 - 14ms/epoch - 7ms/step
# Epoch 112/200
# 2/2 - 0s - loss: 0.1580 - accuracy: 0.9600 - 11ms/epoch - 6ms/step
# Epoch 113/200
# 2/2 - 0s - loss: 0.1525 - accuracy: 0.9733 - 12ms/epoch - 6ms/step
# Epoch 114/200
# 2/2 - 0s - loss: 0.1453 - accuracy: 0.9733 - 14ms/epoch - 7ms/step
# Epoch 115/200
# 2/2 - 0s - loss: 0.1480 - accuracy: 0.9467 - 14ms/epoch - 7ms/step
# Epoch 116/200
# 2/2 - 0s - loss: 0.1496 - accuracy: 0.9333 - 17ms/epoch - 8ms/step
# Epoch 117/200
# 2/2 - 0s - loss: 0.1438 - accuracy: 0.9467 - 13ms/epoch - 6ms/step
# Epoch 118/200
# 2/2 - 0s - loss: 0.1408 - accuracy: 0.9733 - 13ms/epoch - 6ms/step
# Epoch 119/200
# 2/2 - 0s - loss: 0.1416 - accuracy: 0.9733 - 12ms/epoch - 6ms/step
# Epoch 120/200
# 2/2 - 0s - loss: 0.1397 - accuracy: 0.9733 - 11ms/epoch - 6ms/step
# Epoch 121/200
# 2/2 - 0s - loss: 0.1390 - accuracy: 0.9467 - 11ms/epoch - 6ms/step
# Epoch 122/200
# 2/2 - 0s - loss: 0.1392 - accuracy: 0.9467 - 11ms/epoch - 5ms/step
# Epoch 123/200
# 2/2 - 0s - loss: 0.1360 - accuracy: 0.9467 - 11ms/epoch - 6ms/step
# Epoch 124/200
# 2/2 - 0s - loss: 0.1346 - accuracy: 0.9733 - 11ms/epoch - 6ms/step
# Epoch 125/200
# 2/2 - 0s - loss: 0.1336 - accuracy: 0.9733 - 11ms/epoch - 6ms/step
# Epoch 126/200
# 2/2 - 0s - loss: 0.1316 - accuracy: 0.9733 - 14ms/epoch - 7ms/step
# Epoch 127/200
# 2/2 - 0s - loss: 0.1377 - accuracy: 0.9333 - 12ms/epoch - 6ms/step
# Epoch 128/200
# 2/2 - 0s - loss: 0.1351 - accuracy: 0.9467 - 22ms/epoch - 11ms/step
# Epoch 129/200
# 2/2 - 0s - loss: 0.1295 - accuracy: 0.9733 - 20ms/epoch - 10ms/step
# Epoch 130/200
# 2/2 - 0s - loss: 0.1279 - accuracy: 0.9733 - 14ms/epoch - 7ms/step
# Epoch 131/200
# 2/2 - 0s - loss: 0.1272 - accuracy: 0.9733 - 14ms/epoch - 7ms/step
# Epoch 132/200
# 2/2 - 0s - loss: 0.1270 - accuracy: 0.9467 - 12ms/epoch - 6ms/step
# Epoch 133/200
# 2/2 - 0s - loss: 0.1268 - accuracy: 0.9467 - 12ms/epoch - 6ms/step
# Epoch 134/200
# 2/2 - 0s - loss: 0.1257 - accuracy: 0.9467 - 12ms/epoch - 6ms/step
# Epoch 135/200
# 2/2 - 0s - loss: 0.1236 - accuracy: 0.9733 - 12ms/epoch - 6ms/step
# Epoch 136/200
# 2/2 - 0s - loss: 0.1226 - accuracy: 0.9733 - 12ms/epoch - 6ms/step
# Epoch 137/200
# 2/2 - 0s - loss: 0.1222 - accuracy: 0.9600 - 14ms/epoch - 7ms/step
# Epoch 138/200
# 2/2 - 0s - loss: 0.1229 - accuracy: 0.9467 - 14ms/epoch - 7ms/step
# Epoch 139/200
# 2/2 - 0s - loss: 0.1233 - accuracy: 0.9467 - 11ms/epoch - 6ms/step
# Epoch 140/200
# 2/2 - 0s - loss: 0.1206 - accuracy: 0.9467 - 16ms/epoch - 8ms/step
# Epoch 141/200
# 2/2 - 0s - loss: 0.1206 - accuracy: 0.9733 - 11ms/epoch - 6ms/step
# Epoch 142/200
# 2/2 - 0s - loss: 0.1185 - accuracy: 0.9733 - 12ms/epoch - 6ms/step
# Epoch 143/200
# 2/2 - 0s - loss: 0.1171 - accuracy: 0.9733 - 11ms/epoch - 5ms/step
# Epoch 144/200
# 2/2 - 0s - loss: 0.1197 - accuracy: 0.9467 - 18ms/epoch - 9ms/step
# Epoch 145/200
# 2/2 - 0s - loss: 0.1155 - accuracy: 0.9600 - 14ms/epoch - 7ms/step
# Epoch 146/200
# 2/2 - 0s - loss: 0.1176 - accuracy: 0.9733 - 15ms/epoch - 7ms/step
# Epoch 147/200
# 2/2 - 0s - loss: 0.1279 - accuracy: 0.9733 - 13ms/epoch - 7ms/step
# Epoch 148/200
# 2/2 - 0s - loss: 0.1236 - accuracy: 0.9733 - 13ms/epoch - 6ms/step
# Epoch 149/200
# 2/2 - 0s - loss: 0.1145 - accuracy: 0.9733 - 11ms/epoch - 6ms/step
# Epoch 150/200
# 2/2 - 0s - loss: 0.1439 - accuracy: 0.9333 - 13ms/epoch - 7ms/step
# Epoch 151/200
# 2/2 - 0s - loss: 0.1559 - accuracy: 0.9200 - 12ms/epoch - 6ms/step
# Epoch 152/200
# 2/2 - 0s - loss: 0.1294 - accuracy: 0.9333 - 12ms/epoch - 6ms/step
# Epoch 153/200
# 2/2 - 0s - loss: 0.1124 - accuracy: 0.9467 - 14ms/epoch - 7ms/step
# Epoch 154/200
# 2/2 - 0s - loss: 0.1158 - accuracy: 0.9733 - 11ms/epoch - 5ms/step
# Epoch 155/200
# 2/2 - 0s - loss: 0.1175 - accuracy: 0.9733 - 11ms/epoch - 5ms/step
# Epoch 156/200
# 2/2 - 0s - loss: 0.1131 - accuracy: 0.9733 - 11ms/epoch - 5ms/step
# Epoch 157/200
# 2/2 - 0s - loss: 0.1123 - accuracy: 0.9733 - 10ms/epoch - 5ms/step
# Epoch 158/200
# 2/2 - 0s - loss: 0.1120 - accuracy: 0.9733 - 10ms/epoch - 5ms/step
# Epoch 159/200
# 2/2 - 0s - loss: 0.1103 - accuracy: 0.9733 - 13ms/epoch - 6ms/step
# Epoch 160/200
# 2/2 - 0s - loss: 0.1094 - accuracy: 0.9733 - 15ms/epoch - 8ms/step
# Epoch 161/200
# 2/2 - 0s - loss: 0.1102 - accuracy: 0.9733 - 12ms/epoch - 6ms/step
# Epoch 162/200
# 2/2 - 0s - loss: 0.1074 - accuracy: 0.9733 - 13ms/epoch - 6ms/step
# Epoch 163/200
# 2/2 - 0s - loss: 0.1075 - accuracy: 0.9467 - 12ms/epoch - 6ms/step
# Epoch 164/200
# 2/2 - 0s - loss: 0.1095 - accuracy: 0.9333 - 12ms/epoch - 6ms/step
# Epoch 165/200
# 2/2 - 0s - loss: 0.1085 - accuracy: 0.9333 - 13ms/epoch - 7ms/step
# Epoch 166/200
# 2/2 - 0s - loss: 0.1064 - accuracy: 0.9467 - 12ms/epoch - 6ms/step
# Epoch 167/200
# 2/2 - 0s - loss: 0.1046 - accuracy: 0.9600 - 12ms/epoch - 6ms/step
# Epoch 168/200
# 2/2 - 0s - loss: 0.1031 - accuracy: 0.9733 - 12ms/epoch - 6ms/step
# Epoch 169/200
# 2/2 - 0s - loss: 0.1146 - accuracy: 0.9733 - 11ms/epoch - 6ms/step
# Epoch 170/200
# 2/2 - 0s - loss: 0.1221 - accuracy: 0.9733 - 13ms/epoch - 7ms/step
# Epoch 171/200
# 2/2 - 0s - loss: 0.1104 - accuracy: 0.9733 - 15ms/epoch - 8ms/step
# Epoch 172/200
# 2/2 - 0s - loss: 0.1027 - accuracy: 0.9733 - 16ms/epoch - 8ms/step
# Epoch 173/200
# 2/2 - 0s - loss: 0.1105 - accuracy: 0.9333 - 11ms/epoch - 5ms/step
# Epoch 174/200
# 2/2 - 0s - loss: 0.1161 - accuracy: 0.9333 - 12ms/epoch - 6ms/step
# Epoch 175/200
# 2/2 - 0s - loss: 0.1114 - accuracy: 0.9333 - 14ms/epoch - 7ms/step
# Epoch 176/200
# 2/2 - 0s - loss: 0.1106 - accuracy: 0.9467 - 11ms/epoch - 5ms/step
# Epoch 177/200
# 2/2 - 0s - loss: 0.1014 - accuracy: 0.9733 - 12ms/epoch - 6ms/step
# Epoch 178/200
# 2/2 - 0s - loss: 0.1012 - accuracy: 0.9467 - 10ms/epoch - 5ms/step
# Epoch 179/200
# 2/2 - 0s - loss: 0.1148 - accuracy: 0.9333 - 10ms/epoch - 5ms/step
# Epoch 180/200
# 2/2 - 0s - loss: 0.1207 - accuracy: 0.9333 - 10ms/epoch - 5ms/step
# Epoch 181/200
# 2/2 - 0s - loss: 0.1068 - accuracy: 0.9467 - 11ms/epoch - 6ms/step
# Epoch 182/200
# 2/2 - 0s - loss: 0.0983 - accuracy: 0.9733 - 10ms/epoch - 5ms/step
# Epoch 183/200
# 2/2 - 0s - loss: 0.1020 - accuracy: 0.9733 - 15ms/epoch - 7ms/step
# Epoch 184/200
# 2/2 - 0s - loss: 0.1143 - accuracy: 0.9733 - 15ms/epoch - 7ms/step
# Epoch 185/200
# 2/2 - 0s - loss: 0.0964 - accuracy: 0.9733 - 12ms/epoch - 6ms/step
# Epoch 186/200
# 2/2 - 0s - loss: 0.1236 - accuracy: 0.9333 - 14ms/epoch - 7ms/step
# Epoch 187/200
# 2/2 - 0s - loss: 0.1148 - accuracy: 0.9333 - 10ms/epoch - 5ms/step
# Epoch 188/200
# 2/2 - 0s - loss: 0.1050 - accuracy: 0.9733 - 9ms/epoch - 5ms/step
# Epoch 189/200
# 2/2 - 0s - loss: 0.1069 - accuracy: 0.9733 - 10ms/epoch - 5ms/step
# Epoch 190/200
# 2/2 - 0s - loss: 0.1051 - accuracy: 0.9733 - 11ms/epoch - 5ms/step
# Epoch 191/200
# 2/2 - 0s - loss: 0.0995 - accuracy: 0.9733 - 10ms/epoch - 5ms/step
# Epoch 192/200
# 2/2 - 0s - loss: 0.0959 - accuracy: 0.9733 - 18ms/epoch - 9ms/step
# Epoch 193/200
# 2/2 - 0s - loss: 0.0964 - accuracy: 0.9600 - 15ms/epoch - 7ms/step
# Epoch 194/200
# 2/2 - 0s - loss: 0.0964 - accuracy: 0.9600 - 15ms/epoch - 7ms/step
# Epoch 195/200
# 2/2 - 0s - loss: 0.0954 - accuracy: 0.9600 - 11ms/epoch - 6ms/step
# Epoch 196/200
# 2/2 - 0s - loss: 0.0972 - accuracy: 0.9733 - 11ms/epoch - 6ms/step
# Epoch 197/200
# 2/2 - 0s - loss: 0.0941 - accuracy: 0.9733 - 13ms/epoch - 6ms/step
# Epoch 198/200
# 2/2 - 0s - loss: 0.0965 - accuracy: 0.9600 - 10ms/epoch - 5ms/step
# Epoch 199/200
# 2/2 - 0s - loss: 0.1016 - accuracy: 0.9467 - 10ms/epoch - 5ms/step
# Epoch 200/200
# 2/2 - 0s - loss: 0.1044 - accuracy: 0.9467 - 10ms/epoch - 5ms/step
#
# Classification results:
# 3/3 - 0s - loss: 0.0964 - accuracy: 0.9600 - 164ms/epoch - 55ms/step
# 3/3 [==============================] - 0s 3ms/step
# [[26  0  0]
#  [ 0 25  0]
#  [ 0  3 21]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        26
#            1       0.89      1.00      0.94        25
#            2       1.00      0.88      0.93        24
#
#     accuracy                           0.96        75
#    macro avg       0.96      0.96      0.96        75
# weighted avg       0.96      0.96      0.96        75

# %% [markdown]
# **80/20 Split**

# %%
# preprocessing
y_train80_ord = label_encoder.fit_transform(y_train80) # can't use string as before -> assign unique integer to each class
y_test20_ord = label_encoder.fit_transform(y_test20)

x_train80_reshaped = x_train80.to_numpy().reshape(-1, input_size, 1)
x_test20_reshaped = x_test20.to_numpy().reshape(-1, input_size, 1)

# define model

model = Sequential([
    Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(input_size, 1)),
    MaxPooling1D(pool_size=2),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(output_size, activation='softmax')
])

model.summary()

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# training and testing

model.fit(x_train80_reshaped, y_train80_ord, epochs=200, batch_size=64, verbose=2)

print()
print('Classification results:')

loss, accuracy = model.evaluate(x_test20_reshaped, y_test20_ord, verbose=2)

model_pred = model.predict(x_test20_reshaped)

# print(model_pred)

model_pred_classes = np.argmax(model_pred, axis=1)

print(confusion_matrix(y_test20_ord, model_pred_classes))
print(classification_report(y_test20_ord, model_pred_classes))

iris_CNN_8020 = Classifier('CNN [in C1D P1D F 128 out]', accuracy, confusion_matrix(y_test20_ord, model_pred_classes), classification_report(y_test20_ord, model_pred_classes))
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 2, 64)             256
#
#  max_pooling1d_3 (MaxPoolin  (None, 1, 64)             0
#  g1D)
#
#  flatten_3 (Flatten)         (None, 64)                0
#
#  dense_24 (Dense)            (None, 128)               8320
#
#  dense_25 (Dense)            (None, 3)                 387
#
# =================================================================
# Total params: 8963 (35.01 KB)
# Trainable params: 8963 (35.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Epoch 1/200
# 2/2 - 1s - loss: 1.4838 - accuracy: 0.3417 - 806ms/epoch - 403ms/step
# Epoch 2/200
# 2/2 - 0s - loss: 1.3167 - accuracy: 0.3417 - 12ms/epoch - 6ms/step
# Epoch 3/200
# 2/2 - 0s - loss: 1.1798 - accuracy: 0.3417 - 10ms/epoch - 5ms/step
# Epoch 4/200
# 2/2 - 0s - loss: 1.0947 - accuracy: 0.3417 - 11ms/epoch - 6ms/step
# Epoch 5/200
# 2/2 - 0s - loss: 1.0169 - accuracy: 0.5083 - 12ms/epoch - 6ms/step
# Epoch 6/200
# 2/2 - 0s - loss: 0.9834 - accuracy: 0.6500 - 11ms/epoch - 6ms/step
# Epoch 7/200
# 2/2 - 0s - loss: 0.9611 - accuracy: 0.4667 - 13ms/epoch - 7ms/step
# Epoch 8/200
# 2/2 - 0s - loss: 0.9399 - accuracy: 0.4917 - 14ms/epoch - 7ms/step
# Epoch 9/200
# 2/2 - 0s - loss: 0.9171 - accuracy: 0.6083 - 12ms/epoch - 6ms/step
# Epoch 10/200
# 2/2 - 0s - loss: 0.8910 - accuracy: 0.6583 - 12ms/epoch - 6ms/step
# Epoch 11/200
# 2/2 - 0s - loss: 0.8612 - accuracy: 0.6583 - 13ms/epoch - 6ms/step
# Epoch 12/200
# 2/2 - 0s - loss: 0.8313 - accuracy: 0.6583 - 17ms/epoch - 8ms/step
# Epoch 13/200
# 2/2 - 0s - loss: 0.8035 - accuracy: 0.6583 - 11ms/epoch - 6ms/step
# Epoch 14/200
# 2/2 - 0s - loss: 0.7778 - accuracy: 0.6583 - 11ms/epoch - 5ms/step
# Epoch 15/200
# 2/2 - 0s - loss: 0.7537 - accuracy: 0.7333 - 11ms/epoch - 5ms/step
# Epoch 16/200
# 2/2 - 0s - loss: 0.7299 - accuracy: 0.8583 - 11ms/epoch - 6ms/step
# Epoch 17/200
# 2/2 - 0s - loss: 0.7075 - accuracy: 0.9417 - 11ms/epoch - 6ms/step
# Epoch 18/200
# 2/2 - 0s - loss: 0.6840 - accuracy: 0.9333 - 14ms/epoch - 7ms/step
# Epoch 19/200
# 2/2 - 0s - loss: 0.6609 - accuracy: 0.8833 - 12ms/epoch - 6ms/step
# Epoch 20/200
# 2/2 - 0s - loss: 0.6387 - accuracy: 0.8333 - 11ms/epoch - 6ms/step
# Epoch 21/200
# 2/2 - 0s - loss: 0.6183 - accuracy: 0.7583 - 11ms/epoch - 6ms/step
# Epoch 22/200
# 2/2 - 0s - loss: 0.5995 - accuracy: 0.7083 - 13ms/epoch - 6ms/step
# Epoch 23/200
# 2/2 - 0s - loss: 0.5801 - accuracy: 0.7083 - 11ms/epoch - 6ms/step
# Epoch 24/200
# 2/2 - 0s - loss: 0.5625 - accuracy: 0.7417 - 13ms/epoch - 6ms/step
# Epoch 25/200
# 2/2 - 0s - loss: 0.5462 - accuracy: 0.7750 - 11ms/epoch - 5ms/step
# Epoch 26/200
# 2/2 - 0s - loss: 0.5313 - accuracy: 0.8000 - 12ms/epoch - 6ms/step
# Epoch 27/200
# 2/2 - 0s - loss: 0.5176 - accuracy: 0.8167 - 11ms/epoch - 6ms/step
# Epoch 28/200
# 2/2 - 0s - loss: 0.5052 - accuracy: 0.8583 - 14ms/epoch - 7ms/step
# Epoch 29/200
# 2/2 - 0s - loss: 0.4929 - accuracy: 0.8667 - 11ms/epoch - 5ms/step
# Epoch 30/200
# 2/2 - 0s - loss: 0.4816 - accuracy: 0.8750 - 17ms/epoch - 8ms/step
# Epoch 31/200
# 2/2 - 0s - loss: 0.4710 - accuracy: 0.8750 - 19ms/epoch - 10ms/step
# Epoch 32/200
# 2/2 - 0s - loss: 0.4604 - accuracy: 0.8833 - 18ms/epoch - 9ms/step
# Epoch 33/200
# 2/2 - 0s - loss: 0.4504 - accuracy: 0.9083 - 12ms/epoch - 6ms/step
# Epoch 34/200
# 2/2 - 0s - loss: 0.4404 - accuracy: 0.9167 - 15ms/epoch - 7ms/step
# Epoch 35/200
# 2/2 - 0s - loss: 0.4319 - accuracy: 0.9250 - 11ms/epoch - 6ms/step
# Epoch 36/200
# 2/2 - 0s - loss: 0.4230 - accuracy: 0.9333 - 11ms/epoch - 6ms/step
# Epoch 37/200
# 2/2 - 0s - loss: 0.4150 - accuracy: 0.9250 - 12ms/epoch - 6ms/step
# Epoch 38/200
# 2/2 - 0s - loss: 0.4073 - accuracy: 0.9167 - 10ms/epoch - 5ms/step
# Epoch 39/200
# 2/2 - 0s - loss: 0.4000 - accuracy: 0.9167 - 14ms/epoch - 7ms/step
# Epoch 40/200
# 2/2 - 0s - loss: 0.3920 - accuracy: 0.9167 - 11ms/epoch - 5ms/step
# Epoch 41/200
# 2/2 - 0s - loss: 0.3839 - accuracy: 0.9250 - 13ms/epoch - 6ms/step
# Epoch 42/200
# 2/2 - 0s - loss: 0.3768 - accuracy: 0.9583 - 11ms/epoch - 5ms/step
# Epoch 43/200
# 2/2 - 0s - loss: 0.3705 - accuracy: 0.9667 - 11ms/epoch - 5ms/step
# Epoch 44/200
# 2/2 - 0s - loss: 0.3629 - accuracy: 0.9750 - 15ms/epoch - 8ms/step
# Epoch 45/200
# 2/2 - 0s - loss: 0.3563 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 46/200
# 2/2 - 0s - loss: 0.3486 - accuracy: 0.9750 - 12ms/epoch - 6ms/step
# Epoch 47/200
# 2/2 - 0s - loss: 0.3416 - accuracy: 0.9750 - 13ms/epoch - 6ms/step
# Epoch 48/200
# 2/2 - 0s - loss: 0.3347 - accuracy: 0.9750 - 12ms/epoch - 6ms/step
# Epoch 49/200
# 2/2 - 0s - loss: 0.3280 - accuracy: 0.9750 - 12ms/epoch - 6ms/step
# Epoch 50/200
# 2/2 - 0s - loss: 0.3210 - accuracy: 0.9750 - 13ms/epoch - 6ms/step
# Epoch 51/200
# 2/2 - 0s - loss: 0.3140 - accuracy: 0.9750 - 11ms/epoch - 6ms/step
# Epoch 52/200
# 2/2 - 0s - loss: 0.3079 - accuracy: 0.9583 - 11ms/epoch - 5ms/step
# Epoch 53/200
# 2/2 - 0s - loss: 0.3019 - accuracy: 0.9750 - 15ms/epoch - 7ms/step
# Epoch 54/200
# 2/2 - 0s - loss: 0.2948 - accuracy: 0.9833 - 11ms/epoch - 6ms/step
# Epoch 55/200
# 2/2 - 0s - loss: 0.2880 - accuracy: 0.9833 - 16ms/epoch - 8ms/step
# Epoch 56/200
# 2/2 - 0s - loss: 0.2820 - accuracy: 0.9833 - 14ms/epoch - 7ms/step
# Epoch 57/200
# 2/2 - 0s - loss: 0.2757 - accuracy: 0.9833 - 14ms/epoch - 7ms/step
# Epoch 58/200
# 2/2 - 0s - loss: 0.2695 - accuracy: 0.9833 - 14ms/epoch - 7ms/step
# Epoch 59/200
# 2/2 - 0s - loss: 0.2632 - accuracy: 0.9833 - 14ms/epoch - 7ms/step
# Epoch 60/200
# 2/2 - 0s - loss: 0.2574 - accuracy: 0.9833 - 13ms/epoch - 7ms/step
# Epoch 61/200
# 2/2 - 0s - loss: 0.2513 - accuracy: 0.9833 - 13ms/epoch - 6ms/step
# Epoch 62/200
# 2/2 - 0s - loss: 0.2469 - accuracy: 0.9833 - 15ms/epoch - 8ms/step
# Epoch 63/200
# 2/2 - 0s - loss: 0.2437 - accuracy: 0.9833 - 11ms/epoch - 6ms/step
# Epoch 64/200
# 2/2 - 0s - loss: 0.2361 - accuracy: 0.9583 - 12ms/epoch - 6ms/step
# Epoch 65/200
# 2/2 - 0s - loss: 0.2307 - accuracy: 0.9833 - 19ms/epoch - 9ms/step
# Epoch 66/200
# 2/2 - 0s - loss: 0.2254 - accuracy: 0.9833 - 13ms/epoch - 6ms/step
# Epoch 67/200
# 2/2 - 0s - loss: 0.2201 - accuracy: 0.9833 - 14ms/epoch - 7ms/step
# Epoch 68/200
# 2/2 - 0s - loss: 0.2150 - accuracy: 0.9833 - 14ms/epoch - 7ms/step
# Epoch 69/200
# 2/2 - 0s - loss: 0.2100 - accuracy: 0.9833 - 13ms/epoch - 7ms/step
# Epoch 70/200
# 2/2 - 0s - loss: 0.2060 - accuracy: 0.9833 - 13ms/epoch - 7ms/step
# Epoch 71/200
# 2/2 - 0s - loss: 0.2054 - accuracy: 0.9667 - 14ms/epoch - 7ms/step
# Epoch 72/200
# 2/2 - 0s - loss: 0.2023 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 73/200
# 2/2 - 0s - loss: 0.1935 - accuracy: 0.9833 - 11ms/epoch - 6ms/step
# Epoch 74/200
# 2/2 - 0s - loss: 0.1890 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
# Epoch 75/200
# 2/2 - 0s - loss: 0.1854 - accuracy: 0.9833 - 15ms/epoch - 7ms/step
# Epoch 76/200
# 2/2 - 0s - loss: 0.1821 - accuracy: 0.9833 - 13ms/epoch - 7ms/step
# Epoch 77/200
# 2/2 - 0s - loss: 0.1788 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 78/200
# 2/2 - 0s - loss: 0.1750 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 79/200
# 2/2 - 0s - loss: 0.1716 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 80/200
# 2/2 - 0s - loss: 0.1687 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 81/200
# 2/2 - 0s - loss: 0.1661 - accuracy: 0.9583 - 12ms/epoch - 6ms/step
# Epoch 82/200
# 2/2 - 0s - loss: 0.1620 - accuracy: 0.9833 - 13ms/epoch - 6ms/step
# Epoch 83/200
# 2/2 - 0s - loss: 0.1664 - accuracy: 0.9833 - 13ms/epoch - 7ms/step
# Epoch 84/200
# 2/2 - 0s - loss: 0.1571 - accuracy: 0.9833 - 14ms/epoch - 7ms/step
# Epoch 85/200
# 2/2 - 0s - loss: 0.1538 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 86/200
# 2/2 - 0s - loss: 0.1587 - accuracy: 0.9500 - 12ms/epoch - 6ms/step
# Epoch 87/200
# 2/2 - 0s - loss: 0.1523 - accuracy: 0.9667 - 14ms/epoch - 7ms/step
# Epoch 88/200
# 2/2 - 0s - loss: 0.1477 - accuracy: 0.9833 - 14ms/epoch - 7ms/step
# Epoch 89/200
# 2/2 - 0s - loss: 0.1469 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 90/200
# 2/2 - 0s - loss: 0.1432 - accuracy: 0.9833 - 18ms/epoch - 9ms/step
# Epoch 91/200
# 2/2 - 0s - loss: 0.1401 - accuracy: 0.9750 - 15ms/epoch - 7ms/step
# Epoch 92/200
# 2/2 - 0s - loss: 0.1388 - accuracy: 0.9667 - 16ms/epoch - 8ms/step
# Epoch 93/200
# 2/2 - 0s - loss: 0.1362 - accuracy: 0.9667 - 11ms/epoch - 6ms/step
# Epoch 94/200
# 2/2 - 0s - loss: 0.1349 - accuracy: 0.9833 - 11ms/epoch - 6ms/step
# Epoch 95/200
# 2/2 - 0s - loss: 0.1324 - accuracy: 0.9833 - 11ms/epoch - 6ms/step
# Epoch 96/200
# 2/2 - 0s - loss: 0.1304 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 97/200
# 2/2 - 0s - loss: 0.1295 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
# Epoch 98/200
# 2/2 - 0s - loss: 0.1271 - accuracy: 0.9667 - 14ms/epoch - 7ms/step
# Epoch 99/200
# 2/2 - 0s - loss: 0.1259 - accuracy: 0.9667 - 12ms/epoch - 6ms/step
# Epoch 100/200
# 2/2 - 0s - loss: 0.1238 - accuracy: 0.9833 - 13ms/epoch - 6ms/step
# Epoch 101/200
# 2/2 - 0s - loss: 0.1254 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 102/200
# 2/2 - 0s - loss: 0.1219 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 103/200
# 2/2 - 0s - loss: 0.1215 - accuracy: 0.9667 - 11ms/epoch - 6ms/step
# Epoch 104/200
# 2/2 - 0s - loss: 0.1188 - accuracy: 0.9667 - 11ms/epoch - 6ms/step
# Epoch 105/200
# 2/2 - 0s - loss: 0.1190 - accuracy: 0.9750 - 13ms/epoch - 7ms/step
# Epoch 106/200
# 2/2 - 0s - loss: 0.1166 - accuracy: 0.9833 - 11ms/epoch - 6ms/step
# Epoch 107/200
# 2/2 - 0s - loss: 0.1139 - accuracy: 0.9833 - 10ms/epoch - 5ms/step
# Epoch 108/200
# 2/2 - 0s - loss: 0.1135 - accuracy: 0.9750 - 11ms/epoch - 6ms/step
# Epoch 109/200
# 2/2 - 0s - loss: 0.1129 - accuracy: 0.9667 - 11ms/epoch - 5ms/step
# Epoch 110/200
# 2/2 - 0s - loss: 0.1105 - accuracy: 0.9667 - 12ms/epoch - 6ms/step
# Epoch 111/200
# 2/2 - 0s - loss: 0.1090 - accuracy: 0.9833 - 11ms/epoch - 6ms/step
# Epoch 112/200
# 2/2 - 0s - loss: 0.1092 - accuracy: 0.9833 - 14ms/epoch - 7ms/step
# Epoch 113/200
# 2/2 - 0s - loss: 0.1080 - accuracy: 0.9833 - 14ms/epoch - 7ms/step
# Epoch 114/200
# 2/2 - 0s - loss: 0.1075 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 115/200
# 2/2 - 0s - loss: 0.1063 - accuracy: 0.9667 - 12ms/epoch - 6ms/step
# Epoch 116/200
# 2/2 - 0s - loss: 0.1039 - accuracy: 0.9667 - 11ms/epoch - 6ms/step
# Epoch 117/200
# 2/2 - 0s - loss: 0.1037 - accuracy: 0.9833 - 11ms/epoch - 6ms/step
# Epoch 118/200
# 2/2 - 0s - loss: 0.1027 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 119/200
# 2/2 - 0s - loss: 0.1013 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 120/200
# 2/2 - 0s - loss: 0.1002 - accuracy: 0.9833 - 11ms/epoch - 6ms/step
# Epoch 121/200
# 2/2 - 0s - loss: 0.1006 - accuracy: 0.9667 - 13ms/epoch - 6ms/step
# Epoch 122/200
# 2/2 - 0s - loss: 0.0989 - accuracy: 0.9750 - 11ms/epoch - 6ms/step
# Epoch 123/200
# 2/2 - 0s - loss: 0.0975 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
# Epoch 124/200
# 2/2 - 0s - loss: 0.0974 - accuracy: 0.9833 - 15ms/epoch - 8ms/step
# Epoch 125/200
# 2/2 - 0s - loss: 0.0963 - accuracy: 0.9833 - 15ms/epoch - 8ms/step
# Epoch 126/200
# 2/2 - 0s - loss: 0.0959 - accuracy: 0.9750 - 13ms/epoch - 6ms/step
# Epoch 127/200
# 2/2 - 0s - loss: 0.0965 - accuracy: 0.9750 - 13ms/epoch - 6ms/step
# Epoch 128/200
# 2/2 - 0s - loss: 0.0937 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 129/200
# 2/2 - 0s - loss: 0.0956 - accuracy: 0.9833 - 15ms/epoch - 7ms/step
# Epoch 130/200
# 2/2 - 0s - loss: 0.0935 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 131/200
# 2/2 - 0s - loss: 0.0914 - accuracy: 0.9833 - 14ms/epoch - 7ms/step
# Epoch 132/200
# 2/2 - 0s - loss: 0.0915 - accuracy: 0.9667 - 13ms/epoch - 6ms/step
# Epoch 133/200
# 2/2 - 0s - loss: 0.0905 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
# Epoch 134/200
# 2/2 - 0s - loss: 0.0894 - accuracy: 0.9833 - 11ms/epoch - 6ms/step
# Epoch 135/200
# 2/2 - 0s - loss: 0.0893 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
# Epoch 136/200
# 2/2 - 0s - loss: 0.0895 - accuracy: 0.9833 - 18ms/epoch - 9ms/step
# Epoch 137/200
# 2/2 - 0s - loss: 0.0885 - accuracy: 0.9833 - 10ms/epoch - 5ms/step
# Epoch 138/200
# 2/2 - 0s - loss: 0.0872 - accuracy: 0.9833 - 10ms/epoch - 5ms/step
# Epoch 139/200
# 2/2 - 0s - loss: 0.0925 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
# Epoch 140/200
# 2/2 - 0s - loss: 0.0875 - accuracy: 0.9833 - 11ms/epoch - 6ms/step
# Epoch 141/200
# 2/2 - 0s - loss: 0.0853 - accuracy: 0.9833 - 11ms/epoch - 6ms/step
# Epoch 142/200
# 2/2 - 0s - loss: 0.0853 - accuracy: 0.9750 - 10ms/epoch - 5ms/step
# Epoch 143/200
# 2/2 - 0s - loss: 0.0850 - accuracy: 0.9667 - 10ms/epoch - 5ms/step
# Epoch 144/200
# 2/2 - 0s - loss: 0.0855 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
# Epoch 145/200
# 2/2 - 0s - loss: 0.0841 - accuracy: 0.9833 - 11ms/epoch - 6ms/step
# Epoch 146/200
# 2/2 - 0s - loss: 0.0825 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
# Epoch 147/200
# 2/2 - 0s - loss: 0.0832 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
# Epoch 148/200
# 2/2 - 0s - loss: 0.0817 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
# Epoch 149/200
# 2/2 - 0s - loss: 0.0824 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
# Epoch 150/200
# 2/2 - 0s - loss: 0.0815 - accuracy: 0.9833 - 13ms/epoch - 6ms/step
# Epoch 151/200
# 2/2 - 0s - loss: 0.0804 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
# Epoch 152/200
# 2/2 - 0s - loss: 0.0805 - accuracy: 0.9833 - 13ms/epoch - 6ms/step
# Epoch 153/200
# 2/2 - 0s - loss: 0.0793 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
# Epoch 154/200
# 2/2 - 0s - loss: 0.0790 - accuracy: 0.9833 - 10ms/epoch - 5ms/step
# Epoch 155/200
# 2/2 - 0s - loss: 0.0807 - accuracy: 0.9833 - 14ms/epoch - 7ms/step
# Epoch 156/200
# 2/2 - 0s - loss: 0.0785 - accuracy: 0.9833 - 16ms/epoch - 8ms/step
# Epoch 157/200
# 2/2 - 0s - loss: 0.0776 - accuracy: 0.9833 - 10ms/epoch - 5ms/step
# Epoch 158/200
# 2/2 - 0s - loss: 0.0792 - accuracy: 0.9750 - 11ms/epoch - 5ms/step
# Epoch 159/200
# 2/2 - 0s - loss: 0.0769 - accuracy: 0.9833 - 13ms/epoch - 6ms/step
# Epoch 160/200
# 2/2 - 0s - loss: 0.0769 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 161/200
# 2/2 - 0s - loss: 0.0767 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
# Epoch 162/200
# 2/2 - 0s - loss: 0.0765 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 163/200
# 2/2 - 0s - loss: 0.0766 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 164/200
# 2/2 - 0s - loss: 0.0751 - accuracy: 0.9833 - 10ms/epoch - 5ms/step
# Epoch 165/200
# 2/2 - 0s - loss: 0.0746 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
# Epoch 166/200
# 2/2 - 0s - loss: 0.0771 - accuracy: 0.9833 - 13ms/epoch - 6ms/step
# Epoch 167/200
# 2/2 - 0s - loss: 0.0781 - accuracy: 0.9833 - 10ms/epoch - 5ms/step
# Epoch 168/200
# 2/2 - 0s - loss: 0.0749 - accuracy: 0.9667 - 11ms/epoch - 5ms/step
# Epoch 169/200
# 2/2 - 0s - loss: 0.0741 - accuracy: 0.9833 - 11ms/epoch - 6ms/step
# Epoch 170/200
# 2/2 - 0s - loss: 0.0729 - accuracy: 0.9833 - 10ms/epoch - 5ms/step
# Epoch 171/200
# 2/2 - 0s - loss: 0.0729 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 172/200
# 2/2 - 0s - loss: 0.0727 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
# Epoch 173/200
# 2/2 - 0s - loss: 0.0722 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
# Epoch 174/200
# 2/2 - 0s - loss: 0.0716 - accuracy: 0.9833 - 11ms/epoch - 6ms/step
# Epoch 175/200
# 2/2 - 0s - loss: 0.0719 - accuracy: 0.9833 - 11ms/epoch - 6ms/step
# Epoch 176/200
# 2/2 - 0s - loss: 0.0711 - accuracy: 0.9833 - 10ms/epoch - 5ms/step
# Epoch 177/200
# 2/2 - 0s - loss: 0.0706 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 178/200
# 2/2 - 0s - loss: 0.0719 - accuracy: 0.9833 - 11ms/epoch - 6ms/step
# Epoch 179/200
# 2/2 - 0s - loss: 0.0702 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 180/200
# 2/2 - 0s - loss: 0.0699 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 181/200
# 2/2 - 0s - loss: 0.0710 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
# Epoch 182/200
# 2/2 - 0s - loss: 0.0699 - accuracy: 0.9833 - 11ms/epoch - 6ms/step
# Epoch 183/200
# 2/2 - 0s - loss: 0.0716 - accuracy: 0.9833 - 15ms/epoch - 8ms/step
# Epoch 184/200
# 2/2 - 0s - loss: 0.0688 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
# Epoch 185/200
# 2/2 - 0s - loss: 0.0689 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
# Epoch 186/200
# 2/2 - 0s - loss: 0.0684 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
# Epoch 187/200
# 2/2 - 0s - loss: 0.0680 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
# Epoch 188/200
# 2/2 - 0s - loss: 0.0676 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 189/200
# 2/2 - 0s - loss: 0.0677 - accuracy: 0.9833 - 11ms/epoch - 6ms/step
# Epoch 190/200
# 2/2 - 0s - loss: 0.0673 - accuracy: 0.9833 - 14ms/epoch - 7ms/step
# Epoch 191/200
# 2/2 - 0s - loss: 0.0677 - accuracy: 0.9833 - 10ms/epoch - 5ms/step
# Epoch 192/200
# 2/2 - 0s - loss: 0.0668 - accuracy: 0.9833 - 11ms/epoch - 6ms/step
# Epoch 193/200
# 2/2 - 0s - loss: 0.0664 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
# Epoch 194/200
# 2/2 - 0s - loss: 0.0685 - accuracy: 0.9833 - 13ms/epoch - 6ms/step
# Epoch 195/200
# 2/2 - 0s - loss: 0.0677 - accuracy: 0.9833 - 13ms/epoch - 6ms/step
# Epoch 196/200
# 2/2 - 0s - loss: 0.0664 - accuracy: 0.9833 - 14ms/epoch - 7ms/step
# Epoch 197/200
# 2/2 - 0s - loss: 0.0654 - accuracy: 0.9833 - 13ms/epoch - 7ms/step
# Epoch 198/200
# 2/2 - 0s - loss: 0.0658 - accuracy: 0.9917 - 12ms/epoch - 6ms/step
# Epoch 199/200
# 2/2 - 0s - loss: 0.0678 - accuracy: 0.9833 - 12ms/epoch - 6ms/step
# Epoch 200/200
# 2/2 - 0s - loss: 0.0675 - accuracy: 0.9833 - 11ms/epoch - 5ms/step
#
# Classification results:
# 1/1 - 0s - loss: 0.0633 - accuracy: 0.9667 - 168ms/epoch - 168ms/step
# 1/1 [==============================] - 0s 85ms/step
# [[10  0  0]
#  [ 0  8  1]
#  [ 0  0 11]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      0.89      0.94         9
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.96      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# ## **Wine Dataset**
#
# The Wine dataset (1991) contains the results of a chemical analysis of wines grown in the same region in Italy but derived from three different cultivars. The analysis determined the quantities of 13 constituents found in each of the three types of wine. In total, there are 178 instances, each belonging to one of three different classes of wine.

# %%
wine = fetch_ucirepo(id=109)

# data (as pandas dataframes)
X = wine.data.features
y = wine.data.targets

# %%
# metadata
wine.metadata
# Out:
# {'uci_id': 109,
#  'name': 'Wine',
#  'repository_url': 'https://archive.ics.uci.edu/dataset/109/wine',
#  'data_url': 'https://archive.ics.uci.edu/static/public/109/data.csv',
#  'abstract': 'Using chemical analysis to determine the origin of wines',
#  'area': 'Physics and Chemistry',
#  'tasks': ['Classification'],
#  'characteristics': ['Tabular'],
#  'num_instances': 178,
#  'num_features': 13,
#  'feature_types': ['Integer', 'Real'],
#  'demographics': [],
#  'target_col': ['class'],
#  'index_col': None,
#  'has_missing_values': 'no',
#  'missing_values_symbol': None,
#  'year_of_dataset_creation': 1992,
#  'last_updated': 'Mon Aug 28 2023',
#  'dataset_doi': '10.24432/C5PC7J',
#  'creators': ['Stefan Aeberhard', 'M. Forina'],
#  'intro_paper': {'title': 'Comparative analysis of statistical pattern recognition methods in high dimensional settings',
#   'authors': 'S. Aeberhard, D. Coomans, O. Vel',
#   'published_in': 'Pattern Recognition',
#   'year': 1994,
#   'url': 'https://www.semanticscholar.org/paper/83dc3e4030d7b9fbdbb4bde03ce12ab70ca10528',
#   'doi': '10.1016/0031-3203(94)90145-7'},
#  'additional_info': {'summary': 'These data are the results of a chemical analysis of wines grown in the same region in Italy but derived from three different cultivars. The analysis determined the quantities of 13 constituents found in each of the three types of wines. \r\n\r\nI think that the initial data set had around 30 variables, but for some reason I only have the 13 dimensional version. I had a list of what the 30 or so variables were, but a.)  I lost it, and b.), I would not know which 13 variables are included in the set.\r\n\r\nThe attributes are (dontated by Riccardo Leardi, riclea@anchem.unige.it )\r\n1) Alcohol\r\n2) Malic acid\r\n3) Ash\r\n4) Alcalinity of ash  \r\n5) Magnesium\r\n6) Total phenols\r\n7) Flavanoids\r\n8) Nonflavanoid phenols\r\n9) Proanthocyanins\r\n10)Color intensity\r\n11)Hue\r\n12)OD280/OD315 of diluted wines\r\n13)Proline \r\n\r\nIn a classification context, this is a well posed problem with "well behaved" class structures. A good data set for first testing of a new classifier, but not very challenging.           ',
#   'purpose': 'test',
#   'funded_by': None,
#   'instances_represent': None,
#   'recommended_data_splits': None,
#   'sensitive_data': None,
#   'preprocessing_description': None,
#   'variable_info': 'All attributes are continuous\r\n\t\r\nNo statistics available, but suggest to standardise variables for certain uses (e.g. for us with classifiers which are NOT scale invariant)\r\n\r\nNOTE: 1st attribute is class identifier (1-3)',
#   'citation': None}}

# %%
# variable information
wine.variables
# Out:
#                             name     role         type demographic  \
# 0                          class   Target  Categorical        None
# 1                        Alcohol  Feature   Continuous        None
# 2                      Malicacid  Feature   Continuous        None
# 3                            Ash  Feature   Continuous        None
# 4              Alcalinity_of_ash  Feature   Continuous        None
# 5                      Magnesium  Feature      Integer        None
# 6                  Total_phenols  Feature   Continuous        None
# 7                     Flavanoids  Feature   Continuous        None
# 8           Nonflavanoid_phenols  Feature   Continuous        None
# 9                Proanthocyanins  Feature   Continuous        None
# 10               Color_intensity  Feature   Continuous        None
# 11                           Hue  Feature   Continuous        None
# 12  0D280_0D315_of_diluted_wines  Feature   Continuous        None
# 13                       Proline  Feature      Integer        None
#
#    description units missing_values
# 0         None  None             no
# 1         None  None             no
# 2         None  None             no
# 3         None  None             no
# 4         None  None             no
# 5         None  None             no
# 6         None  None             no
# 7         None  None             no
# 8         None  None             no
# 9         None  None             no
# 10        None  None             no
# 11        None  None             no
# 12        None  None             no
# 13        None  None             no

# %%
X
# Out:
#      Alcohol  Malicacid   Ash  Alcalinity_of_ash  Magnesium  Total_phenols  \
# 0      14.23       1.71  2.43               15.6        127           2.80
# 1      13.20       1.78  2.14               11.2        100           2.65
# 2      13.16       2.36  2.67               18.6        101           2.80
# 3      14.37       1.95  2.50               16.8        113           3.85
# 4      13.24       2.59  2.87               21.0        118           2.80
# ..       ...        ...   ...                ...        ...            ...
# 173    13.71       5.65  2.45               20.5         95           1.68
# 174    13.40       3.91  2.48               23.0        102           1.80
# 175    13.27       4.28  2.26               20.0        120           1.59
# 176    13.17       2.59  2.37               20.0        120           1.65
# 177    14.13       4.10  2.74               24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_phenols  Proanthocyanins  Color_intensity   Hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      0D280_0D315_of_diluted_wines  Proline
# 0                            3.92     1065
# 1                            3.40     1050
# 2                            3.17     1185
# 3                            3.45     1480
# 4                            2.93      735
# ..                            ...      ...
# 173                          1.74      740
# 174                          1.56      750
# 175                          1.56      835
# 176                          1.62      840
# 177                          1.60      560
#
# [178 rows x 13 columns]

# %%
y
# Out:
#      class
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ..     ...
# 173      3
# 174      3
# 175      3
# 176      3
# 177      3
#
# [178 rows x 1 columns]

# %%
x_train50, x_test50, y_train50, y_test50 = train_test_split(X, y, test_size = 0.5, random_state = seed)
x_train80, x_test20, y_train80, y_test20 = train_test_split(X, y, test_size = 0.2, random_state = seed)

# %% [markdown]
# ### Decision Tree

# %% [markdown]
# **50 / 50 split**

# %%
model = tree.DecisionTreeClassifier()

model.fit(x_train50, y_train50.to_numpy().ravel())

model_pred = model.predict(x_test50)

print(confusion_matrix(y_test50, model_pred))
print(classification_report(y_test50, model_pred))

tree.plot_tree(model, feature_names = wine.data.headers, class_names = ['1', '2', '3'])

wine_tree_5050 = Classifier('Decision Tree 50/50', accuracy_score(y_test50, model_pred), confusion_matrix(y_test50, model_pred), classification_report(y_test50, model_pred))
# Out:
# [[26  4  0]
#  [ 0 33  3]
#  [ 0  2 21]]
#               precision    recall  f1-score   support
#
#            1       1.00      0.87      0.93        30
#            2       0.85      0.92      0.88        36
#            3       0.88      0.91      0.89        23
#
#     accuracy                           0.90        89
#    macro avg       0.91      0.90      0.90        89
# weighted avg       0.91      0.90      0.90        89

# %% [markdown]
# **80 / 20 split**

# %%
model = tree.DecisionTreeClassifier()

model.fit(x_train80, y_train80.to_numpy().ravel())

model_pred = model.predict(x_test20)

print(confusion_matrix(y_test20, model_pred))
print(classification_report(y_test20, model_pred))

tree.plot_tree(model, feature_names = wine.data.headers, class_names = ['1', '2', '3'])

wine_tree_8020 = Classifier('Decision Tree 80/20', accuracy_score(y_test20, model_pred), confusion_matrix(y_test20, model_pred), classification_report(y_test20, model_pred))
# Out:
# [[ 9  2  0]
#  [ 0 14  0]
#  [ 0  1 10]]
#               precision    recall  f1-score   support
#
#            1       1.00      0.82      0.90        11
#            2       0.82      1.00      0.90        14
#            3       1.00      0.91      0.95        11
#
#     accuracy                           0.92        36
#    macro avg       0.94      0.91      0.92        36
# weighted avg       0.93      0.92      0.92        36

# %% [markdown]
# ### Naive Bayes

# %% [markdown]
# **50 / 50 split**

# %%
model = GaussianNB()

model.fit(x_train50, y_train50.to_numpy().ravel())

model_pred = model.predict(x_test50)

print(confusion_matrix(y_test50, model_pred))
print(classification_report(y_test50, model_pred))

wine_bayes_5050 = Classifier('Naïve-Bayes 50/50', accuracy_score(y_test50, model_pred), confusion_matrix(y_test50, model_pred), classification_report(y_test50, model_pred))
# Out:
# [[28  2  0]
#  [ 0 36  0]
#  [ 0  1 22]]
#               precision    recall  f1-score   support
#
#            1       1.00      0.93      0.97        30
#            2       0.92      1.00      0.96        36
#            3       1.00      0.96      0.98        23
#
#     accuracy                           0.97        89
#    macro avg       0.97      0.96      0.97        89
# weighted avg       0.97      0.97      0.97        89

# %% [markdown]
# **80 / 20 split**

# %%
model = GaussianNB()

model.fit(x_train80, y_train80.to_numpy().ravel())

model_pred = model.predict(x_test20)

print(confusion_matrix(y_test20, model_pred))
print(classification_report(y_test20, model_pred))

wine_bayes_8020 = Classifier('Naïve-Bayes 80/20', accuracy_score(y_test20, model_pred), confusion_matrix(y_test20, model_pred), classification_report(y_test20, model_pred))
# Out:
# [[10  1  0]
#  [ 0 14  0]
#  [ 0  0 11]]
#               precision    recall  f1-score   support
#
#            1       1.00      0.91      0.95        11
#            2       0.93      1.00      0.97        14
#            3       1.00      1.00      1.00        11
#
#     accuracy                           0.97        36
#    macro avg       0.98      0.97      0.97        36
# weighted avg       0.97      0.97      0.97        36

# %% [markdown]
# ### K-nearest neighbors

# %% [markdown]
# **Visualization**

# %%
# taken from https://scikit-learn.org/stable/auto_examples/neighbors/plot_classification.html#sphx-glr-auto-examples-neighbors-plot-classification-py

x_trainvis = x_train50[['Flavanoids', 'Nonflavanoid_phenols']]
y_trainvis = y_train50

x_testvis = x_test50[['Flavanoids', 'Nonflavanoid_phenols']]
y_testvis = y_test50

label_encoder = LabelEncoder()
colors = label_encoder.fit_transform(y)

wine_knearest_vis = Pipeline(
    steps=[("scaler", StandardScaler()), ("knn", KNeighborsClassifier(n_neighbors=11))]
)

_, axs = plt.subplots(ncols=2, figsize=(12, 5))

for ax, weights in zip(axs, ("uniform", "distance")):
    wine_knearest_vis.set_params(knn__weights=weights).fit(x_trainvis, y_trainvis.to_numpy().ravel())
    disp = DecisionBoundaryDisplay.from_estimator(
        wine_knearest_vis,
        x_testvis,
        response_method="predict",
        plot_method="pcolormesh",
        xlabel="Flavanoids",
        ylabel="Nonflavanoid phenols",
        shading="auto",
        alpha=0.5,
        ax=ax,
    )
    scatter = disp.ax_.scatter(X.iloc[:, 6], X.iloc[:, 7], c=colors, edgecolors="k")
    disp.ax_.legend(
        scatter.legend_elements()[0],
        ['1', '2', '3'],
        loc="lower left",
        title="Classes",
    )
    _ = disp.ax_.set_title(
        f"3-Class classification\n(k={wine_knearest_vis[-1].n_neighbors}, weights={weights!r})"
    )

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# **50/50 Split**

# %%
model_pred = None
best_accuracy = -1
best_k = 0

for k in range(1, len(x_test50)):

    k_model = Pipeline(
        steps=[("scaler", StandardScaler()), ('knn', KNeighborsClassifier(k, weights = 'distance'))]
        # steps=[('knn', KNeighborsClassifier(k, weights = 'distance'))]
    )

    k_model.fit(x_train50, y_train50.to_numpy().ravel())

    k_model_pred = k_model.predict(x_test50)

    k_accuracy = accuracy_score(y_test50, k_model_pred)

    # print(f'> k({k}) accuracy: {k_accuracy}')

    if best_accuracy < k_accuracy:
        best_accuracy = k_accuracy
        model_pred = k_model_pred
        best_k = k

print()
print(f'> best k: {best_k}')
print(confusion_matrix(y_test50, model_pred))
print(classification_report(y_test50, model_pred))

wine_k_neighbors_5050 = Classifier(f'k({best_k})-neighbors 50/50', accuracy_score(y_test50, model_pred), confusion_matrix(y_test50, model_pred), classification_report(y_test50, model_pred))
# Out:
# > best k: 48
# [[30  0  0]
#  [ 0 36  0]
#  [ 0  0 23]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        30
#            2       1.00      1.00      1.00        36
#            3       1.00      1.00      1.00        23
#
#     accuracy                           1.00        89
#    macro avg       1.00      1.00      1.00        89
# weighted avg       1.00      1.00      1.00        89

# %% [markdown]
# **80/20 Split**

# %%
model_pred = None
best_accuracy = -1
best_k = 0

for k in range(1, len(x_test20)):

    k_model = Pipeline(
        steps=[("scaler", StandardScaler()), ('knn', KNeighborsClassifier(k, weights = 'distance'))]
        # steps=[('knn', KNeighborsClassifier(k, weights = 'distance'))]
    )

    k_model.fit(x_train80, y_train80.to_numpy().ravel())

    k_model_pred = k_model.predict(x_test20)

    k_accuracy = accuracy_score(y_test20, k_model_pred)

    # print(f'> k({k}) accuracy: {k_accuracy}')

    if best_accuracy < k_accuracy:
        best_accuracy = k_accuracy
        model_pred = k_model_pred
        best_k = k

print()
print(f'> best k: {best_k}')
print(confusion_matrix(y_test20, model_pred))
print(classification_report(y_test20, model_pred))

wine_k_neighbors_8020 = Classifier(f'k({best_k})-neighbors 80/20', accuracy_score(y_test20, model_pred), confusion_matrix(y_test20, model_pred), classification_report(y_test20, model_pred))
# Out:
# > best k: 21
# [[11  0  0]
#  [ 0 14  0]
#  [ 0  0 11]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        11
#            2       1.00      1.00      1.00        14
#            3       1.00      1.00      1.00        11
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36

# %% [markdown]
# ### SVM (linear kernel)

# %% [markdown]
# **50/50**

# %%
model = svm.SVC(kernel = 'linear', C = 1.0)

model.fit(x_train50, y_train50.to_numpy().ravel())

model_pred = model.predict(x_test50)

print(confusion_matrix(y_test50, model_pred))
print(classification_report(y_test50, model_pred))

wine_SVM_linear_5050 = Classifier('SVM (linear) 50/50', accuracy_score(y_test50, model_pred), confusion_matrix(y_test50, model_pred), classification_report(y_test50, model_pred))
# Out:
# [[27  3  0]
#  [ 1 34  1]
#  [ 0  1 22]]
#               precision    recall  f1-score   support
#
#            1       0.96      0.90      0.93        30
#            2       0.89      0.94      0.92        36
#            3       0.96      0.96      0.96        23
#
#     accuracy                           0.93        89
#    macro avg       0.94      0.93      0.94        89
# weighted avg       0.93      0.93      0.93        89

# %% [markdown]
# **80/20**

# %%
model = svm.SVC(kernel = 'linear', C = 1.0)

model.fit(x_train80, y_train80.to_numpy().ravel())

model_pred = model.predict(x_test20)

print(confusion_matrix(y_test20, model_pred))
print(classification_report(y_test20, model_pred))

wine_SVM_linear_8020 = Classifier('SVM (linear) 80/20', accuracy_score(y_test20, model_pred), confusion_matrix(y_test20, model_pred), classification_report(y_test20, model_pred))
# Out:
# [[ 9  2  0]
#  [ 0 14  0]
#  [ 0  1 10]]
#               precision    recall  f1-score   support
#
#            1       1.00      0.82      0.90        11
#            2       0.82      1.00      0.90        14
#            3       1.00      0.91      0.95        11
#
#     accuracy                           0.92        36
#    macro avg       0.94      0.91      0.92        36
# weighted avg       0.93      0.92      0.92        36

# %% [markdown]
# ### SVM (rbf)

# %% [markdown]
# **50/50**

# %%
C_range = np.logspace(-2, 10, 13)
gamma_range = np.logspace(-9, 3, 13)
param_grid = dict(gamma=gamma_range, C=C_range)
cv = StratifiedShuffleSplit(n_splits = 5, test_size = 0.5, random_state = seed)
grid = GridSearchCV(svm.SVC(), param_grid=param_grid, cv=cv)
grid.fit(X, y.to_numpy().ravel())

best_C = grid.best_params_['C']
best_gamma = grid.best_params_['gamma']

print(f'best params c:{best_C}, gamma: {best_gamma}')

model = svm.SVC(C = best_C, gamma = best_gamma)

model.fit(x_train50, y_train50.to_numpy().ravel())

model_pred = model.predict(x_test50)

print(confusion_matrix(y_test50, model_pred))
print(classification_report(y_test50, model_pred))

wine_SVM_rbf_5050 = Classifier('SVM (rbf) 50/50', accuracy_score(y_test50, model_pred), confusion_matrix(y_test50, model_pred), classification_report(y_test50, model_pred))
# Out:
# best params c:100000.0, gamma: 1e-06
# [[27  3  0]
#  [ 2 34  0]
#  [ 0  1 22]]
#               precision    recall  f1-score   support
#
#            1       0.93      0.90      0.92        30
#            2       0.89      0.94      0.92        36
#            3       1.00      0.96      0.98        23
#
#     accuracy                           0.93        89
#    macro avg       0.94      0.93      0.94        89
# weighted avg       0.93      0.93      0.93        89

# %%
scores = grid.cv_results_["mean_test_score"].reshape(len(C_range), len(gamma_range))

plt.figure(figsize=(8, 6))
plt.subplots_adjust(left=0.2, right=0.95, bottom=0.15, top=0.95)
plt.imshow(
    scores,
    interpolation="nearest",
    cmap=plt.cm.hot,
    norm=MidpointNormalize(vmin=0.2, midpoint=0.92),
)
plt.xlabel("gamma")
plt.ylabel("C")
plt.colorbar()
plt.xticks(np.arange(len(gamma_range)), gamma_range, rotation=45)
plt.yticks(np.arange(len(C_range)), C_range)
plt.title("Validation accuracy")
plt.show()

# %% [markdown]
# **80/20**

# %%
C_range = np.logspace(-2, 10, 13)
gamma_range = np.logspace(-9, 3, 13)
param_grid = dict(gamma=gamma_range, C=C_range)
cv = StratifiedShuffleSplit(n_splits = 5, test_size = 0.2, random_state = seed)
grid = GridSearchCV(svm.SVC(), param_grid=param_grid, cv=cv)
grid.fit(X, y.to_numpy().ravel())

best_C = grid.best_params_['C']
best_gamma = grid.best_params_['gamma']

print(f'best params c:{best_C}, gamma: {best_gamma}')

model = svm.SVC(C = best_C, gamma = best_gamma)

model.fit(x_train50, y_train50.to_numpy().ravel())

model_pred = model.predict(x_test50)

print(confusion_matrix(y_test50, model_pred))
print(classification_report(y_test50, model_pred))

wine_SVM_rbf_8020 = Classifier('SVM (rbf) 80/20', accuracy_score(y_test50, model_pred), confusion_matrix(y_test50, model_pred), classification_report(y_test50, model_pred))
# Out:
# best params c:10000000.0, gamma: 1e-08
# [[27  3  0]
#  [ 1 35  0]
#  [ 0  1 22]]
#               precision    recall  f1-score   support
#
#            1       0.96      0.90      0.93        30
#            2       0.90      0.97      0.93        36
#            3       1.00      0.96      0.98        23
#
#     accuracy                           0.94        89
#    macro avg       0.95      0.94      0.95        89
# weighted avg       0.95      0.94      0.94        89

# %%
scores = grid.cv_results_["mean_test_score"].reshape(len(C_range), len(gamma_range))

plt.figure(figsize=(8, 6))
plt.subplots_adjust(left=0.2, right=0.95, bottom=0.15, top=0.95)
plt.imshow(
    scores,
    interpolation="nearest",
    cmap=plt.cm.hot,
    norm=MidpointNormalize(vmin=0.2, midpoint=0.92),
)
plt.xlabel("gamma")
plt.ylabel("C")
plt.colorbar()
plt.xticks(np.arange(len(gamma_range)), gamma_range, rotation=45)
plt.yticks(np.arange(len(C_range)), C_range)
plt.title("Validation accuracy")
plt.show()

# %% [markdown]
# ### DNN

# %%
input_size = X.shape[1]
output_size = 3

#preprocessing
label_encoder = LabelEncoder()
scaler = StandardScaler()

# %% [markdown]
# **50/50 Split**

# %%
# preprocessing
y_train50_ord = label_encoder.fit_transform(y_train50) # can't use string as before -> assign unique integer to each class
y_test50_ord = label_encoder.fit_transform(y_test50)
x_train50_scaled = scaler.fit_transform(x_train50) # scale data to unit variance -> better results
x_test50_scaled = scaler.fit_transform(x_test50)

# define model

model = Sequential([
    Dense(64, activation='relu', input_shape=(input_size,)),
    Dense(64, activation='relu'),
    Dense(output_size, activation='softmax')
])

model.summary()

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# training and testing

model.fit(x_train50_scaled, y_train50_ord, epochs=100, batch_size=64, verbose=2)

print()
print('Classification results:')

loss, accuracy = model.evaluate(x_test50_scaled, y_test50_ord, verbose=2)

model_pred = model.predict(x_test50_scaled)

# print(model_pred)

model_pred_classes = np.argmax(model_pred, axis=1)

print(confusion_matrix(y_test50_ord, model_pred_classes))
print(classification_report(y_test50_ord, model_pred_classes))

wine_DNN_5050 = Classifier('DNN [in 64 64 out]', accuracy, confusion_matrix(y_test50_ord, model_pred_classes), classification_report(y_test50_ord, model_pred_classes))
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_26 (Dense)            (None, 64)                896
#
#  dense_27 (Dense)            (None, 64)                4160
#
#  dense_28 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 5251 (20.51 KB)
# Trainable params: 5251 (20.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 2/2 - 1s - loss: 1.0642 - accuracy: 0.4270 - 736ms/epoch - 368ms/step
# Epoch 2/100
# 2/2 - 0s - loss: 0.9545 - accuracy: 0.5955 - 12ms/epoch - 6ms/step
# Epoch 3/100
# 2/2 - 0s - loss: 0.8616 - accuracy: 0.6854 - 10ms/epoch - 5ms/step
# Epoch 4/100
# 2/2 - 0s - loss: 0.7771 - accuracy: 0.8202 - 10ms/epoch - 5ms/step
# Epoch 5/100
# 2/2 - 0s - loss: 0.6988 - accuracy: 0.8876 - 11ms/epoch - 6ms/step
# Epoch 6/100
# 2/2 - 0s - loss: 0.6278 - accuracy: 0.9326 - 10ms/epoch - 5ms/step
# Epoch 7/100
# 2/2 - 0s - loss: 0.5643 - accuracy: 0.9438 - 9ms/epoch - 5ms/step
# Epoch 8/100
# 2/2 - 0s - loss: 0.5054 - accuracy: 0.9438 - 11ms/epoch - 6ms/step
# Epoch 9/100
# 2/2 - 0s - loss: 0.4530 - accuracy: 0.9775 - 10ms/epoch - 5ms/step
# Epoch 10/100
# 2/2 - 0s - loss: 0.4053 - accuracy: 0.9775 - 10ms/epoch - 5ms/step
# Epoch 11/100
# 2/2 - 0s - loss: 0.3642 - accuracy: 0.9775 - 10ms/epoch - 5ms/step
# Epoch 12/100
# 2/2 - 0s - loss: 0.3266 - accuracy: 0.9775 - 12ms/epoch - 6ms/step
# Epoch 13/100
# 2/2 - 0s - loss: 0.2941 - accuracy: 0.9775 - 11ms/epoch - 5ms/step
# Epoch 14/100
# 2/2 - 0s - loss: 0.2658 - accuracy: 0.9775 - 10ms/epoch - 5ms/step
# Epoch 15/100
# 2/2 - 0s - loss: 0.2417 - accuracy: 0.9775 - 10ms/epoch - 5ms/step
# Epoch 16/100
# 2/2 - 0s - loss: 0.2202 - accuracy: 0.9775 - 10ms/epoch - 5ms/step
# Epoch 17/100
# 2/2 - 0s - loss: 0.2019 - accuracy: 0.9775 - 10ms/epoch - 5ms/step
# Epoch 18/100
# 2/2 - 0s - loss: 0.1861 - accuracy: 0.9775 - 11ms/epoch - 5ms/step
# Epoch 19/100
# 2/2 - 0s - loss: 0.1715 - accuracy: 0.9775 - 13ms/epoch - 6ms/step
# Epoch 20/100
# 2/2 - 0s - loss: 0.1583 - accuracy: 0.9775 - 11ms/epoch - 5ms/step
# Epoch 21/100
# 2/2 - 0s - loss: 0.1473 - accuracy: 0.9775 - 10ms/epoch - 5ms/step
# Epoch 22/100
# 2/2 - 0s - loss: 0.1370 - accuracy: 0.9775 - 10ms/epoch - 5ms/step
# Epoch 23/100
# 2/2 - 0s - loss: 0.1275 - accuracy: 0.9775 - 10ms/epoch - 5ms/step
# Epoch 24/100
# 2/2 - 0s - loss: 0.1193 - accuracy: 0.9888 - 13ms/epoch - 6ms/step
# Epoch 25/100
# 2/2 - 0s - loss: 0.1120 - accuracy: 0.9888 - 10ms/epoch - 5ms/step
# Epoch 26/100
# 2/2 - 0s - loss: 0.1049 - accuracy: 0.9888 - 9ms/epoch - 5ms/step
# Epoch 27/100
# 2/2 - 0s - loss: 0.0992 - accuracy: 0.9888 - 9ms/epoch - 5ms/step
# Epoch 28/100
# 2/2 - 0s - loss: 0.0930 - accuracy: 0.9888 - 9ms/epoch - 5ms/step
# Epoch 29/100
# 2/2 - 0s - loss: 0.0880 - accuracy: 0.9888 - 10ms/epoch - 5ms/step
# Epoch 30/100
# 2/2 - 0s - loss: 0.0834 - accuracy: 0.9888 - 9ms/epoch - 5ms/step
# Epoch 31/100
# 2/2 - 0s - loss: 0.0786 - accuracy: 0.9888 - 9ms/epoch - 5ms/step
# Epoch 32/100
# 2/2 - 0s - loss: 0.0746 - accuracy: 0.9888 - 11ms/epoch - 5ms/step
# Epoch 33/100
# 2/2 - 0s - loss: 0.0704 - accuracy: 0.9888 - 10ms/epoch - 5ms/step
# Epoch 34/100
# 2/2 - 0s - loss: 0.0668 - accuracy: 0.9888 - 10ms/epoch - 5ms/step
# Epoch 35/100
# 2/2 - 0s - loss: 0.0631 - accuracy: 0.9888 - 9ms/epoch - 5ms/step
# Epoch 36/100
# 2/2 - 0s - loss: 0.0599 - accuracy: 0.9888 - 11ms/epoch - 5ms/step
# Epoch 37/100
# 2/2 - 0s - loss: 0.0570 - accuracy: 0.9888 - 11ms/epoch - 6ms/step
# Epoch 38/100
# 2/2 - 0s - loss: 0.0539 - accuracy: 0.9888 - 10ms/epoch - 5ms/step
# Epoch 39/100
# 2/2 - 0s - loss: 0.0514 - accuracy: 0.9888 - 10ms/epoch - 5ms/step
# Epoch 40/100
# 2/2 - 0s - loss: 0.0489 - accuracy: 0.9888 - 10ms/epoch - 5ms/step
# Epoch 41/100
# 2/2 - 0s - loss: 0.0465 - accuracy: 0.9888 - 10ms/epoch - 5ms/step
# Epoch 42/100
# 2/2 - 0s - loss: 0.0446 - accuracy: 0.9888 - 9ms/epoch - 5ms/step
# Epoch 43/100
# 2/2 - 0s - loss: 0.0427 - accuracy: 0.9888 - 9ms/epoch - 4ms/step
# Epoch 44/100
# 2/2 - 0s - loss: 0.0409 - accuracy: 0.9888 - 9ms/epoch - 5ms/step
# Epoch 45/100
# 2/2 - 0s - loss: 0.0392 - accuracy: 0.9888 - 9ms/epoch - 5ms/step
# Epoch 46/100
# 2/2 - 0s - loss: 0.0377 - accuracy: 0.9888 - 12ms/epoch - 6ms/step
# Epoch 47/100
# 2/2 - 0s - loss: 0.0360 - accuracy: 1.0000 - 10ms/epoch - 5ms/step
# Epoch 48/100
# 2/2 - 0s - loss: 0.0345 - accuracy: 1.0000 - 10ms/epoch - 5ms/step
# Epoch 49/100
# 2/2 - 0s - loss: 0.0331 - accuracy: 1.0000 - 11ms/epoch - 6ms/step
# Epoch 50/100
# 2/2 - 0s - loss: 0.0315 - accuracy: 1.0000 - 13ms/epoch - 6ms/step
# Epoch 51/100
# 2/2 - 0s - loss: 0.0303 - accuracy: 1.0000 - 11ms/epoch - 5ms/step
# Epoch 52/100
# 2/2 - 0s - loss: 0.0290 - accuracy: 1.0000 - 10ms/epoch - 5ms/step
# Epoch 53/100
# 2/2 - 0s - loss: 0.0278 - accuracy: 1.0000 - 10ms/epoch - 5ms/step
# Epoch 54/100
# 2/2 - 0s - loss: 0.0267 - accuracy: 1.0000 - 10ms/epoch - 5ms/step
# Epoch 55/100
# 2/2 - 0s - loss: 0.0257 - accuracy: 1.0000 - 10ms/epoch - 5ms/step
# Epoch 56/100
# 2/2 - 0s - loss: 0.0246 - accuracy: 1.0000 - 10ms/epoch - 5ms/step
# Epoch 57/100
# 2/2 - 0s - loss: 0.0237 - accuracy: 1.0000 - 11ms/epoch - 6ms/step
# Epoch 58/100
# 2/2 - 0s - loss: 0.0229 - accuracy: 1.0000 - 16ms/epoch - 8ms/step
# Epoch 59/100
# 2/2 - 0s - loss: 0.0220 - accuracy: 1.0000 - 11ms/epoch - 6ms/step
# Epoch 60/100
# 2/2 - 0s - loss: 0.0213 - accuracy: 1.0000 - 11ms/epoch - 5ms/step
# Epoch 61/100
# 2/2 - 0s - loss: 0.0205 - accuracy: 1.0000 - 10ms/epoch - 5ms/step
# Epoch 62/100
# 2/2 - 0s - loss: 0.0198 - accuracy: 1.0000 - 11ms/epoch - 6ms/step
# Epoch 63/100
# 2/2 - 0s - loss: 0.0191 - accuracy: 1.0000 - 11ms/epoch - 6ms/step
# Epoch 64/100
# 2/2 - 0s - loss: 0.0184 - accuracy: 1.0000 - 10ms/epoch - 5ms/step
# Epoch 65/100
# 2/2 - 0s - loss: 0.0178 - accuracy: 1.0000 - 9ms/epoch - 5ms/step
# Epoch 66/100
# 2/2 - 0s - loss: 0.0172 - accuracy: 1.0000 - 9ms/epoch - 5ms/step
# Epoch 67/100
# 2/2 - 0s - loss: 0.0167 - accuracy: 1.0000 - 10ms/epoch - 5ms/step
# Epoch 68/100
# 2/2 - 0s - loss: 0.0161 - accuracy: 1.0000 - 10ms/epoch - 5ms/step
# Epoch 69/100
# 2/2 - 0s - loss: 0.0156 - accuracy: 1.0000 - 12ms/epoch - 6ms/step
# Epoch 70/100
# 2/2 - 0s - loss: 0.0151 - accuracy: 1.0000 - 9ms/epoch - 5ms/step
# Epoch 71/100
# 2/2 - 0s - loss: 0.0147 - accuracy: 1.0000 - 9ms/epoch - 4ms/step
# Epoch 72/100
# 2/2 - 0s - loss: 0.0143 - accuracy: 1.0000 - 12ms/epoch - 6ms/step
# Epoch 73/100
# 2/2 - 0s - loss: 0.0139 - accuracy: 1.0000 - 10ms/epoch - 5ms/step
# Epoch 74/100
# 2/2 - 0s - loss: 0.0135 - accuracy: 1.0000 - 12ms/epoch - 6ms/step
# Epoch 75/100
# 2/2 - 0s - loss: 0.0131 - accuracy: 1.0000 - 12ms/epoch - 6ms/step
# Epoch 76/100
# 2/2 - 0s - loss: 0.0127 - accuracy: 1.0000 - 14ms/epoch - 7ms/step
# Epoch 77/100
# 2/2 - 0s - loss: 0.0123 - accuracy: 1.0000 - 10ms/epoch - 5ms/step
# Epoch 78/100
# 2/2 - 0s - loss: 0.0120 - accuracy: 1.0000 - 10ms/epoch - 5ms/step
# Epoch 79/100
# 2/2 - 0s - loss: 0.0117 - accuracy: 1.0000 - 11ms/epoch - 6ms/step
# Epoch 80/100
# 2/2 - 0s - loss: 0.0113 - accuracy: 1.0000 - 10ms/epoch - 5ms/step
# Epoch 81/100
# 2/2 - 0s - loss: 0.0110 - accuracy: 1.0000 - 10ms/epoch - 5ms/step
# Epoch 82/100
# 2/2 - 0s - loss: 0.0108 - accuracy: 1.0000 - 10ms/epoch - 5ms/step
# Epoch 83/100
# 2/2 - 0s - loss: 0.0105 - accuracy: 1.0000 - 11ms/epoch - 5ms/step
# Epoch 84/100
# 2/2 - 0s - loss: 0.0102 - accuracy: 1.0000 - 16ms/epoch - 8ms/step
# Epoch 85/100
# 2/2 - 0s - loss: 0.0100 - accuracy: 1.0000 - 13ms/epoch - 6ms/step
# Epoch 86/100
# 2/2 - 0s - loss: 0.0097 - accuracy: 1.0000 - 14ms/epoch - 7ms/step
# Epoch 87/100
# 2/2 - 0s - loss: 0.0095 - accuracy: 1.0000 - 12ms/epoch - 6ms/step
# Epoch 88/100
# 2/2 - 0s - loss: 0.0092 - accuracy: 1.0000 - 13ms/epoch - 7ms/step
# Epoch 89/100
# 2/2 - 0s - loss: 0.0090 - accuracy: 1.0000 - 14ms/epoch - 7ms/step
# Epoch 90/100
# 2/2 - 0s - loss: 0.0088 - accuracy: 1.0000 - 13ms/epoch - 6ms/step
# Epoch 91/100
# 2/2 - 0s - loss: 0.0086 - accuracy: 1.0000 - 12ms/epoch - 6ms/step
# Epoch 92/100
# 2/2 - 0s - loss: 0.0084 - accuracy: 1.0000 - 15ms/epoch - 8ms/step
# Epoch 93/100
# 2/2 - 0s - loss: 0.0082 - accuracy: 1.0000 - 12ms/epoch - 6ms/step
# Epoch 94/100
# 2/2 - 0s - loss: 0.0080 - accuracy: 1.0000 - 13ms/epoch - 7ms/step
# Epoch 95/100
# 2/2 - 0s - loss: 0.0078 - accuracy: 1.0000 - 15ms/epoch - 8ms/step
# Epoch 96/100
# 2/2 - 0s - loss: 0.0077 - accuracy: 1.0000 - 13ms/epoch - 7ms/step
# Epoch 97/100
# 2/2 - 0s - loss: 0.0075 - accuracy: 1.0000 - 15ms/epoch - 8ms/step
# Epoch 98/100
# 2/2 - 0s - loss: 0.0073 - accuracy: 1.0000 - 13ms/epoch - 7ms/step
# Epoch 99/100
# 2/2 - 0s - loss: 0.0072 - accuracy: 1.0000 - 13ms/epoch - 6ms/step
# Epoch 100/100
# 2/2 - 0s - loss: 0.0070 - accuracy: 1.0000 - 14ms/epoch - 7ms/step
#
# Classification results:
# 3/3 - 0s - loss: 0.0365 - accuracy: 0.9888 - 218ms/epoch - 73ms/step
# 3/3 [==============================] - 0s 3ms/step
# [[30  0  0]
#  [ 0 35  1]
#  [ 0  0 23]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        30
#            1       1.00      0.97      0.99        36
#            2       0.96      1.00      0.98        23
#
#     accuracy                           0.99        89
#    macro avg       0.99      0.99      0.99        89
# weighted avg       0.99      0.99      0.99        89

# %% [markdown]
# **80/20 Split**

# %%
# preprocessing
y_train80_ord = label_encoder.fit_transform(y_train80) # can't use string as before -> assign unique integer to each class
y_test20_ord = label_encoder.fit_transform(y_test20)
x_train80_scaled = scaler.fit_transform(x_train80) # scale data to unit variance -> better results
x_test20_scaled = scaler.fit_transform(x_test20)

# define model

model = Sequential([
    Dense(64, activation='relu', input_shape=(input_size,)),
    Dense(64, activation='relu'),
    Dense(output_size, activation='softmax')
])

model.summary()

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# training and testing

model.fit(x_train80_scaled, y_train80_ord, epochs=100, batch_size=64, verbose=2)

print()
print('Classification results:')

loss, accuracy = model.evaluate(x_test20_scaled, y_test20_ord, verbose=2)

model_pred = model.predict(x_test20_scaled)

# print(model_pred)

model_pred_classes = np.argmax(model_pred, axis=1)

print(confusion_matrix(y_test20_ord, model_pred_classes))
print(classification_report(y_test20_ord, model_pred_classes))

wine_DNN_8020 = Classifier('DNN [in 64 64 out]', accuracy, confusion_matrix(y_test20_ord, model_pred_classes), classification_report(y_test20_ord, model_pred_classes))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_29 (Dense)            (None, 64)                896
#
#  dense_30 (Dense)            (None, 64)                4160
#
#  dense_31 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 5251 (20.51 KB)
# Trainable params: 5251 (20.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 3/3 - 1s - loss: 1.2999 - accuracy: 0.0775 - 997ms/epoch - 332ms/step
# Epoch 2/100
# 3/3 - 0s - loss: 1.1366 - accuracy: 0.2183 - 14ms/epoch - 5ms/step
# Epoch 3/100
# 3/3 - 0s - loss: 1.0019 - accuracy: 0.6127 - 14ms/epoch - 5ms/step
# Epoch 4/100
# 3/3 - 0s - loss: 0.8823 - accuracy: 0.7887 - 16ms/epoch - 5ms/step
# Epoch 5/100
# 3/3 - 0s - loss: 0.7771 - accuracy: 0.8662 - 17ms/epoch - 6ms/step
# Epoch 6/100
# 3/3 - 0s - loss: 0.6854 - accuracy: 0.9366 - 15ms/epoch - 5ms/step
# Epoch 7/100
# 3/3 - 0s - loss: 0.6047 - accuracy: 0.9648 - 15ms/epoch - 5ms/step
# Epoch 8/100
# 3/3 - 0s - loss: 0.5317 - accuracy: 0.9789 - 17ms/epoch - 6ms/step
# Epoch 9/100
# 3/3 - 0s - loss: 0.4669 - accuracy: 0.9789 - 14ms/epoch - 5ms/step
# Epoch 10/100
# 3/3 - 0s - loss: 0.4100 - accuracy: 0.9859 - 17ms/epoch - 6ms/step
# Epoch 11/100
# 3/3 - 0s - loss: 0.3586 - accuracy: 0.9859 - 13ms/epoch - 4ms/step
# Epoch 12/100
# 3/3 - 0s - loss: 0.3138 - accuracy: 0.9859 - 16ms/epoch - 5ms/step
# Epoch 13/100
# 3/3 - 0s - loss: 0.2746 - accuracy: 0.9859 - 16ms/epoch - 5ms/step
# Epoch 14/100
# 3/3 - 0s - loss: 0.2400 - accuracy: 0.9859 - 16ms/epoch - 5ms/step
# Epoch 15/100
# 3/3 - 0s - loss: 0.2100 - accuracy: 0.9859 - 15ms/epoch - 5ms/step
# Epoch 16/100
# 3/3 - 0s - loss: 0.1853 - accuracy: 0.9859 - 16ms/epoch - 5ms/step
# Epoch 17/100
# 3/3 - 0s - loss: 0.1630 - accuracy: 0.9859 - 14ms/epoch - 5ms/step
# Epoch 18/100
# 3/3 - 0s - loss: 0.1448 - accuracy: 0.9859 - 14ms/epoch - 5ms/step
# Epoch 19/100
# 3/3 - 0s - loss: 0.1284 - accuracy: 0.9859 - 15ms/epoch - 5ms/step
# Epoch 20/100
# 3/3 - 0s - loss: 0.1151 - accuracy: 0.9859 - 13ms/epoch - 4ms/step
# Epoch 21/100
# 3/3 - 0s - loss: 0.1030 - accuracy: 0.9859 - 14ms/epoch - 5ms/step
# Epoch 22/100
# 3/3 - 0s - loss: 0.0930 - accuracy: 0.9930 - 15ms/epoch - 5ms/step
# Epoch 23/100
# 3/3 - 0s - loss: 0.0845 - accuracy: 0.9930 - 14ms/epoch - 5ms/step
# Epoch 24/100
# 3/3 - 0s - loss: 0.0767 - accuracy: 1.0000 - 14ms/epoch - 5ms/step
# Epoch 25/100
# 3/3 - 0s - loss: 0.0702 - accuracy: 1.0000 - 15ms/epoch - 5ms/step
# Epoch 26/100
# 3/3 - 0s - loss: 0.0642 - accuracy: 1.0000 - 14ms/epoch - 5ms/step
# Epoch 27/100
# 3/3 - 0s - loss: 0.0591 - accuracy: 1.0000 - 15ms/epoch - 5ms/step
# Epoch 28/100
# 3/3 - 0s - loss: 0.0544 - accuracy: 1.0000 - 13ms/epoch - 4ms/step
# Epoch 29/100
# 3/3 - 0s - loss: 0.0504 - accuracy: 1.0000 - 19ms/epoch - 6ms/step
# Epoch 30/100
# 3/3 - 0s - loss: 0.0469 - accuracy: 1.0000 - 14ms/epoch - 5ms/step
# Epoch 31/100
# 3/3 - 0s - loss: 0.0438 - accuracy: 1.0000 - 15ms/epoch - 5ms/step
# Epoch 32/100
# 3/3 - 0s - loss: 0.0410 - accuracy: 1.0000 - 15ms/epoch - 5ms/step
# Epoch 33/100
# 3/3 - 0s - loss: 0.0384 - accuracy: 1.0000 - 13ms/epoch - 4ms/step
# Epoch 34/100
# 3/3 - 0s - loss: 0.0361 - accuracy: 1.0000 - 12ms/epoch - 4ms/step
# Epoch 35/100
# 3/3 - 0s - loss: 0.0341 - accuracy: 1.0000 - 19ms/epoch - 6ms/step
# Epoch 36/100
# 3/3 - 0s - loss: 0.0321 - accuracy: 1.0000 - 13ms/epoch - 4ms/step
# Epoch 37/100
# 3/3 - 0s - loss: 0.0304 - accuracy: 1.0000 - 14ms/epoch - 5ms/step
# Epoch 38/100
# 3/3 - 0s - loss: 0.0287 - accuracy: 1.0000 - 17ms/epoch - 6ms/step
# Epoch 39/100
# 3/3 - 0s - loss: 0.0272 - accuracy: 1.0000 - 14ms/epoch - 5ms/step
# Epoch 40/100
# 3/3 - 0s - loss: 0.0258 - accuracy: 1.0000 - 14ms/epoch - 5ms/step
# Epoch 41/100
# 3/3 - 0s - loss: 0.0245 - accuracy: 1.0000 - 14ms/epoch - 5ms/step
# Epoch 42/100
# 3/3 - 0s - loss: 0.0234 - accuracy: 1.0000 - 14ms/epoch - 5ms/step
# Epoch 43/100
# 3/3 - 0s - loss: 0.0221 - accuracy: 1.0000 - 13ms/epoch - 4ms/step
# Epoch 44/100
# 3/3 - 0s - loss: 0.0212 - accuracy: 1.0000 - 14ms/epoch - 5ms/step
# Epoch 45/100
# 3/3 - 0s - loss: 0.0201 - accuracy: 1.0000 - 21ms/epoch - 7ms/step
# Epoch 46/100
# 3/3 - 0s - loss: 0.0192 - accuracy: 1.0000 - 21ms/epoch - 7ms/step
# Epoch 47/100
# 3/3 - 0s - loss: 0.0184 - accuracy: 1.0000 - 12ms/epoch - 4ms/step
# Epoch 48/100
# 3/3 - 0s - loss: 0.0176 - accuracy: 1.0000 - 14ms/epoch - 5ms/step
# Epoch 49/100
# 3/3 - 0s - loss: 0.0169 - accuracy: 1.0000 - 13ms/epoch - 4ms/step
# Epoch 50/100
# 3/3 - 0s - loss: 0.0163 - accuracy: 1.0000 - 13ms/epoch - 4ms/step
# Epoch 51/100
# 3/3 - 0s - loss: 0.0154 - accuracy: 1.0000 - 16ms/epoch - 5ms/step
# Epoch 52/100
# 3/3 - 0s - loss: 0.0149 - accuracy: 1.0000 - 14ms/epoch - 5ms/step
# Epoch 53/100
# 3/3 - 0s - loss: 0.0142 - accuracy: 1.0000 - 13ms/epoch - 4ms/step
# Epoch 54/100
# 3/3 - 0s - loss: 0.0136 - accuracy: 1.0000 - 12ms/epoch - 4ms/step
# Epoch 55/100
# 3/3 - 0s - loss: 0.0131 - accuracy: 1.0000 - 12ms/epoch - 4ms/step
# Epoch 56/100
# 3/3 - 0s - loss: 0.0126 - accuracy: 1.0000 - 14ms/epoch - 5ms/step
# Epoch 57/100
# 3/3 - 0s - loss: 0.0121 - accuracy: 1.0000 - 15ms/epoch - 5ms/step
# Epoch 58/100
# 3/3 - 0s - loss: 0.0117 - accuracy: 1.0000 - 15ms/epoch - 5ms/step
# Epoch 59/100
# 3/3 - 0s - loss: 0.0112 - accuracy: 1.0000 - 18ms/epoch - 6ms/step
# Epoch 60/100
# 3/3 - 0s - loss: 0.0108 - accuracy: 1.0000 - 13ms/epoch - 4ms/step
# Epoch 61/100
# 3/3 - 0s - loss: 0.0104 - accuracy: 1.0000 - 13ms/epoch - 4ms/step
# Epoch 62/100
# 3/3 - 0s - loss: 0.0101 - accuracy: 1.0000 - 12ms/epoch - 4ms/step
# Epoch 63/100
# 3/3 - 0s - loss: 0.0097 - accuracy: 1.0000 - 11ms/epoch - 4ms/step
# Epoch 64/100
# 3/3 - 0s - loss: 0.0094 - accuracy: 1.0000 - 18ms/epoch - 6ms/step
# Epoch 65/100
# 3/3 - 0s - loss: 0.0091 - accuracy: 1.0000 - 12ms/epoch - 4ms/step
# Epoch 66/100
# 3/3 - 0s - loss: 0.0088 - accuracy: 1.0000 - 13ms/epoch - 4ms/step
# Epoch 67/100
# 3/3 - 0s - loss: 0.0085 - accuracy: 1.0000 - 13ms/epoch - 4ms/step
# Epoch 68/100
# 3/3 - 0s - loss: 0.0082 - accuracy: 1.0000 - 13ms/epoch - 4ms/step
# Epoch 69/100
# 3/3 - 0s - loss: 0.0079 - accuracy: 1.0000 - 12ms/epoch - 4ms/step
# Epoch 70/100
# 3/3 - 0s - loss: 0.0076 - accuracy: 1.0000 - 12ms/epoch - 4ms/step
# Epoch 71/100
# 3/3 - 0s - loss: 0.0074 - accuracy: 1.0000 - 12ms/epoch - 4ms/step
# Epoch 72/100
# 3/3 - 0s - loss: 0.0071 - accuracy: 1.0000 - 12ms/epoch - 4ms/step
# Epoch 73/100
# 3/3 - 0s - loss: 0.0069 - accuracy: 1.0000 - 13ms/epoch - 4ms/step
# Epoch 74/100
# 3/3 - 0s - loss: 0.0067 - accuracy: 1.0000 - 13ms/epoch - 4ms/step
# Epoch 75/100
# 3/3 - 0s - loss: 0.0065 - accuracy: 1.0000 - 13ms/epoch - 4ms/step
# Epoch 76/100
# 3/3 - 0s - loss: 0.0063 - accuracy: 1.0000 - 14ms/epoch - 5ms/step
# Epoch 77/100
# 3/3 - 0s - loss: 0.0062 - accuracy: 1.0000 - 15ms/epoch - 5ms/step
# Epoch 78/100
# 3/3 - 0s - loss: 0.0060 - accuracy: 1.0000 - 12ms/epoch - 4ms/step
# Epoch 79/100
# 3/3 - 0s - loss: 0.0059 - accuracy: 1.0000 - 12ms/epoch - 4ms/step
# Epoch 80/100
# 3/3 - 0s - loss: 0.0057 - accuracy: 1.0000 - 13ms/epoch - 4ms/step
# Epoch 81/100
# 3/3 - 0s - loss: 0.0055 - accuracy: 1.0000 - 12ms/epoch - 4ms/step
# Epoch 82/100
# 3/3 - 0s - loss: 0.0054 - accuracy: 1.0000 - 12ms/epoch - 4ms/step
# Epoch 83/100
# 3/3 - 0s - loss: 0.0052 - accuracy: 1.0000 - 11ms/epoch - 4ms/step
# Epoch 84/100
# 3/3 - 0s - loss: 0.0051 - accuracy: 1.0000 - 12ms/epoch - 4ms/step
# Epoch 85/100
# 3/3 - 0s - loss: 0.0050 - accuracy: 1.0000 - 15ms/epoch - 5ms/step
# Epoch 86/100
# 3/3 - 0s - loss: 0.0049 - accuracy: 1.0000 - 12ms/epoch - 4ms/step
# Epoch 87/100
# 3/3 - 0s - loss: 0.0047 - accuracy: 1.0000 - 12ms/epoch - 4ms/step
# Epoch 88/100
# 3/3 - 0s - loss: 0.0046 - accuracy: 1.0000 - 13ms/epoch - 4ms/step
# Epoch 89/100
# 3/3 - 0s - loss: 0.0045 - accuracy: 1.0000 - 12ms/epoch - 4ms/step
# Epoch 90/100
# 3/3 - 0s - loss: 0.0044 - accuracy: 1.0000 - 12ms/epoch - 4ms/step
# Epoch 91/100
# 3/3 - 0s - loss: 0.0043 - accuracy: 1.0000 - 14ms/epoch - 5ms/step
# Epoch 92/100
# 3/3 - 0s - loss: 0.0042 - accuracy: 1.0000 - 12ms/epoch - 4ms/step
# Epoch 93/100
# 3/3 - 0s - loss: 0.0041 - accuracy: 1.0000 - 11ms/epoch - 4ms/step
# Epoch 94/100
# 3/3 - 0s - loss: 0.0040 - accuracy: 1.0000 - 11ms/epoch - 4ms/step
# Epoch 95/100
# 3/3 - 0s - loss: 0.0040 - accuracy: 1.0000 - 14ms/epoch - 5ms/step
# Epoch 96/100
# 3/3 - 0s - loss: 0.0039 - accuracy: 1.0000 - 11ms/epoch - 4ms/step
# Epoch 97/100
# 3/3 - 0s - loss: 0.0038 - accuracy: 1.0000 - 12ms/epoch - 4ms/step
# Epoch 98/100
# 3/3 - 0s - loss: 0.0037 - accuracy: 1.0000 - 13ms/epoch - 4ms/step
# Epoch 99/100
# 3/3 - 0s - loss: 0.0036 - accuracy: 1.0000 - 11ms/epoch - 4ms/step
# Epoch 100/100
# 3/3 - 0s - loss: 0.0035 - accuracy: 1.0000 - 12ms/epoch - 4ms/step
#
# Classification results:
# 2/2 - 0s - loss: 0.0490 - accuracy: 0.9722 - 165ms/epoch - 83ms/step
# 2/2 [==============================] - 0s 6ms/step
# [[11  0  0]
#  [ 0 13  1]
#  [ 0  0 11]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      0.93      0.96        14
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.97        36
#    macro avg       0.97      0.98      0.97        36
# weighted avg       0.97      0.97      0.97        36

# %% [markdown]
# ### CNN

# %%
input_size = X.shape[1]
output_size = 3

#preprocessing
label_encoder = LabelEncoder()
# Out:
# 13

# %% [markdown]
# **50/50 Split**

# %%
# preprocessing
y_train50_ord = label_encoder.fit_transform(y_train50) # can't use string as before -> assign unique integer to each class
y_test50_ord = label_encoder.fit_transform(y_test50)

x_train50_reshaped = x_train50.to_numpy().reshape(-1, input_size, 1)
x_test50_reshaped = x_test50.to_numpy().reshape(-1, input_size, 1)

# define model

model = Sequential([
    Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(input_size, 1)),
    MaxPooling1D(pool_size=2),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(output_size, activation='softmax')
])

model.summary()

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# training and testing

model.fit(x_train50_reshaped, y_train50_ord, epochs=200, batch_size=64, verbose=2)

print()
print('Classification results:')

loss, accuracy = model.evaluate(x_test50_reshaped, y_test50_ord, verbose=2)

model_pred = model.predict(x_test50_reshaped)

# print(model_pred)

model_pred_classes = np.argmax(model_pred, axis=1)

print(confusion_matrix(y_test50_ord, model_pred_classes))
print(classification_report(y_test50_ord, model_pred_classes))

wine_CNN_5050 = Classifier('CNN [in C1D P1D F 128 out]', accuracy, confusion_matrix(y_test50_ord, model_pred_classes), classification_report(y_test50_ord, model_pred_classes))
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 11, 64)            256
#
#  max_pooling1d_4 (MaxPoolin  (None, 5, 64)             0
#  g1D)
#
#  flatten_4 (Flatten)         (None, 320)               0
#
#  dense_32 (Dense)            (None, 128)               41088
#
#  dense_33 (Dense)            (None, 3)                 387
#
# =================================================================
# Total params: 41731 (163.01 KB)
# Trainable params: 41731 (163.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Epoch 1/200
# 2/2 - 1s - loss: 1.8684 - accuracy: 0.4045 - 737ms/epoch - 368ms/step
# Epoch 2/200
# 2/2 - 0s - loss: 1.1805 - accuracy: 0.4157 - 13ms/epoch - 6ms/step
# Epoch 3/200
# 2/2 - 0s - loss: 1.5441 - accuracy: 0.5056 - 20ms/epoch - 10ms/step
# Epoch 4/200
# 2/2 - 0s - loss: 1.0141 - accuracy: 0.5843 - 15ms/epoch - 7ms/step
# Epoch 5/200
# 2/2 - 0s - loss: 1.0640 - accuracy: 0.3034 - 16ms/epoch - 8ms/step
# Epoch 6/200
# 2/2 - 0s - loss: 0.7427 - accuracy: 0.7191 - 11ms/epoch - 5ms/step
# Epoch 7/200
# 2/2 - 0s - loss: 0.9506 - accuracy: 0.6067 - 17ms/epoch - 9ms/step
# Epoch 8/200
# 2/2 - 0s - loss: 0.7861 - accuracy: 0.6517 - 12ms/epoch - 6ms/step
# Epoch 9/200
# 2/2 - 0s - loss: 0.6460 - accuracy: 0.8090 - 11ms/epoch - 5ms/step
# Epoch 10/200
# 2/2 - 0s - loss: 0.8083 - accuracy: 0.4944 - 14ms/epoch - 7ms/step
# Epoch 11/200
# 2/2 - 0s - loss: 0.5869 - accuracy: 0.8090 - 12ms/epoch - 6ms/step
# Epoch 12/200
# 2/2 - 0s - loss: 0.6944 - accuracy: 0.6966 - 13ms/epoch - 6ms/step
# Epoch 13/200
# 2/2 - 0s - loss: 0.6047 - accuracy: 0.7865 - 13ms/epoch - 7ms/step
# Epoch 14/200
# 2/2 - 0s - loss: 0.5047 - accuracy: 0.8876 - 13ms/epoch - 7ms/step
# Epoch 15/200
# 2/2 - 0s - loss: 0.5763 - accuracy: 0.7978 - 13ms/epoch - 6ms/step
# Epoch 16/200
# 2/2 - 0s - loss: 0.4779 - accuracy: 0.8539 - 12ms/epoch - 6ms/step
# Epoch 17/200
# 2/2 - 0s - loss: 0.5141 - accuracy: 0.7865 - 13ms/epoch - 6ms/step
# Epoch 18/200
# 2/2 - 0s - loss: 0.4601 - accuracy: 0.8427 - 12ms/epoch - 6ms/step
# Epoch 19/200
# 2/2 - 0s - loss: 0.4334 - accuracy: 0.8539 - 12ms/epoch - 6ms/step
# Epoch 20/200
# 2/2 - 0s - loss: 0.4427 - accuracy: 0.8876 - 15ms/epoch - 8ms/step
# Epoch 21/200
# 2/2 - 0s - loss: 0.4274 - accuracy: 0.8764 - 18ms/epoch - 9ms/step
# Epoch 22/200
# 2/2 - 0s - loss: 0.4100 - accuracy: 0.8315 - 13ms/epoch - 7ms/step
# Epoch 23/200
# 2/2 - 0s - loss: 0.4174 - accuracy: 0.8090 - 15ms/epoch - 8ms/step
# Epoch 24/200
# 2/2 - 0s - loss: 0.3918 - accuracy: 0.8764 - 13ms/epoch - 7ms/step
# Epoch 25/200
# 2/2 - 0s - loss: 0.3634 - accuracy: 0.8989 - 11ms/epoch - 6ms/step
# Epoch 26/200
# 2/2 - 0s - loss: 0.3984 - accuracy: 0.8652 - 12ms/epoch - 6ms/step
# Epoch 27/200
# 2/2 - 0s - loss: 0.3888 - accuracy: 0.8539 - 12ms/epoch - 6ms/step
# Epoch 28/200
# 2/2 - 0s - loss: 0.3510 - accuracy: 0.8989 - 13ms/epoch - 6ms/step
# Epoch 29/200
# 2/2 - 0s - loss: 0.3518 - accuracy: 0.8764 - 15ms/epoch - 7ms/step
# Epoch 30/200
# 2/2 - 0s - loss: 0.3417 - accuracy: 0.8539 - 12ms/epoch - 6ms/step
# Epoch 31/200
# 2/2 - 0s - loss: 0.3331 - accuracy: 0.8876 - 12ms/epoch - 6ms/step
# Epoch 32/200
# 2/2 - 0s - loss: 0.3262 - accuracy: 0.9213 - 13ms/epoch - 6ms/step
# Epoch 33/200
# 2/2 - 0s - loss: 0.3261 - accuracy: 0.8989 - 12ms/epoch - 6ms/step
# Epoch 34/200
# 2/2 - 0s - loss: 0.3127 - accuracy: 0.8539 - 11ms/epoch - 6ms/step
# Epoch 35/200
# 2/2 - 0s - loss: 0.3068 - accuracy: 0.8876 - 12ms/epoch - 6ms/step
# Epoch 36/200
# 2/2 - 0s - loss: 0.3089 - accuracy: 0.9101 - 13ms/epoch - 6ms/step
# Epoch 37/200
# 2/2 - 0s - loss: 0.2983 - accuracy: 0.9101 - 12ms/epoch - 6ms/step
# Epoch 38/200
# 2/2 - 0s - loss: 0.3146 - accuracy: 0.8539 - 11ms/epoch - 6ms/step
# Epoch 39/200
# 2/2 - 0s - loss: 0.3205 - accuracy: 0.8315 - 13ms/epoch - 7ms/step
# Epoch 40/200
# 2/2 - 0s - loss: 0.2909 - accuracy: 0.9101 - 13ms/epoch - 6ms/step
# Epoch 41/200
# 2/2 - 0s - loss: 0.2822 - accuracy: 0.9213 - 12ms/epoch - 6ms/step
# Epoch 42/200
# 2/2 - 0s - loss: 0.3038 - accuracy: 0.8652 - 12ms/epoch - 6ms/step
# Epoch 43/200
# 2/2 - 0s - loss: 0.2673 - accuracy: 0.9101 - 12ms/epoch - 6ms/step
# Epoch 44/200
# 2/2 - 0s - loss: 0.3255 - accuracy: 0.8989 - 12ms/epoch - 6ms/step
# Epoch 45/200
# 2/2 - 0s - loss: 0.2766 - accuracy: 0.9101 - 12ms/epoch - 6ms/step
# Epoch 46/200
# 2/2 - 0s - loss: 0.3114 - accuracy: 0.8764 - 12ms/epoch - 6ms/step
# Epoch 47/200
# 2/2 - 0s - loss: 0.2607 - accuracy: 0.9213 - 12ms/epoch - 6ms/step
# Epoch 48/200
# 2/2 - 0s - loss: 0.2788 - accuracy: 0.9101 - 12ms/epoch - 6ms/step
# Epoch 49/200
# 2/2 - 0s - loss: 0.2794 - accuracy: 0.8989 - 11ms/epoch - 5ms/step
# Epoch 50/200
# 2/2 - 0s - loss: 0.2617 - accuracy: 0.8989 - 14ms/epoch - 7ms/step
# Epoch 51/200
# 2/2 - 0s - loss: 0.2807 - accuracy: 0.9326 - 12ms/epoch - 6ms/step
# Epoch 52/200
# 2/2 - 0s - loss: 0.2466 - accuracy: 0.9326 - 12ms/epoch - 6ms/step
# Epoch 53/200
# 2/2 - 0s - loss: 0.2876 - accuracy: 0.8764 - 12ms/epoch - 6ms/step
# Epoch 54/200
# 2/2 - 0s - loss: 0.2642 - accuracy: 0.8764 - 11ms/epoch - 6ms/step
# Epoch 55/200
# 2/2 - 0s - loss: 0.2693 - accuracy: 0.9101 - 12ms/epoch - 6ms/step
# Epoch 56/200
# 2/2 - 0s - loss: 0.2509 - accuracy: 0.9101 - 15ms/epoch - 8ms/step
# Epoch 57/200
# 2/2 - 0s - loss: 0.2528 - accuracy: 0.9213 - 14ms/epoch - 7ms/step
# Epoch 58/200
# 2/2 - 0s - loss: 0.2374 - accuracy: 0.9213 - 12ms/epoch - 6ms/step
# Epoch 59/200
# 2/2 - 0s - loss: 0.2426 - accuracy: 0.9213 - 14ms/epoch - 7ms/step
# Epoch 60/200
# 2/2 - 0s - loss: 0.2319 - accuracy: 0.8989 - 13ms/epoch - 6ms/step
# Epoch 61/200
# 2/2 - 0s - loss: 0.2634 - accuracy: 0.8652 - 12ms/epoch - 6ms/step
# Epoch 62/200
# 2/2 - 0s - loss: 0.2210 - accuracy: 0.9213 - 13ms/epoch - 6ms/step
# Epoch 63/200
# 2/2 - 0s - loss: 0.2315 - accuracy: 0.9326 - 12ms/epoch - 6ms/step
# Epoch 64/200
# 2/2 - 0s - loss: 0.2234 - accuracy: 0.9213 - 16ms/epoch - 8ms/step
# Epoch 65/200
# 2/2 - 0s - loss: 0.2447 - accuracy: 0.9101 - 17ms/epoch - 8ms/step
# Epoch 66/200
# 2/2 - 0s - loss: 0.2142 - accuracy: 0.9326 - 12ms/epoch - 6ms/step
# Epoch 67/200
# 2/2 - 0s - loss: 0.2232 - accuracy: 0.9326 - 12ms/epoch - 6ms/step
# Epoch 68/200
# 2/2 - 0s - loss: 0.2108 - accuracy: 0.9326 - 12ms/epoch - 6ms/step
# Epoch 69/200
# 2/2 - 0s - loss: 0.2398 - accuracy: 0.8876 - 13ms/epoch - 6ms/step
# Epoch 70/200
# 2/2 - 0s - loss: 0.2131 - accuracy: 0.9326 - 13ms/epoch - 7ms/step
# Epoch 71/200
# 2/2 - 0s - loss: 0.2859 - accuracy: 0.8989 - 12ms/epoch - 6ms/step
# Epoch 72/200
# 2/2 - 0s - loss: 0.2102 - accuracy: 0.9326 - 12ms/epoch - 6ms/step
# Epoch 73/200
# 2/2 - 0s - loss: 0.2921 - accuracy: 0.8539 - 12ms/epoch - 6ms/step
# Epoch 74/200
# 2/2 - 0s - loss: 0.2307 - accuracy: 0.9213 - 12ms/epoch - 6ms/step
# Epoch 75/200
# 2/2 - 0s - loss: 0.3200 - accuracy: 0.8539 - 11ms/epoch - 6ms/step
# Epoch 76/200
# 2/2 - 0s - loss: 0.2060 - accuracy: 0.9101 - 11ms/epoch - 6ms/step
# Epoch 77/200
# 2/2 - 0s - loss: 0.2299 - accuracy: 0.9101 - 11ms/epoch - 6ms/step
# Epoch 78/200
# 2/2 - 0s - loss: 0.2095 - accuracy: 0.9213 - 12ms/epoch - 6ms/step
# Epoch 79/200
# 2/2 - 0s - loss: 0.2031 - accuracy: 0.9326 - 12ms/epoch - 6ms/step
# Epoch 80/200
# 2/2 - 0s - loss: 0.1997 - accuracy: 0.9213 - 12ms/epoch - 6ms/step
# Epoch 81/200
# 2/2 - 0s - loss: 0.1985 - accuracy: 0.9326 - 12ms/epoch - 6ms/step
# Epoch 82/200
# 2/2 - 0s - loss: 0.2012 - accuracy: 0.9438 - 13ms/epoch - 7ms/step
# Epoch 83/200
# 2/2 - 0s - loss: 0.1957 - accuracy: 0.9326 - 13ms/epoch - 6ms/step
# Epoch 84/200
# 2/2 - 0s - loss: 0.1973 - accuracy: 0.9213 - 11ms/epoch - 6ms/step
# Epoch 85/200
# 2/2 - 0s - loss: 0.1896 - accuracy: 0.9438 - 11ms/epoch - 5ms/step
# Epoch 86/200
# 2/2 - 0s - loss: 0.1969 - accuracy: 0.9438 - 13ms/epoch - 6ms/step
# Epoch 87/200
# 2/2 - 0s - loss: 0.1901 - accuracy: 0.9438 - 11ms/epoch - 6ms/step
# Epoch 88/200
# 2/2 - 0s - loss: 0.1922 - accuracy: 0.9326 - 13ms/epoch - 6ms/step
# Epoch 89/200
# 2/2 - 0s - loss: 0.1864 - accuracy: 0.9326 - 12ms/epoch - 6ms/step
# Epoch 90/200
# 2/2 - 0s - loss: 0.1865 - accuracy: 0.9438 - 10ms/epoch - 5ms/step
# Epoch 91/200
# 2/2 - 0s - loss: 0.1856 - accuracy: 0.9326 - 11ms/epoch - 6ms/step
# Epoch 92/200
# 2/2 - 0s - loss: 0.1848 - accuracy: 0.9213 - 15ms/epoch - 8ms/step
# Epoch 93/200
# 2/2 - 0s - loss: 0.1825 - accuracy: 0.9438 - 13ms/epoch - 6ms/step
# Epoch 94/200
# 2/2 - 0s - loss: 0.2062 - accuracy: 0.9326 - 13ms/epoch - 6ms/step
# Epoch 95/200
# 2/2 - 0s - loss: 0.1822 - accuracy: 0.9438 - 12ms/epoch - 6ms/step
# Epoch 96/200
# 2/2 - 0s - loss: 0.1789 - accuracy: 0.9326 - 11ms/epoch - 6ms/step
# Epoch 97/200
# 2/2 - 0s - loss: 0.1812 - accuracy: 0.9326 - 13ms/epoch - 6ms/step
# Epoch 98/200
# 2/2 - 0s - loss: 0.1759 - accuracy: 0.9438 - 12ms/epoch - 6ms/step
# Epoch 99/200
# 2/2 - 0s - loss: 0.1769 - accuracy: 0.9326 - 13ms/epoch - 6ms/step
# Epoch 100/200
# 2/2 - 0s - loss: 0.1823 - accuracy: 0.9213 - 14ms/epoch - 7ms/step
# Epoch 101/200
# 2/2 - 0s - loss: 0.1797 - accuracy: 0.9213 - 13ms/epoch - 7ms/step
# Epoch 102/200
# 2/2 - 0s - loss: 0.1822 - accuracy: 0.9213 - 13ms/epoch - 6ms/step
# Epoch 103/200
# 2/2 - 0s - loss: 0.1719 - accuracy: 0.9438 - 15ms/epoch - 8ms/step
# Epoch 104/200
# 2/2 - 0s - loss: 0.1724 - accuracy: 0.9438 - 13ms/epoch - 7ms/step
# Epoch 105/200
# 2/2 - 0s - loss: 0.1688 - accuracy: 0.9438 - 14ms/epoch - 7ms/step
# Epoch 106/200
# 2/2 - 0s - loss: 0.1734 - accuracy: 0.9213 - 13ms/epoch - 6ms/step
# Epoch 107/200
# 2/2 - 0s - loss: 0.1693 - accuracy: 0.9438 - 12ms/epoch - 6ms/step
# Epoch 108/200
# 2/2 - 0s - loss: 0.1705 - accuracy: 0.9438 - 12ms/epoch - 6ms/step
# Epoch 109/200
# 2/2 - 0s - loss: 0.1642 - accuracy: 0.9438 - 14ms/epoch - 7ms/step
# Epoch 110/200
# 2/2 - 0s - loss: 0.1639 - accuracy: 0.9551 - 15ms/epoch - 7ms/step
# Epoch 111/200
# 2/2 - 0s - loss: 0.1661 - accuracy: 0.9438 - 11ms/epoch - 6ms/step
# Epoch 112/200
# 2/2 - 0s - loss: 0.1642 - accuracy: 0.9551 - 11ms/epoch - 6ms/step
# Epoch 113/200
# 2/2 - 0s - loss: 0.1636 - accuracy: 0.9551 - 13ms/epoch - 7ms/step
# Epoch 114/200
# 2/2 - 0s - loss: 0.1598 - accuracy: 0.9551 - 12ms/epoch - 6ms/step
# Epoch 115/200
# 2/2 - 0s - loss: 0.1650 - accuracy: 0.9438 - 13ms/epoch - 7ms/step
# Epoch 116/200
# 2/2 - 0s - loss: 0.1559 - accuracy: 0.9551 - 13ms/epoch - 6ms/step
# Epoch 117/200
# 2/2 - 0s - loss: 0.1822 - accuracy: 0.9326 - 12ms/epoch - 6ms/step
# Epoch 118/200
# 2/2 - 0s - loss: 0.1556 - accuracy: 0.9551 - 13ms/epoch - 6ms/step
# Epoch 119/200
# 2/2 - 0s - loss: 0.1878 - accuracy: 0.9326 - 13ms/epoch - 6ms/step
# Epoch 120/200
# 2/2 - 0s - loss: 0.1656 - accuracy: 0.9438 - 13ms/epoch - 7ms/step
# Epoch 121/200
# 2/2 - 0s - loss: 0.1926 - accuracy: 0.9326 - 12ms/epoch - 6ms/step
# Epoch 122/200
# 2/2 - 0s - loss: 0.1782 - accuracy: 0.9213 - 13ms/epoch - 7ms/step
# Epoch 123/200
# 2/2 - 0s - loss: 0.1865 - accuracy: 0.9438 - 13ms/epoch - 7ms/step
# Epoch 124/200
# 2/2 - 0s - loss: 0.1572 - accuracy: 0.9326 - 12ms/epoch - 6ms/step
# Epoch 125/200
# 2/2 - 0s - loss: 0.1542 - accuracy: 0.9551 - 16ms/epoch - 8ms/step
# Epoch 126/200
# 2/2 - 0s - loss: 0.1648 - accuracy: 0.9438 - 15ms/epoch - 8ms/step
# Epoch 127/200
# 2/2 - 0s - loss: 0.1585 - accuracy: 0.9438 - 19ms/epoch - 10ms/step
# Epoch 128/200
# 2/2 - 0s - loss: 0.1571 - accuracy: 0.9438 - 14ms/epoch - 7ms/step
# Epoch 129/200
# 2/2 - 0s - loss: 0.1505 - accuracy: 0.9438 - 15ms/epoch - 8ms/step
# Epoch 130/200
# 2/2 - 0s - loss: 0.1525 - accuracy: 0.9438 - 16ms/epoch - 8ms/step
# Epoch 131/200
# 2/2 - 0s - loss: 0.1479 - accuracy: 0.9438 - 15ms/epoch - 7ms/step
# Epoch 132/200
# 2/2 - 0s - loss: 0.1528 - accuracy: 0.9551 - 16ms/epoch - 8ms/step
# Epoch 133/200
# 2/2 - 0s - loss: 0.1533 - accuracy: 0.9775 - 14ms/epoch - 7ms/step
# Epoch 134/200
# 2/2 - 0s - loss: 0.1757 - accuracy: 0.9551 - 23ms/epoch - 12ms/step
# Epoch 135/200
# 2/2 - 0s - loss: 0.1838 - accuracy: 0.9326 - 15ms/epoch - 7ms/step
# Epoch 136/200
# 2/2 - 0s - loss: 0.1544 - accuracy: 0.9326 - 15ms/epoch - 7ms/step
# Epoch 137/200
# 2/2 - 0s - loss: 0.1582 - accuracy: 0.9326 - 14ms/epoch - 7ms/step
# Epoch 138/200
# 2/2 - 0s - loss: 0.1453 - accuracy: 0.9438 - 17ms/epoch - 9ms/step
# Epoch 139/200
# 2/2 - 0s - loss: 0.1462 - accuracy: 0.9663 - 18ms/epoch - 9ms/step
# Epoch 140/200
# 2/2 - 0s - loss: 0.1646 - accuracy: 0.9551 - 15ms/epoch - 8ms/step
# Epoch 141/200
# 2/2 - 0s - loss: 0.1407 - accuracy: 0.9438 - 17ms/epoch - 9ms/step
# Epoch 142/200
# 2/2 - 0s - loss: 0.1609 - accuracy: 0.9326 - 16ms/epoch - 8ms/step
# Epoch 143/200
# 2/2 - 0s - loss: 0.1473 - accuracy: 0.9551 - 15ms/epoch - 8ms/step
# Epoch 144/200
# 2/2 - 0s - loss: 0.1428 - accuracy: 0.9326 - 14ms/epoch - 7ms/step
# Epoch 145/200
# 2/2 - 0s - loss: 0.1339 - accuracy: 0.9775 - 14ms/epoch - 7ms/step
# Epoch 146/200
# 2/2 - 0s - loss: 0.1504 - accuracy: 0.9551 - 14ms/epoch - 7ms/step
# Epoch 147/200
# 2/2 - 0s - loss: 0.1547 - accuracy: 0.9551 - 16ms/epoch - 8ms/step
# Epoch 148/200
# 2/2 - 0s - loss: 0.1325 - accuracy: 0.9663 - 13ms/epoch - 7ms/step
# Epoch 149/200
# 2/2 - 0s - loss: 0.1404 - accuracy: 0.9551 - 16ms/epoch - 8ms/step
# Epoch 150/200
# 2/2 - 0s - loss: 0.1476 - accuracy: 0.9551 - 14ms/epoch - 7ms/step
# Epoch 151/200
# 2/2 - 0s - loss: 0.1356 - accuracy: 0.9551 - 14ms/epoch - 7ms/step
# Epoch 152/200
# 2/2 - 0s - loss: 0.1400 - accuracy: 0.9326 - 14ms/epoch - 7ms/step
# Epoch 153/200
# 2/2 - 0s - loss: 0.1353 - accuracy: 0.9775 - 13ms/epoch - 7ms/step
# Epoch 154/200
# 2/2 - 0s - loss: 0.1418 - accuracy: 0.9326 - 16ms/epoch - 8ms/step
# Epoch 155/200
# 2/2 - 0s - loss: 0.1291 - accuracy: 0.9663 - 14ms/epoch - 7ms/step
# Epoch 156/200
# 2/2 - 0s - loss: 0.1318 - accuracy: 0.9663 - 14ms/epoch - 7ms/step
# Epoch 157/200
# 2/2 - 0s - loss: 0.1337 - accuracy: 0.9438 - 14ms/epoch - 7ms/step
# Epoch 158/200
# 2/2 - 0s - loss: 0.1332 - accuracy: 0.9551 - 16ms/epoch - 8ms/step
# Epoch 159/200
# 2/2 - 0s - loss: 0.1266 - accuracy: 0.9551 - 13ms/epoch - 7ms/step
# Epoch 160/200
# 2/2 - 0s - loss: 0.1360 - accuracy: 0.9551 - 19ms/epoch - 10ms/step
# Epoch 161/200
# 2/2 - 0s - loss: 0.1331 - accuracy: 0.9775 - 15ms/epoch - 7ms/step
# Epoch 162/200
# 2/2 - 0s - loss: 0.1225 - accuracy: 0.9551 - 15ms/epoch - 7ms/step
# Epoch 163/200
# 2/2 - 0s - loss: 0.1319 - accuracy: 0.9326 - 13ms/epoch - 7ms/step
# Epoch 164/200
# 2/2 - 0s - loss: 0.1258 - accuracy: 0.9551 - 15ms/epoch - 8ms/step
# Epoch 165/200
# 2/2 - 0s - loss: 0.1207 - accuracy: 0.9663 - 15ms/epoch - 8ms/step
# Epoch 166/200
# 2/2 - 0s - loss: 0.1224 - accuracy: 0.9663 - 17ms/epoch - 9ms/step
# Epoch 167/200
# 2/2 - 0s - loss: 0.1249 - accuracy: 0.9775 - 17ms/epoch - 8ms/step
# Epoch 168/200
# 2/2 - 0s - loss: 0.1221 - accuracy: 0.9663 - 16ms/epoch - 8ms/step
# Epoch 169/200
# 2/2 - 0s - loss: 0.1216 - accuracy: 0.9551 - 16ms/epoch - 8ms/step
# Epoch 170/200
# 2/2 - 0s - loss: 0.1223 - accuracy: 0.9663 - 18ms/epoch - 9ms/step
# Epoch 171/200
# 2/2 - 0s - loss: 0.1216 - accuracy: 0.9663 - 16ms/epoch - 8ms/step
# Epoch 172/200
# 2/2 - 0s - loss: 0.1447 - accuracy: 0.9326 - 18ms/epoch - 9ms/step
# Epoch 173/200
# 2/2 - 0s - loss: 0.1540 - accuracy: 0.9326 - 15ms/epoch - 7ms/step
# Epoch 174/200
# 2/2 - 0s - loss: 0.1298 - accuracy: 0.9551 - 17ms/epoch - 9ms/step
# Epoch 175/200
# 2/2 - 0s - loss: 0.1319 - accuracy: 0.9663 - 16ms/epoch - 8ms/step
# Epoch 176/200
# 2/2 - 0s - loss: 0.1256 - accuracy: 0.9551 - 14ms/epoch - 7ms/step
# Epoch 177/200
# 2/2 - 0s - loss: 0.1324 - accuracy: 0.9438 - 19ms/epoch - 9ms/step
# Epoch 178/200
# 2/2 - 0s - loss: 0.1217 - accuracy: 0.9551 - 17ms/epoch - 8ms/step
# Epoch 179/200
# 2/2 - 0s - loss: 0.1230 - accuracy: 0.9775 - 18ms/epoch - 9ms/step
# Epoch 180/200
# 2/2 - 0s - loss: 0.1220 - accuracy: 0.9663 - 16ms/epoch - 8ms/step
# Epoch 181/200
# 2/2 - 0s - loss: 0.1131 - accuracy: 0.9775 - 12ms/epoch - 6ms/step
# Epoch 182/200
# 2/2 - 0s - loss: 0.1304 - accuracy: 0.9663 - 13ms/epoch - 6ms/step
# Epoch 183/200
# 2/2 - 0s - loss: 0.1226 - accuracy: 0.9663 - 13ms/epoch - 7ms/step
# Epoch 184/200
# 2/2 - 0s - loss: 0.1096 - accuracy: 0.9775 - 15ms/epoch - 8ms/step
# Epoch 185/200
# 2/2 - 0s - loss: 0.1176 - accuracy: 0.9663 - 13ms/epoch - 6ms/step
# Epoch 186/200
# 2/2 - 0s - loss: 0.1113 - accuracy: 0.9775 - 12ms/epoch - 6ms/step
# Epoch 187/200
# 2/2 - 0s - loss: 0.1140 - accuracy: 0.9663 - 12ms/epoch - 6ms/step
# Epoch 188/200
# 2/2 - 0s - loss: 0.1146 - accuracy: 0.9663 - 12ms/epoch - 6ms/step
# Epoch 189/200
# 2/2 - 0s - loss: 0.1061 - accuracy: 0.9663 - 14ms/epoch - 7ms/step
# Epoch 190/200
# 2/2 - 0s - loss: 0.1184 - accuracy: 0.9326 - 13ms/epoch - 6ms/step
# Epoch 191/200
# 2/2 - 0s - loss: 0.1360 - accuracy: 0.9551 - 12ms/epoch - 6ms/step
# Epoch 192/200
# 2/2 - 0s - loss: 0.1134 - accuracy: 0.9663 - 12ms/epoch - 6ms/step
# Epoch 193/200
# 2/2 - 0s - loss: 0.1453 - accuracy: 0.9438 - 12ms/epoch - 6ms/step
# Epoch 194/200
# 2/2 - 0s - loss: 0.1298 - accuracy: 0.9551 - 12ms/epoch - 6ms/step
# Epoch 195/200
# 2/2 - 0s - loss: 0.1316 - accuracy: 0.9663 - 12ms/epoch - 6ms/step
# Epoch 196/200
# 2/2 - 0s - loss: 0.1063 - accuracy: 0.9663 - 12ms/epoch - 6ms/step
# Epoch 197/200
# 2/2 - 0s - loss: 0.1245 - accuracy: 0.9663 - 12ms/epoch - 6ms/step
# Epoch 198/200
# 2/2 - 0s - loss: 0.1053 - accuracy: 0.9663 - 12ms/epoch - 6ms/step
# Epoch 199/200
# 2/2 - 0s - loss: 0.1285 - accuracy: 0.9326 - 11ms/epoch - 6ms/step
# Epoch 200/200
# 2/2 - 0s - loss: 0.0994 - accuracy: 0.9775 - 15ms/epoch - 8ms/step
#
# Classification results:
# 3/3 - 0s - loss: 0.3124 - accuracy: 0.8989 - 159ms/epoch - 53ms/step
# 3/3 [==============================] - 0s 4ms/step
# [[23  7  0]
#  [ 0 36  0]
#  [ 0  2 21]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.77      0.87        30
#            1       0.80      1.00      0.89        36
#            2       1.00      0.91      0.95        23
#
#     accuracy                           0.90        89
#    macro avg       0.93      0.89      0.90        89
# weighted avg       0.92      0.90      0.90        89

# %% [markdown]
# **80/20 Split**

# %%
# preprocessing
y_train80_ord = label_encoder.fit_transform(y_train80) # can't use string as before -> assign unique integer to each class
y_test20_ord = label_encoder.fit_transform(y_test20)

x_train80_reshaped = x_train80.to_numpy().reshape(-1, input_size, 1)
x_test20_reshaped = x_test20.to_numpy().reshape(-1, input_size, 1)

# define model

model = Sequential([
    Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(input_size, 1)),
    MaxPooling1D(pool_size=2),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(output_size, activation='softmax')
])

model.summary()

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# training and testing

model.fit(x_train80_reshaped, y_train80_ord, epochs=200, batch_size=64, verbose=2)

print()
print('Classification results:')

loss, accuracy = model.evaluate(x_test20_reshaped, y_test20_ord, verbose=2)

model_pred = model.predict(x_test20_reshaped)

# print(model_pred)

model_pred_classes = np.argmax(model_pred, axis=1)

print(confusion_matrix(y_test20_ord, model_pred_classes))
print(classification_report(y_test20_ord, model_pred_classes))

wine_CNN_8020 = Classifier('CNN [in C1D P1D F 128 out]', accuracy, confusion_matrix(y_test20_ord, model_pred_classes), classification_report(y_test20_ord, model_pred_classes))
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_5 (Conv1D)           (None, 11, 64)            256
#
#  max_pooling1d_5 (MaxPoolin  (None, 5, 64)             0
#  g1D)
#
#  flatten_5 (Flatten)         (None, 320)               0
#
#  dense_34 (Dense)            (None, 128)               41088
#
#  dense_35 (Dense)            (None, 3)                 387
#
# =================================================================
# Total params: 41731 (163.01 KB)
# Trainable params: 41731 (163.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/200
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 3/3 - 1s - loss: 4.3989 - accuracy: 0.4155 - 806ms/epoch - 269ms/step
# Epoch 2/200
# 3/3 - 0s - loss: 1.8885 - accuracy: 0.2676 - 19ms/epoch - 6ms/step
# Epoch 3/200
# 3/3 - 0s - loss: 1.3556 - accuracy: 0.4014 - 18ms/epoch - 6ms/step
# Epoch 4/200
# 3/3 - 0s - loss: 1.4367 - accuracy: 0.3944 - 17ms/epoch - 6ms/step
# Epoch 5/200
# 3/3 - 0s - loss: 1.3755 - accuracy: 0.5070 - 17ms/epoch - 6ms/step
# Epoch 6/200
# 3/3 - 0s - loss: 0.9514 - accuracy: 0.6127 - 18ms/epoch - 6ms/step
# Epoch 7/200
# 3/3 - 0s - loss: 0.9221 - accuracy: 0.5563 - 19ms/epoch - 6ms/step
# Epoch 8/200
# 3/3 - 0s - loss: 1.0532 - accuracy: 0.4859 - 18ms/epoch - 6ms/step
# Epoch 9/200
# 3/3 - 0s - loss: 0.7507 - accuracy: 0.7042 - 17ms/epoch - 6ms/step
# Epoch 10/200
# 3/3 - 0s - loss: 0.6802 - accuracy: 0.7183 - 17ms/epoch - 6ms/step
# Epoch 11/200
# 3/3 - 0s - loss: 0.6602 - accuracy: 0.8521 - 19ms/epoch - 6ms/step
# Epoch 12/200
# 3/3 - 0s - loss: 0.6404 - accuracy: 0.6972 - 18ms/epoch - 6ms/step
# Epoch 13/200
# 3/3 - 0s - loss: 0.6033 - accuracy: 0.7535 - 18ms/epoch - 6ms/step
# Epoch 14/200
# 3/3 - 0s - loss: 0.5488 - accuracy: 0.8451 - 23ms/epoch - 8ms/step
# Epoch 15/200
# 3/3 - 0s - loss: 0.5632 - accuracy: 0.7535 - 21ms/epoch - 7ms/step
# Epoch 16/200
# 3/3 - 0s - loss: 0.4816 - accuracy: 0.8662 - 15ms/epoch - 5ms/step
# Epoch 17/200
# 3/3 - 0s - loss: 0.4683 - accuracy: 0.8873 - 16ms/epoch - 5ms/step
# Epoch 18/200
# 3/3 - 0s - loss: 0.4558 - accuracy: 0.8803 - 15ms/epoch - 5ms/step
# Epoch 19/200
# 3/3 - 0s - loss: 0.4599 - accuracy: 0.8310 - 15ms/epoch - 5ms/step
# Epoch 20/200
# 3/3 - 0s - loss: 0.4264 - accuracy: 0.9014 - 15ms/epoch - 5ms/step
# Epoch 21/200
# 3/3 - 0s - loss: 0.4738 - accuracy: 0.7887 - 15ms/epoch - 5ms/step
# Epoch 22/200
# 3/3 - 0s - loss: 0.4508 - accuracy: 0.8169 - 23ms/epoch - 8ms/step
# Epoch 23/200
# 3/3 - 0s - loss: 0.4144 - accuracy: 0.8732 - 21ms/epoch - 7ms/step
# Epoch 24/200
# 3/3 - 0s - loss: 0.3815 - accuracy: 0.8944 - 19ms/epoch - 6ms/step
# Epoch 25/200
# 3/3 - 0s - loss: 0.4566 - accuracy: 0.7817 - 14ms/epoch - 5ms/step
# Epoch 26/200
# 3/3 - 0s - loss: 0.3765 - accuracy: 0.8732 - 23ms/epoch - 8ms/step
# Epoch 27/200
# 3/3 - 0s - loss: 0.3495 - accuracy: 0.9155 - 15ms/epoch - 5ms/step
# Epoch 28/200
# 3/3 - 0s - loss: 0.3619 - accuracy: 0.9225 - 16ms/epoch - 5ms/step
# Epoch 29/200
# 3/3 - 0s - loss: 0.3677 - accuracy: 0.8592 - 14ms/epoch - 5ms/step
# Epoch 30/200
# 3/3 - 0s - loss: 0.3533 - accuracy: 0.9014 - 16ms/epoch - 5ms/step
# Epoch 31/200
# 3/3 - 0s - loss: 0.3252 - accuracy: 0.9225 - 16ms/epoch - 5ms/step
# Epoch 32/200
# 3/3 - 0s - loss: 0.3206 - accuracy: 0.9155 - 16ms/epoch - 5ms/step
# Epoch 33/200
# 3/3 - 0s - loss: 0.3199 - accuracy: 0.9225 - 16ms/epoch - 5ms/step
# Epoch 34/200
# 3/3 - 0s - loss: 0.3010 - accuracy: 0.9085 - 15ms/epoch - 5ms/step
# Epoch 35/200
# 3/3 - 0s - loss: 0.3039 - accuracy: 0.8944 - 23ms/epoch - 8ms/step
# Epoch 36/200
# 3/3 - 0s - loss: 0.3046 - accuracy: 0.9085 - 28ms/epoch - 9ms/step
# Epoch 37/200
# 3/3 - 0s - loss: 0.2866 - accuracy: 0.9085 - 21ms/epoch - 7ms/step
# Epoch 38/200
# 3/3 - 0s - loss: 0.2939 - accuracy: 0.9085 - 20ms/epoch - 7ms/step
# Epoch 39/200
# 3/3 - 0s - loss: 0.2891 - accuracy: 0.9366 - 20ms/epoch - 7ms/step
# Epoch 40/200
# 3/3 - 0s - loss: 0.2879 - accuracy: 0.9225 - 22ms/epoch - 7ms/step
# Epoch 41/200
# 3/3 - 0s - loss: 0.3071 - accuracy: 0.8803 - 21ms/epoch - 7ms/step
# Epoch 42/200
# 3/3 - 0s - loss: 0.2803 - accuracy: 0.9085 - 20ms/epoch - 7ms/step
# Epoch 43/200
# 3/3 - 0s - loss: 0.2841 - accuracy: 0.8944 - 22ms/epoch - 7ms/step
# Epoch 44/200
# 3/3 - 0s - loss: 0.2654 - accuracy: 0.9296 - 21ms/epoch - 7ms/step
# Epoch 45/200
# 3/3 - 0s - loss: 0.2643 - accuracy: 0.9225 - 21ms/epoch - 7ms/step
# Epoch 46/200
# 3/3 - 0s - loss: 0.2699 - accuracy: 0.8944 - 23ms/epoch - 8ms/step
# Epoch 47/200
# 3/3 - 0s - loss: 0.2379 - accuracy: 0.9296 - 24ms/epoch - 8ms/step
# Epoch 48/200
# 3/3 - 0s - loss: 0.2525 - accuracy: 0.8944 - 25ms/epoch - 8ms/step
# Epoch 49/200
# 3/3 - 0s - loss: 0.2515 - accuracy: 0.9085 - 23ms/epoch - 8ms/step
# Epoch 50/200
# 3/3 - 0s - loss: 0.2496 - accuracy: 0.9366 - 23ms/epoch - 8ms/step
# Epoch 51/200
# 3/3 - 0s - loss: 0.2454 - accuracy: 0.9155 - 23ms/epoch - 8ms/step
# Epoch 52/200
# 3/3 - 0s - loss: 0.2410 - accuracy: 0.9155 - 24ms/epoch - 8ms/step
# Epoch 53/200
# 3/3 - 0s - loss: 0.2389 - accuracy: 0.9085 - 25ms/epoch - 8ms/step
# Epoch 54/200
# 3/3 - 0s - loss: 0.2347 - accuracy: 0.9366 - 22ms/epoch - 7ms/step
# Epoch 55/200
# 3/3 - 0s - loss: 0.2368 - accuracy: 0.9437 - 26ms/epoch - 9ms/step
# Epoch 56/200
# 3/3 - 0s - loss: 0.2211 - accuracy: 0.9296 - 25ms/epoch - 8ms/step
# Epoch 57/200
# 3/3 - 0s - loss: 0.2418 - accuracy: 0.9225 - 23ms/epoch - 8ms/step
# Epoch 58/200
# 3/3 - 0s - loss: 0.2051 - accuracy: 0.9507 - 26ms/epoch - 9ms/step
# Epoch 59/200
# 3/3 - 0s - loss: 0.2234 - accuracy: 0.9296 - 30ms/epoch - 10ms/step
# Epoch 60/200
# 3/3 - 0s - loss: 0.2076 - accuracy: 0.9507 - 27ms/epoch - 9ms/step
# Epoch 61/200
# 3/3 - 0s - loss: 0.2065 - accuracy: 0.9437 - 25ms/epoch - 8ms/step
# Epoch 62/200
# 3/3 - 0s - loss: 0.2064 - accuracy: 0.9507 - 22ms/epoch - 7ms/step
# Epoch 63/200
# 3/3 - 0s - loss: 0.2210 - accuracy: 0.9296 - 19ms/epoch - 6ms/step
# Epoch 64/200
# 3/3 - 0s - loss: 0.2152 - accuracy: 0.9296 - 21ms/epoch - 7ms/step
# Epoch 65/200
# 3/3 - 0s - loss: 0.2112 - accuracy: 0.9366 - 19ms/epoch - 6ms/step
# Epoch 66/200
# 3/3 - 0s - loss: 0.2558 - accuracy: 0.8873 - 21ms/epoch - 7ms/step
# Epoch 67/200
# 3/3 - 0s - loss: 0.2171 - accuracy: 0.9507 - 21ms/epoch - 7ms/step
# Epoch 68/200
# 3/3 - 0s - loss: 0.2037 - accuracy: 0.9437 - 26ms/epoch - 9ms/step
# Epoch 69/200
# 3/3 - 0s - loss: 0.1982 - accuracy: 0.9437 - 22ms/epoch - 7ms/step
# Epoch 70/200
# 3/3 - 0s - loss: 0.2133 - accuracy: 0.9366 - 23ms/epoch - 8ms/step
# Epoch 71/200
# 3/3 - 0s - loss: 0.1863 - accuracy: 0.9366 - 19ms/epoch - 6ms/step
# Epoch 72/200
# 3/3 - 0s - loss: 0.1900 - accuracy: 0.9437 - 24ms/epoch - 8ms/step
# Epoch 73/200
# 3/3 - 0s - loss: 0.1876 - accuracy: 0.9296 - 22ms/epoch - 7ms/step
# Epoch 74/200
# 3/3 - 0s - loss: 0.1982 - accuracy: 0.9507 - 20ms/epoch - 7ms/step
# Epoch 75/200
# 3/3 - 0s - loss: 0.1914 - accuracy: 0.9366 - 20ms/epoch - 7ms/step
# Epoch 76/200
# 3/3 - 0s - loss: 0.2402 - accuracy: 0.9155 - 20ms/epoch - 7ms/step
# Epoch 77/200
# 3/3 - 0s - loss: 0.2448 - accuracy: 0.8944 - 19ms/epoch - 6ms/step
# Epoch 78/200
# 3/3 - 0s - loss: 0.1949 - accuracy: 0.9155 - 18ms/epoch - 6ms/step
# Epoch 79/200
# 3/3 - 0s - loss: 0.2321 - accuracy: 0.9225 - 19ms/epoch - 6ms/step
# Epoch 80/200
# 3/3 - 0s - loss: 0.1878 - accuracy: 0.9648 - 20ms/epoch - 7ms/step
# Epoch 81/200
# 3/3 - 0s - loss: 0.2213 - accuracy: 0.8944 - 23ms/epoch - 8ms/step
# Epoch 82/200
# 3/3 - 0s - loss: 0.2280 - accuracy: 0.9225 - 23ms/epoch - 8ms/step
# Epoch 83/200
# 3/3 - 0s - loss: 0.2042 - accuracy: 0.9225 - 25ms/epoch - 8ms/step
# Epoch 84/200
# 3/3 - 0s - loss: 0.2150 - accuracy: 0.9296 - 20ms/epoch - 7ms/step
# Epoch 85/200
# 3/3 - 0s - loss: 0.1874 - accuracy: 0.9437 - 20ms/epoch - 7ms/step
# Epoch 86/200
# 3/3 - 0s - loss: 0.2107 - accuracy: 0.8944 - 23ms/epoch - 8ms/step
# Epoch 87/200
# 3/3 - 0s - loss: 0.2058 - accuracy: 0.9296 - 22ms/epoch - 7ms/step
# Epoch 88/200
# 3/3 - 0s - loss: 0.1778 - accuracy: 0.9437 - 23ms/epoch - 8ms/step
# Epoch 89/200
# 3/3 - 0s - loss: 0.2149 - accuracy: 0.9225 - 21ms/epoch - 7ms/step
# Epoch 90/200
# 3/3 - 0s - loss: 0.1673 - accuracy: 0.9507 - 20ms/epoch - 7ms/step
# Epoch 91/200
# 3/3 - 0s - loss: 0.1680 - accuracy: 0.9577 - 20ms/epoch - 7ms/step
# Epoch 92/200
# 3/3 - 0s - loss: 0.1683 - accuracy: 0.9577 - 21ms/epoch - 7ms/step
# Epoch 93/200
# 3/3 - 0s - loss: 0.1646 - accuracy: 0.9577 - 20ms/epoch - 7ms/step
# Epoch 94/200
# 3/3 - 0s - loss: 0.1731 - accuracy: 0.9366 - 21ms/epoch - 7ms/step
# Epoch 95/200
# 3/3 - 0s - loss: 0.2093 - accuracy: 0.9225 - 22ms/epoch - 7ms/step
# Epoch 96/200
# 3/3 - 0s - loss: 0.1604 - accuracy: 0.9437 - 29ms/epoch - 10ms/step
# Epoch 97/200
# 3/3 - 0s - loss: 0.2108 - accuracy: 0.9225 - 22ms/epoch - 7ms/step
# Epoch 98/200
# 3/3 - 0s - loss: 0.1944 - accuracy: 0.9225 - 22ms/epoch - 7ms/step
# Epoch 99/200
# 3/3 - 0s - loss: 0.1569 - accuracy: 0.9577 - 21ms/epoch - 7ms/step
# Epoch 100/200
# 3/3 - 0s - loss: 0.1736 - accuracy: 0.9225 - 20ms/epoch - 7ms/step
# Epoch 101/200
# 3/3 - 0s - loss: 0.1644 - accuracy: 0.9437 - 20ms/epoch - 7ms/step
# Epoch 102/200
# 3/3 - 0s - loss: 0.1649 - accuracy: 0.9437 - 21ms/epoch - 7ms/step
# Epoch 103/200
# 3/3 - 0s - loss: 0.1697 - accuracy: 0.9437 - 22ms/epoch - 7ms/step
# Epoch 104/200
# 3/3 - 0s - loss: 0.1545 - accuracy: 0.9577 - 20ms/epoch - 7ms/step
# Epoch 105/200
# 3/3 - 0s - loss: 0.1641 - accuracy: 0.9366 - 21ms/epoch - 7ms/step
# Epoch 106/200
# 3/3 - 0s - loss: 0.1587 - accuracy: 0.9507 - 21ms/epoch - 7ms/step
# Epoch 107/200
# 3/3 - 0s - loss: 0.1631 - accuracy: 0.9437 - 22ms/epoch - 7ms/step
# Epoch 108/200
# 3/3 - 0s - loss: 0.1482 - accuracy: 0.9577 - 24ms/epoch - 8ms/step
# Epoch 109/200
# 3/3 - 0s - loss: 0.1768 - accuracy: 0.9437 - 23ms/epoch - 8ms/step
# Epoch 110/200
# 3/3 - 0s - loss: 0.1828 - accuracy: 0.9225 - 21ms/epoch - 7ms/step
# Epoch 111/200
# 3/3 - 0s - loss: 0.1868 - accuracy: 0.9296 - 24ms/epoch - 8ms/step
# Epoch 112/200
# 3/3 - 0s - loss: 0.1729 - accuracy: 0.9366 - 21ms/epoch - 7ms/step
# Epoch 113/200
# 3/3 - 0s - loss: 0.2131 - accuracy: 0.9085 - 20ms/epoch - 7ms/step
# Epoch 114/200
# 3/3 - 0s - loss: 0.2310 - accuracy: 0.9085 - 23ms/epoch - 8ms/step
# Epoch 115/200
# 3/3 - 0s - loss: 0.1440 - accuracy: 0.9648 - 25ms/epoch - 8ms/step
# Epoch 116/200
# 3/3 - 0s - loss: 0.2029 - accuracy: 0.9014 - 22ms/epoch - 7ms/step
# Epoch 117/200
# 3/3 - 0s - loss: 0.2003 - accuracy: 0.9225 - 27ms/epoch - 9ms/step
# Epoch 118/200
# 3/3 - 0s - loss: 0.2216 - accuracy: 0.9014 - 29ms/epoch - 10ms/step
# Epoch 119/200
# 3/3 - 0s - loss: 0.1549 - accuracy: 0.9366 - 24ms/epoch - 8ms/step
# Epoch 120/200
# 3/3 - 0s - loss: 0.1746 - accuracy: 0.9366 - 20ms/epoch - 7ms/step
# Epoch 121/200
# 3/3 - 0s - loss: 0.2465 - accuracy: 0.8944 - 20ms/epoch - 7ms/step
# Epoch 122/200
# 3/3 - 0s - loss: 0.1636 - accuracy: 0.9366 - 23ms/epoch - 8ms/step
# Epoch 123/200
# 3/3 - 0s - loss: 0.1659 - accuracy: 0.9366 - 25ms/epoch - 8ms/step
# Epoch 124/200
# 3/3 - 0s - loss: 0.2119 - accuracy: 0.9085 - 21ms/epoch - 7ms/step
# Epoch 125/200
# 3/3 - 0s - loss: 0.1708 - accuracy: 0.9366 - 19ms/epoch - 6ms/step
# Epoch 126/200
# 3/3 - 0s - loss: 0.1410 - accuracy: 0.9437 - 23ms/epoch - 8ms/step
# Epoch 127/200
# 3/3 - 0s - loss: 0.1593 - accuracy: 0.9437 - 23ms/epoch - 8ms/step
# Epoch 128/200
# 3/3 - 0s - loss: 0.1811 - accuracy: 0.9296 - 24ms/epoch - 8ms/step
# Epoch 129/200
# 3/3 - 0s - loss: 0.1507 - accuracy: 0.9577 - 20ms/epoch - 7ms/step
# Epoch 130/200
# 3/3 - 0s - loss: 0.1754 - accuracy: 0.9155 - 20ms/epoch - 7ms/step
# Epoch 131/200
# 3/3 - 0s - loss: 0.1417 - accuracy: 0.9648 - 20ms/epoch - 7ms/step
# Epoch 132/200
# 3/3 - 0s - loss: 0.1463 - accuracy: 0.9577 - 19ms/epoch - 6ms/step
# Epoch 133/200
# 3/3 - 0s - loss: 0.1390 - accuracy: 0.9577 - 19ms/epoch - 6ms/step
# Epoch 134/200
# 3/3 - 0s - loss: 0.1565 - accuracy: 0.9507 - 19ms/epoch - 6ms/step
# Epoch 135/200
# 3/3 - 0s - loss: 0.1408 - accuracy: 0.9577 - 20ms/epoch - 7ms/step
# Epoch 136/200
# 3/3 - 0s - loss: 0.1440 - accuracy: 0.9507 - 21ms/epoch - 7ms/step
# Epoch 137/200
# 3/3 - 0s - loss: 0.1513 - accuracy: 0.9437 - 27ms/epoch - 9ms/step
# Epoch 138/200
# 3/3 - 0s - loss: 0.1564 - accuracy: 0.9366 - 22ms/epoch - 7ms/step
# Epoch 139/200
# 3/3 - 0s - loss: 0.1525 - accuracy: 0.9507 - 19ms/epoch - 6ms/step
# Epoch 140/200
# 3/3 - 0s - loss: 0.1579 - accuracy: 0.9366 - 18ms/epoch - 6ms/step
# Epoch 141/200
# 3/3 - 0s - loss: 0.1429 - accuracy: 0.9366 - 19ms/epoch - 6ms/step
# Epoch 142/200
# 3/3 - 0s - loss: 0.1363 - accuracy: 0.9648 - 18ms/epoch - 6ms/step
# Epoch 143/200
# 3/3 - 0s - loss: 0.1366 - accuracy: 0.9437 - 23ms/epoch - 8ms/step
# Epoch 144/200
# 3/3 - 0s - loss: 0.1359 - accuracy: 0.9507 - 25ms/epoch - 8ms/step
# Epoch 145/200
# 3/3 - 0s - loss: 0.1931 - accuracy: 0.9225 - 21ms/epoch - 7ms/step
# Epoch 146/200
# 3/3 - 0s - loss: 0.1392 - accuracy: 0.9507 - 20ms/epoch - 7ms/step
# Epoch 147/200
# 3/3 - 0s - loss: 0.1909 - accuracy: 0.9225 - 21ms/epoch - 7ms/step
# Epoch 148/200
# 3/3 - 0s - loss: 0.1306 - accuracy: 0.9577 - 19ms/epoch - 6ms/step
# Epoch 149/200
# 3/3 - 0s - loss: 0.1427 - accuracy: 0.9366 - 22ms/epoch - 7ms/step
# Epoch 150/200
# 3/3 - 0s - loss: 0.1515 - accuracy: 0.9437 - 21ms/epoch - 7ms/step
# Epoch 151/200
# 3/3 - 0s - loss: 0.1993 - accuracy: 0.9225 - 23ms/epoch - 8ms/step
# Epoch 152/200
# 3/3 - 0s - loss: 0.1460 - accuracy: 0.9507 - 21ms/epoch - 7ms/step
# Epoch 153/200
# 3/3 - 0s - loss: 0.1956 - accuracy: 0.9296 - 20ms/epoch - 7ms/step
# Epoch 154/200
# 3/3 - 0s - loss: 0.1598 - accuracy: 0.9366 - 20ms/epoch - 7ms/step
# Epoch 155/200
# 3/3 - 0s - loss: 0.1529 - accuracy: 0.9296 - 23ms/epoch - 8ms/step
# Epoch 156/200
# 3/3 - 0s - loss: 0.1297 - accuracy: 0.9507 - 23ms/epoch - 8ms/step
# Epoch 157/200
# 3/3 - 0s - loss: 0.1332 - accuracy: 0.9437 - 26ms/epoch - 9ms/step
# Epoch 158/200
# 3/3 - 0s - loss: 0.1498 - accuracy: 0.9296 - 20ms/epoch - 7ms/step
# Epoch 159/200
# 3/3 - 0s - loss: 0.1610 - accuracy: 0.9366 - 23ms/epoch - 8ms/step
# Epoch 160/200
# 3/3 - 0s - loss: 0.1282 - accuracy: 0.9437 - 25ms/epoch - 8ms/step
# Epoch 161/200
# 3/3 - 0s - loss: 0.1565 - accuracy: 0.9225 - 20ms/epoch - 7ms/step
# Epoch 162/200
# 3/3 - 0s - loss: 0.1287 - accuracy: 0.9507 - 23ms/epoch - 8ms/step
# Epoch 163/200
# 3/3 - 0s - loss: 0.1259 - accuracy: 0.9507 - 25ms/epoch - 8ms/step
# Epoch 164/200
# 3/3 - 0s - loss: 0.1330 - accuracy: 0.9437 - 20ms/epoch - 7ms/step
# Epoch 165/200
# 3/3 - 0s - loss: 0.1305 - accuracy: 0.9577 - 20ms/epoch - 7ms/step
# Epoch 166/200
# 3/3 - 0s - loss: 0.1190 - accuracy: 0.9648 - 20ms/epoch - 7ms/step
# Epoch 167/200
# 3/3 - 0s - loss: 0.1301 - accuracy: 0.9648 - 21ms/epoch - 7ms/step
# Epoch 168/200
# 3/3 - 0s - loss: 0.1407 - accuracy: 0.9366 - 20ms/epoch - 7ms/step
# Epoch 169/200
# 3/3 - 0s - loss: 0.1290 - accuracy: 0.9437 - 24ms/epoch - 8ms/step
# Epoch 170/200
# 3/3 - 0s - loss: 0.1465 - accuracy: 0.9296 - 31ms/epoch - 10ms/step
# Epoch 171/200
# 3/3 - 0s - loss: 0.1257 - accuracy: 0.9507 - 31ms/epoch - 10ms/step
# Epoch 172/200
# 3/3 - 0s - loss: 0.1215 - accuracy: 0.9577 - 23ms/epoch - 8ms/step
# Epoch 173/200
# 3/3 - 0s - loss: 0.1318 - accuracy: 0.9507 - 25ms/epoch - 8ms/step
# Epoch 174/200
# 3/3 - 0s - loss: 0.1751 - accuracy: 0.9296 - 21ms/epoch - 7ms/step
# Epoch 175/200
# 3/3 - 0s - loss: 0.2053 - accuracy: 0.9225 - 19ms/epoch - 6ms/step
# Epoch 176/200
# 3/3 - 0s - loss: 0.1568 - accuracy: 0.9366 - 24ms/epoch - 8ms/step
# Epoch 177/200
# 3/3 - 0s - loss: 0.3353 - accuracy: 0.8944 - 20ms/epoch - 7ms/step
# Epoch 178/200
# 3/3 - 0s - loss: 0.2360 - accuracy: 0.9155 - 18ms/epoch - 6ms/step
# Epoch 179/200
# 3/3 - 0s - loss: 0.1258 - accuracy: 0.9507 - 18ms/epoch - 6ms/step
# Epoch 180/200
# 3/3 - 0s - loss: 0.2026 - accuracy: 0.9296 - 17ms/epoch - 6ms/step
# Epoch 181/200
# 3/3 - 0s - loss: 0.1536 - accuracy: 0.9366 - 16ms/epoch - 5ms/step
# Epoch 182/200
# 3/3 - 0s - loss: 0.1129 - accuracy: 0.9648 - 17ms/epoch - 6ms/step
# Epoch 183/200
# 3/3 - 0s - loss: 0.1554 - accuracy: 0.9225 - 26ms/epoch - 9ms/step
# Epoch 184/200
# 3/3 - 0s - loss: 0.1289 - accuracy: 0.9507 - 17ms/epoch - 6ms/step
# Epoch 185/200
# 3/3 - 0s - loss: 0.1465 - accuracy: 0.9366 - 17ms/epoch - 6ms/step
# Epoch 186/200
# 3/3 - 0s - loss: 0.1385 - accuracy: 0.9437 - 20ms/epoch - 7ms/step
# Epoch 187/200
# 3/3 - 0s - loss: 0.1175 - accuracy: 0.9577 - 18ms/epoch - 6ms/step
# Epoch 188/200
# 3/3 - 0s - loss: 0.1386 - accuracy: 0.9366 - 18ms/epoch - 6ms/step
# Epoch 189/200
# 3/3 - 0s - loss: 0.1097 - accuracy: 0.9718 - 20ms/epoch - 7ms/step
# Epoch 190/200
# 3/3 - 0s - loss: 0.1571 - accuracy: 0.9366 - 19ms/epoch - 6ms/step
# Epoch 191/200
# 3/3 - 0s - loss: 0.1291 - accuracy: 0.9507 - 17ms/epoch - 6ms/step
# Epoch 192/200
# 3/3 - 0s - loss: 0.1272 - accuracy: 0.9507 - 17ms/epoch - 6ms/step
# Epoch 193/200
# 3/3 - 0s - loss: 0.1335 - accuracy: 0.9507 - 19ms/epoch - 6ms/step
# Epoch 194/200
# 3/3 - 0s - loss: 0.1162 - accuracy: 0.9648 - 17ms/epoch - 6ms/step
# Epoch 195/200
# 3/3 - 0s - loss: 0.1389 - accuracy: 0.9366 - 16ms/epoch - 5ms/step
# Epoch 196/200
# 3/3 - 0s - loss: 0.1446 - accuracy: 0.9437 - 18ms/epoch - 6ms/step
# Epoch 197/200
# 3/3 - 0s - loss: 0.1274 - accuracy: 0.9577 - 22ms/epoch - 7ms/step
# Epoch 198/200
# 3/3 - 0s - loss: 0.1227 - accuracy: 0.9648 - 18ms/epoch - 6ms/step
# Epoch 199/200
# 3/3 - 0s - loss: 0.1197 - accuracy: 0.9437 - 20ms/epoch - 7ms/step
# Epoch 200/200
# 3/3 - 0s - loss: 0.1353 - accuracy: 0.9577 - 17ms/epoch - 6ms/step
#
# Classification results:
# 2/2 - 0s - loss: 0.3822 - accuracy: 0.8889 - 168ms/epoch - 84ms/step
# 2/2 [==============================] - 0s 7ms/step
# [[10  1  0]
#  [ 2 12  0]
#  [ 0  1 10]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87        11
#            1       0.86      0.86      0.86        14
#            2       1.00      0.91      0.95        11
#
#     accuracy                           0.89        36
#    macro avg       0.90      0.89      0.89        36
# weighted avg       0.89      0.89      0.89        36

# %% [markdown]
# ## Results
#
# The following tables contain the evaluation metrics for each of the models.

# %% [markdown]
# ### Iris Dataset

# %% [markdown]
# **50/50 Split**

# %%
models = [iris_tree_5050,
          iris_bayes_5050,
          iris_k_neighbors_5050,
          iris_SVM_linear_5050,
          iris_SVM_rbf_5050,
          iris_DNN_5050,
          iris_CNN_5050]

data = {
    'Model': [m.name for m in models],
    'Accuracy': [m.accuracy for m in models],
}

table_iris_5050 = pd.DataFrame(data)

# %%
table_iris_5050
# Out:
#                         Model  Accuracy
# 0         Decision Tree 50/50  0.946667
# 1           Naïve-Bayes 50/50  0.920000
# 2        k(1)-neighbors 50/50  0.946667
# 3          SVM (linear) 50/50  0.946667
# 4             SVM (rbf) 50/50  0.946667
# 5          DNN [in 64 64 out]  0.933333
# 6  CNN [in C1D P1D F 128 out]  0.960000

# %% [markdown]
# **80/20 Split**

# %%
models = [iris_tree_8020,
          iris_bayes_8020,
          iris_k_neighbors_8020,
          iris_SVM_linear_8020,
          iris_SVM_rbf_8020,
          iris_DNN_8020,
          iris_CNN_8020]

data = {
    'Model': [m.name for m in models],
    'Accuracy': [m.accuracy for m in models],
}

table_iris_8020 = pd.DataFrame(data)

# %%
table_iris_8020
# Out:
#                         Model  Accuracy
# 0         Decision Tree 80/20  0.866667
# 1           Naïve-Bayes 80/20  0.866667
# 2        k(5)-neighbors 80/20  0.933333
# 3          SVM (linear) 80/20  0.933333
# 4             SVM (rbf) 80/20  0.946667
# 5          DNN [in 64 64 out]  0.900000
# 6  CNN [in C1D P1D F 128 out]  0.966667

# %% [markdown]
# ### Wine Dataset

# %% [markdown]
# **50/50 Split**

# %%
models = [wine_tree_5050,
          wine_bayes_5050,
          wine_k_neighbors_5050,
          wine_SVM_linear_5050,
          wine_SVM_rbf_5050,
          wine_DNN_5050,
          wine_CNN_5050]

data = {
    'Model': [m.name for m in models],
    'Accuracy': [m.accuracy for m in models],
}

table_wine_5050 = pd.DataFrame(data)

# %%
table_wine_5050
# Out:
#                         Model  Accuracy
# 0         Decision Tree 50/50  0.898876
# 1           Naïve-Bayes 50/50  0.966292
# 2       k(48)-neighbors 50/50  1.000000
# 3          SVM (linear) 50/50  0.932584
# 4             SVM (rbf) 50/50  0.932584
# 5          DNN [in 64 64 out]  0.988764
# 6  CNN [in C1D P1D F 128 out]  0.898876

# %% [markdown]
# **80/20 Split**

# %%
models = [wine_tree_8020,
          wine_bayes_8020,
          wine_k_neighbors_8020,
          wine_SVM_linear_8020,
          wine_SVM_rbf_8020,
          wine_DNN_8020,
          wine_CNN_8020]

data = {
    'Model': [m.name for m in models],
    'Accuracy': [m.accuracy for m in models],
}

table_wine_8020 = pd.DataFrame(data)

# %%
table_wine_8020
# Out:
#                         Model  Accuracy
# 0         Decision Tree 80/20  0.916667
# 1           Naïve-Bayes 80/20  0.972222
# 2       k(21)-neighbors 80/20  1.000000
# 3          SVM (linear) 80/20  0.916667
# 4             SVM (rbf) 80/20  0.943820
# 5          DNN [in 64 64 out]  0.972222
# 6  CNN [in C1D P1D F 128 out]  0.888889

# %% [markdown]
# ## **Conclusions**
#
# Most of the classifiers had comparable results, scoring relatively highly in each of the
# tests. In order to choose which algorithms one to use in future work, one should conduct tests using multiple approaches with different training and testing sampling techniques, since, as always, the algorithms are just the pawns while data is king.
#
# Additionally, maybe by averaging the results over a set of tests, one could get more statistically significant results since the accuracy with the same split percentages varies between test runs. In future work, maybe performing 100 tests for each of the models using a defined set of 100 seeds, and computing the average performance, could yield better results.
#
# On another note, the DNN results could still be improved by performing hyperparameter tuning methods, such as a grid search approach. However, just scaling the data beforehand yielded notable improvements.
#
# Finally, CNNs are not really suited for these sorts of applications since both datasets do not contain spatial information and would not benefit from the core concepts of these architectures. This could explain the relatively low accuracy of the of the results.

# %% [markdown]
# ## **References**
#
# Aeberhard, S. & Forina, M. (1991). Wine. UCI Machine Learning Repository.
# https://doi.org/10.24432/C5PC7J.
#
# Cuevas, J. (2020). Handouts on Classification Algorithms. DOI:10.13140/RG.2.2.23597.03043/1.
#
# Cuevas, J.,Valenzuela, M., and Nolazco, J. (2016b). A tutorial on deep neural networks for intelligent systems. DOI:10.13140/RG.2.1.2420.6481
#
# Gunn, S. (1998). Support Vector Machines for Classification and Regression. University of Southampton.
#
# Goodfellow, I., Bengio, Y., & Courville, A. (2016). Deep Learning. MIT Press. http://www.deeplearningbook.org.
#
# Hastie, T., Tibshirani, R., Friedman, R. (2008). The Elements of
# Statistical Learning: Data Mining, Inference, and Prediction. Springer.
#
# Hinton et al. (2012). Deep Neural Networks for Acoustic Modeling in Speech Recognition. IEEE Signal Processing. DOI: 10.1109/MSP.2012.2205597
#
# Fisher, R. A. (1988). Iris. UCI Machine Learning Repository. https://doi.org/10.24432/C56C76.
#
# Russell, S. & Norvig, P. (2015). Artificial Intelligence: A Modern Approach, 3rd Edition. Pearson Education. ISBN: 978-0136042594.
